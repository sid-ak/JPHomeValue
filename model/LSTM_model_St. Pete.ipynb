# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive, files # google colab specific
import requests
import pandas as pd
import os
import warnings
import sys
import matplotlib.pyplot as plt
import json
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from tensorflow import keras
from keras import layers
import math
from sklearn.metrics import mean_squared_error

# %%
# Read in the csv file that contains the time series data of the Shiller Index
# Create the dataframe

# Quarterly Data

#df = pd.read_csv('/content/ATNHPIUS45300Q (1).csv')
#df.head()
# Out:
#          DATE  ATNHPIUS45300Q
# 0  2002-01-01          151.34
# 1  2002-04-01          155.46
# 2  2002-07-01          159.55
# 3  2002-10-01          162.39
# 4  2003-01-01          165.24

# %%
filePath = "/content/drive/MyDrive/JPM/jphomevalue/data/ATNHPIUS45300Q.csv"
df = pd.read_csv(filePath, header = 0)
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.set_index('DATE')
df.index = df.index.to_period("1M")
df = df.resample('1M').interpolate()

# %%
df.to_csv('StPete-Clearwater.csv')
files.download('StPete-Clearwater.csv')

# %%
# Reset the index based on the prices
df1 = df.reset_index()['ATNHPIUS45300Q']
df1
# Out:
# 0      151.340000
# 1      152.713333
# 2      154.086667
# 3      155.460000
# 4      156.823333
#           ...
# 233    394.440000
# 234    403.850000
# 235    411.443333
# 236    419.036667
# 237    426.630000
# Name: ATNHPIUS45300Q, Length: 238, dtype: float64

# %%
# Visualize the data for reference. 
plt.plot(df1)

# %%
# Normalize the data with the range 0 - 1
scaler = MinMaxScaler(feature_range=(0,1))

# Apply the scaler to the dataframe
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# Print df1 to check the change
print(df1)

# %%
# Split data into train, validation and test set. Ratio: 6/1/3
training_size = int(len(df1)*0.4)
validation_size = int(len(df1)*0.82) 
test_size = int(len(df1))

train_set = df1[0:training_size,:]
validation_set = df1[training_size:validation_size,:]
test_set = df1[validation_size:test_size,:1]

prediction_set = df1[71:238,:]

# %%
#prediction_set.shape
scaler.inverse_transform(prediction_set)
# Out:
# array([[190.35666667],
#        [190.99      ],
#        [192.70666667],
#        [194.42333333],
#        [196.14      ],
#        [197.68      ],
#        [199.22      ],
#        [200.76      ],
#        [201.48666667],
#        [202.21333333],
#        [202.94      ],
#        [204.28666667],
#        [205.63333333],
#        [206.98      ],
#        [209.05333333],
#        [211.12666667],
#        [213.2       ],
#        [215.17666667],
#        [217.15333333],
#        [219.13      ],
#        [220.17333333],
#        [221.21666667],
#        [222.26      ],
#        [223.88666667],
#        [225.51333333],
#        [227.14      ],
#        [229.70333333],
#        [232.26666667],
#        [234.83      ],
#        [236.69      ],
#        [238.55      ],
#        [240.41      ],
#        [242.51      ],
#        [244.61      ],
#        [246.71      ],
#        [248.11      ],
#        [249.51      ],
#        [250.91      ],
#        [253.77      ],
#        [256.63      ],
#        [259.49      ],
#        [261.06333333],
#        [262.63666667],
#        [264.21      ],
#        [265.84      ],
#        [267.47      ],
#        [269.1       ],
#        [271.56      ],
#        [274.02      ],
#        [276.48      ],
#        [278.81333333],
#        [281.14666667],
#        [283.48      ],
#        [285.11      ],
#        [286.74      ],
#        [288.37      ],
#        [288.93      ],
#        [289.49      ],
#        [290.05      ],
#        [292.03333333],
#        [294.01666667],
#        [296.        ],
#        [297.66      ],
#        [299.32      ],
#        [300.98      ],
#        [303.14333333],
#        [305.30666667],
#        [307.47      ],
#        [308.89666667],
#        [310.32333333],
#        [311.75      ],
#        [313.56666667],
#        [315.38333333],
#        [317.2       ],
#        [318.66      ],
#        [320.12      ],
#        [321.58      ],
#        [324.19      ],
#        [326.8       ],
#        [329.41      ],
#        [332.29      ],
#        [335.17      ],
#        [338.05      ],
#        [342.43666667],
#        [346.82333333],
#        [351.21      ],
#        [359.34666667],
#        [367.48333333],
#        [375.62      ],
#        [385.03      ],
#        [394.44      ],
#        [403.85      ],
#        [411.44333333],
#        [419.03666667],
#        [426.63      ]])

# %%
# Check sizes and set sizes
#training_size
#validation_size 
#test_size
print(train_set.shape)
print(validation_set.shape)
print(test_set.shape)
# Out:
# (95, 1)
# (100, 1)
# (43, 1)

# %%
# The current array of values needs to be converted into a dataset matrix
def create_dmatrix(dataset, time_step=1):
  data_X, data_Y = [], []
  for i in range(len(dataset)-time_step-1):
    k = dataset[i:(i + time_step), 0]
    data_X.append(k)
    data_Y.append(dataset[i + time_step, 0])
  return np.array(data_X), np.array(data_Y)

# %%
# Using the function already created for the conversion, convert training, validation and test sets. 
time_step = 24
X_train, Y_train = create_dmatrix(train_set, time_step)
X_val, Y_val = create_dmatrix(validation_set, time_step)
X_test, Y_test = create_dmatrix(test_set, time_step)
X_pred, Y_pred = create_dmatrix(prediction_set, time_step)

print('X Train set shape:', X_train.shape)
print('y Train set shape:', Y_train.shape)

print('X Validation set shape:', X_val.shape)
print('y Validation set shape:', Y_val.shape)

print('X Test set shape:', X_test.shape)
print('y Test set shape:', Y_test.shape)

print('X Pred set shape:', X_pred.shape)
print('y Pred set shape:', Y_pred.shape)
# Out:
# X Train set shape: (70, 24)
# y Train set shape: (70,)
# X Validation set shape: (75, 24)
# y Validation set shape: (75,)
# X Test set shape: (18, 24)
# y Test set shape: (18,)
# X Pred set shape: (142, 24)
# y Pred set shape: (142,)

# %%
# Check the matrixes created
X_test

# %%
# In order to feed the dataset to the neural network the data must be in 3D

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[1], 1)

# %%
# Hyperparameters
batch_size = 32
epochs = 200
learning_rate = 0.001

# %%
# LSTM MODEL ARCHITECTURE

model = keras.models.Sequential([
  keras.Input(shape=(24, 1)),
  # Masking layer, to ignore zeros.
  # keras.layers.Masking(),
  # 4 LSTM Layers with 16 units.
  keras.layers.LSTM(units=200, return_sequences=True),
  keras.layers.LSTM(units=200, return_sequences=True),
  keras.layers.LSTM(units=200, return_sequences=True),
  keras.layers.LSTM(units=200),
  keras.layers.Dropout(0.5),
  # Fully Connected Layer
  keras.layers.Dense(units=1)
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 24, 200)           161600
#
#  lstm_5 (LSTM)               (None, 24, 200)           320800
#
#  lstm_6 (LSTM)               (None, 24, 200)           320800
#
#  lstm_7 (LSTM)               (None, 200)               320800
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 1,124,201
# Trainable params: 1,124,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Loss and Optimizer Functions
mse = tf.keras.losses.MeanSquaredError()
rmse = tf.keras.metrics.RootMeanSquaredError()
model.compile(loss=mse, optimizer=keras.optimizers.Adam(learning_rate=learning_rate), metrics=[rmse])

# %%
# Callbacks.

callbacks = [EarlyStopping(monitor='val_loss', patience=50, verbose=1), 
            ModelCheckpoint(filepath='/content/sample_data/lstm-model-st.pete-24-0.4-1.h5', verbose=1, monitor='val_loss', save_best_only=True, save_weights_only=False)]

# Train the model
history = model.fit(x=X_train, y=Y_train, validation_data =(X_val, Y_val), epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=callbacks)
# Out:
# Epoch 1/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0899 - root_mean_squared_error: 0.2998
# Epoch 1: val_loss improved from inf to 0.10788, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 7s 830ms/step - loss: 0.0899 - root_mean_squared_error: 0.2998 - val_loss: 0.1079 - val_root_mean_squared_error: 0.3284
# Epoch 2/200
# 3/3 [==============================] - ETA: 0s - loss: 0.1592 - root_mean_squared_error: 0.3990
# Epoch 2: val_loss improved from 0.10788 to 0.02418, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 204ms/step - loss: 0.1592 - root_mean_squared_error: 0.3990 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1555
# Epoch 3/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0559 - root_mean_squared_error: 0.2364
# Epoch 3: val_loss did not improve from 0.02418
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0559 - root_mean_squared_error: 0.2364 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1722
# Epoch 4/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0568 - root_mean_squared_error: 0.2384
# Epoch 4: val_loss improved from 0.02418 to 0.01796, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 204ms/step - loss: 0.0568 - root_mean_squared_error: 0.2384 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1340
# Epoch 5/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0310 - root_mean_squared_error: 0.1762
# Epoch 5: val_loss improved from 0.01796 to 0.00852, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 201ms/step - loss: 0.0310 - root_mean_squared_error: 0.1762 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0923
# Epoch 6/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0145 - root_mean_squared_error: 0.1203
# Epoch 6: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1414
# Epoch 7/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0213 - root_mean_squared_error: 0.1459
# Epoch 7: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 172ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 8/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0132 - root_mean_squared_error: 0.1150
# Epoch 8: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 176ms/step - loss: 0.0132 - root_mean_squared_error: 0.1150 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 9/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0164 - root_mean_squared_error: 0.1280
# Epoch 9: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 172ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1037
# Epoch 10/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1217
# Epoch 10: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 173ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# Epoch 11/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0146 - root_mean_squared_error: 0.1209
# Epoch 11: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0146 - root_mean_squared_error: 0.1209 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# Epoch 12/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0131 - root_mean_squared_error: 0.1146
# Epoch 12: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1247
# Epoch 13/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1135
# Epoch 13: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 170ms/step - loss: 0.0129 - root_mean_squared_error: 0.1135 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 14/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0148 - root_mean_squared_error: 0.1218
# Epoch 14: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0148 - root_mean_squared_error: 0.1218 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 15/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1138
# Epoch 15: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 172ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 16/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0129 - root_mean_squared_error: 0.1134
# Epoch 16: val_loss did not improve from 0.00852
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 17/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0114 - root_mean_squared_error: 0.1069
# Epoch 17: val_loss did not improve from 0.00852
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 18/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1043
# Epoch 18: val_loss did not improve from 0.00852
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 19/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0104 - root_mean_squared_error: 0.1020
# Epoch 19: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0956
# Epoch 20/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0123 - root_mean_squared_error: 0.1109
# Epoch 20: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 21/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0109 - root_mean_squared_error: 0.1043
# Epoch 21: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0969
# Epoch 22/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0110 - root_mean_squared_error: 0.1049
# Epoch 22: val_loss did not improve from 0.00852
# 3/3 [==============================] - 0s 172ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0944
# Epoch 23/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0107 - root_mean_squared_error: 0.1034
# Epoch 23: val_loss improved from 0.00852 to 0.00715, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 201ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 24/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0115 - root_mean_squared_error: 0.1073
# Epoch 24: val_loss improved from 0.00715 to 0.00654, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 199ms/step - loss: 0.0115 - root_mean_squared_error: 0.1073 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0809
# Epoch 25/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0081 - root_mean_squared_error: 0.0900
# Epoch 25: val_loss did not improve from 0.00654
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0813
# Epoch 26/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0909
# Epoch 26: val_loss improved from 0.00654 to 0.00551, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 201ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0742
# Epoch 27/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0886
# Epoch 27: val_loss improved from 0.00551 to 0.00536, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 206ms/step - loss: 0.0078 - root_mean_squared_error: 0.0886 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0732
# Epoch 28/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0078 - root_mean_squared_error: 0.0883
# Epoch 28: val_loss did not improve from 0.00536
# 3/3 [==============================] - 0s 176ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0833
# Epoch 29/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0055 - root_mean_squared_error: 0.0742
# Epoch 29: val_loss improved from 0.00536 to 0.00510, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 199ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 30/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0059 - root_mean_squared_error: 0.0768
# Epoch 30: val_loss improved from 0.00510 to 0.00499, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 201ms/step - loss: 0.0059 - root_mean_squared_error: 0.0768 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 31/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0065 - root_mean_squared_error: 0.0804
# Epoch 31: val_loss improved from 0.00499 to 0.00382, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 211ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0618
# Epoch 32/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - root_mean_squared_error: 0.0604
# Epoch 32: val_loss did not improve from 0.00382
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0037 - root_mean_squared_error: 0.0604 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0649
# Epoch 33/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0038 - root_mean_squared_error: 0.0617
# Epoch 33: val_loss improved from 0.00382 to 0.00279, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 205ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0529
# Epoch 34/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - root_mean_squared_error: 0.0607
# Epoch 34: val_loss did not improve from 0.00279
# 3/3 [==============================] - 0s 171ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0565
# Epoch 35/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0036 - root_mean_squared_error: 0.0602
# Epoch 35: val_loss improved from 0.00279 to 0.00245, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0036 - root_mean_squared_error: 0.0602 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0495
# Epoch 36/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0041 - root_mean_squared_error: 0.0639
# Epoch 36: val_loss improved from 0.00245 to 0.00121, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 199ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 37/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0036 - root_mean_squared_error: 0.0602
# Epoch 37: val_loss did not improve from 0.00121
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0036 - root_mean_squared_error: 0.0602 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0376
# Epoch 38/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0024 - root_mean_squared_error: 0.0493
# Epoch 38: val_loss did not improve from 0.00121
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0024 - root_mean_squared_error: 0.0493 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0458
# Epoch 39/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0369
# Epoch 39: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0014 - root_mean_squared_error: 0.0369 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538
# Epoch 40/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0023 - root_mean_squared_error: 0.0475
# Epoch 40: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 170ms/step - loss: 0.0023 - root_mean_squared_error: 0.0475 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 41/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0356
# Epoch 41: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 176ms/step - loss: 0.0013 - root_mean_squared_error: 0.0356 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0384
# Epoch 42/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0431
# Epoch 42: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0350
# Epoch 43/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0430
# Epoch 43: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0018 - root_mean_squared_error: 0.0430 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 44/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0460
# Epoch 44: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0021 - root_mean_squared_error: 0.0460 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476
# Epoch 45/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - root_mean_squared_error: 0.0547
# Epoch 45: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 46/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0037 - root_mean_squared_error: 0.0605
# Epoch 46: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0566
# Epoch 47/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0521
# Epoch 47: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0027 - root_mean_squared_error: 0.0521 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0483
# Epoch 48/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0047 - root_mean_squared_error: 0.0683
# Epoch 48: val_loss did not improve from 0.00121
# 3/3 [==============================] - 0s 176ms/step - loss: 0.0047 - root_mean_squared_error: 0.0683 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 49/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0026 - root_mean_squared_error: 0.0513
# Epoch 49: val_loss improved from 0.00121 to 0.00107, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 203ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 50/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0033 - root_mean_squared_error: 0.0572
# Epoch 50: val_loss did not improve from 0.00107
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0033 - root_mean_squared_error: 0.0572 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0357
# Epoch 51/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0463
# Epoch 51: val_loss did not improve from 0.00107
# 3/3 [==============================] - 0s 184ms/step - loss: 0.0021 - root_mean_squared_error: 0.0463 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0339
# Epoch 52/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0402
# Epoch 52: val_loss did not improve from 0.00107
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0016 - root_mean_squared_error: 0.0402 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0511
# Epoch 53/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0024 - root_mean_squared_error: 0.0489
# Epoch 53: val_loss did not improve from 0.00107
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0024 - root_mean_squared_error: 0.0489 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0417
# Epoch 54/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0523
# Epoch 54: val_loss did not improve from 0.00107
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 55/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0416
# Epoch 55: val_loss improved from 0.00107 to 0.00099, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 206ms/step - loss: 0.0017 - root_mean_squared_error: 0.0416 - val_loss: 9.8993e-04 - val_root_mean_squared_error: 0.0315
# Epoch 56/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0024 - root_mean_squared_error: 0.0494
# Epoch 56: val_loss did not improve from 0.00099
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0024 - root_mean_squared_error: 0.0494 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0368
# Epoch 57/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0522
# Epoch 57: val_loss did not improve from 0.00099
# 3/3 [==============================] - 1s 184ms/step - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0366
# Epoch 58/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 58: val_loss did not improve from 0.00099
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0530
# Epoch 59/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0030 - root_mean_squared_error: 0.0549
# Epoch 59: val_loss did not improve from 0.00099
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0030 - root_mean_squared_error: 0.0549 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0461
# Epoch 60/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0023 - root_mean_squared_error: 0.0475
# Epoch 60: val_loss did not improve from 0.00099
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0023 - root_mean_squared_error: 0.0475 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0392
# Epoch 61/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0448
# Epoch 61: val_loss improved from 0.00099 to 0.00061, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 201ms/step - loss: 0.0020 - root_mean_squared_error: 0.0448 - val_loss: 6.1079e-04 - val_root_mean_squared_error: 0.0247
# Epoch 62/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0463
# Epoch 62: val_loss did not improve from 0.00061
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0021 - root_mean_squared_error: 0.0463 - val_loss: 9.7511e-04 - val_root_mean_squared_error: 0.0312
# Epoch 63/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0028 - root_mean_squared_error: 0.0529
# Epoch 63: val_loss did not improve from 0.00061
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 8.3600e-04 - val_root_mean_squared_error: 0.0289
# Epoch 64/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0429
# Epoch 64: val_loss did not improve from 0.00061
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 8.9069e-04 - val_root_mean_squared_error: 0.0298
# Epoch 65/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0399
# Epoch 65: val_loss did not improve from 0.00061
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 9.6390e-04 - val_root_mean_squared_error: 0.0310
# Epoch 66/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0453
# Epoch 66: val_loss did not improve from 0.00061
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0021 - root_mean_squared_error: 0.0453 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 67/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0436
# Epoch 67: val_loss did not improve from 0.00061
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0406
# Epoch 68/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0425
# Epoch 68: val_loss did not improve from 0.00061
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0463
# Epoch 69/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0022 - root_mean_squared_error: 0.0466
# Epoch 69: val_loss did not improve from 0.00061
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0022 - root_mean_squared_error: 0.0466 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 70/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0439
# Epoch 70: val_loss improved from 0.00061 to 0.00035, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 199ms/step - loss: 0.0019 - root_mean_squared_error: 0.0439 - val_loss: 3.5471e-04 - val_root_mean_squared_error: 0.0188
# Epoch 71/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0024 - root_mean_squared_error: 0.0487
# Epoch 71: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0024 - root_mean_squared_error: 0.0487 - val_loss: 7.0232e-04 - val_root_mean_squared_error: 0.0265
# Epoch 72/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0403
# Epoch 72: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0016 - root_mean_squared_error: 0.0403 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0437
# Epoch 73/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0371
# Epoch 73: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# Epoch 74/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0023 - root_mean_squared_error: 0.0483
# Epoch 74: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0023 - root_mean_squared_error: 0.0483 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 75/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0355
# Epoch 75: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 9.8859e-04 - val_root_mean_squared_error: 0.0314
# Epoch 76/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0395
# Epoch 76: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 184ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 7.6768e-04 - val_root_mean_squared_error: 0.0277
# Epoch 77/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0347
# Epoch 77: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0012 - root_mean_squared_error: 0.0347 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# Epoch 78/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0428
# Epoch 78: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0018 - root_mean_squared_error: 0.0428 - val_loss: 4.0832e-04 - val_root_mean_squared_error: 0.0202
# Epoch 79/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0370
# Epoch 79: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 6.2995e-04 - val_root_mean_squared_error: 0.0251
# Epoch 80/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0426
# Epoch 80: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0018 - root_mean_squared_error: 0.0426 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 81/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0324
# Epoch 81: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0010 - root_mean_squared_error: 0.0324 - val_loss: 7.3176e-04 - val_root_mean_squared_error: 0.0271
# Epoch 82/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0353
# Epoch 82: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0012 - root_mean_squared_error: 0.0353 - val_loss: 4.3776e-04 - val_root_mean_squared_error: 0.0209
# Epoch 83/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0379
# Epoch 83: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 198ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 7.2530e-04 - val_root_mean_squared_error: 0.0269
# Epoch 84/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0373
# Epoch 84: val_loss did not improve from 0.00035
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0014 - root_mean_squared_error: 0.0373 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 85/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0385
# Epoch 85: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0349
# Epoch 86/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0376
# Epoch 86: val_loss did not improve from 0.00035
# 3/3 [==============================] - 0s 174ms/step - loss: 0.0014 - root_mean_squared_error: 0.0376 - val_loss: 5.2185e-04 - val_root_mean_squared_error: 0.0228
# Epoch 87/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0340
# Epoch 87: val_loss improved from 0.00035 to 0.00017, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 195ms/step - loss: 0.0012 - root_mean_squared_error: 0.0340 - val_loss: 1.6648e-04 - val_root_mean_squared_error: 0.0129
# Epoch 88/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0417
# Epoch 88: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 174ms/step - loss: 0.0017 - root_mean_squared_error: 0.0417 - val_loss: 5.6943e-04 - val_root_mean_squared_error: 0.0239
# Epoch 89/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0397
# Epoch 89: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0387
# Epoch 90/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0348
# Epoch 90: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0012 - root_mean_squared_error: 0.0348 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0413
# Epoch 91/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0444
# Epoch 91: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 174ms/step - loss: 0.0020 - root_mean_squared_error: 0.0444 - val_loss: 8.0728e-04 - val_root_mean_squared_error: 0.0284
# Epoch 92/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0374
# Epoch 92: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0014 - root_mean_squared_error: 0.0374 - val_loss: 2.8630e-04 - val_root_mean_squared_error: 0.0169
# Epoch 93/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0372
# Epoch 93: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 3.2906e-04 - val_root_mean_squared_error: 0.0181
# Epoch 94/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0391
# Epoch 94: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 172ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 7.1132e-04 - val_root_mean_squared_error: 0.0267
# Epoch 95/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0364
# Epoch 95: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0013 - root_mean_squared_error: 0.0364 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 96/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0373
# Epoch 96: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0014 - root_mean_squared_error: 0.0373 - val_loss: 9.7328e-04 - val_root_mean_squared_error: 0.0312
# Epoch 97/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0360
# Epoch 97: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 8.7705e-04 - val_root_mean_squared_error: 0.0296
# Epoch 98/200
# 3/3 [==============================] - ETA: 0s - loss: 9.9531e-04 - root_mean_squared_error: 0.0315
# Epoch 98: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 180ms/step - loss: 9.9531e-04 - root_mean_squared_error: 0.0315 - val_loss: 6.7961e-04 - val_root_mean_squared_error: 0.0261
# Epoch 99/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0332
# Epoch 99: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 2.2505e-04 - val_root_mean_squared_error: 0.0150
# Epoch 100/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0358
# Epoch 100: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 4.5206e-04 - val_root_mean_squared_error: 0.0213
# Epoch 101/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0401
# Epoch 101: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 171ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 7.8663e-04 - val_root_mean_squared_error: 0.0280
# Epoch 102/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 102: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0419
# Epoch 103/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0414
# Epoch 103: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 172ms/step - loss: 0.0017 - root_mean_squared_error: 0.0414 - val_loss: 7.7421e-04 - val_root_mean_squared_error: 0.0278
# Epoch 104/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0382
# Epoch 104: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 4.6798e-04 - val_root_mean_squared_error: 0.0216
# Epoch 105/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0338
# Epoch 105: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 184ms/step - loss: 0.0011 - root_mean_squared_error: 0.0338 - val_loss: 7.3425e-04 - val_root_mean_squared_error: 0.0271
# Epoch 106/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0424
# Epoch 106: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 2.8812e-04 - val_root_mean_squared_error: 0.0170
# Epoch 107/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0346
# Epoch 107: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 182ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 5.9184e-04 - val_root_mean_squared_error: 0.0243
# Epoch 108/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0333
# Epoch 108: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 9.9048e-04 - val_root_mean_squared_error: 0.0315
# Epoch 109/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0368
# Epoch 109: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0014 - root_mean_squared_error: 0.0368 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0355
# Epoch 110/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0022 - root_mean_squared_error: 0.0469
# Epoch 110: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0022 - root_mean_squared_error: 0.0469 - val_loss: 4.9373e-04 - val_root_mean_squared_error: 0.0222
# Epoch 111/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0413
# Epoch 111: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 6.1436e-04 - val_root_mean_squared_error: 0.0248
# Epoch 112/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0328
# Epoch 112: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 6.0400e-04 - val_root_mean_squared_error: 0.0246
# Epoch 113/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0360
# Epoch 113: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 183ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 4.9872e-04 - val_root_mean_squared_error: 0.0223
# Epoch 114/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 114: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 193ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 3.2524e-04 - val_root_mean_squared_error: 0.0180
# Epoch 115/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 115: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367 - val_loss: 5.3348e-04 - val_root_mean_squared_error: 0.0231
# Epoch 116/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0381
# Epoch 116: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0015 - root_mean_squared_error: 0.0381 - val_loss: 6.4130e-04 - val_root_mean_squared_error: 0.0253
# Epoch 117/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0358
# Epoch 117: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 7.3213e-04 - val_root_mean_squared_error: 0.0271
# Epoch 118/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0328
# Epoch 118: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 2.8131e-04 - val_root_mean_squared_error: 0.0168
# Epoch 119/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0377
# Epoch 119: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 4.7360e-04 - val_root_mean_squared_error: 0.0218
# Epoch 120/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0438
# Epoch 120: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0019 - root_mean_squared_error: 0.0438 - val_loss: 8.7331e-04 - val_root_mean_squared_error: 0.0296
# Epoch 121/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0375
# Epoch 121: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0014 - root_mean_squared_error: 0.0375 - val_loss: 4.2321e-04 - val_root_mean_squared_error: 0.0206
# Epoch 122/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0346
# Epoch 122: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 173ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 3.1308e-04 - val_root_mean_squared_error: 0.0177
# Epoch 123/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0400
# Epoch 123: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0016 - root_mean_squared_error: 0.0400 - val_loss: 3.6980e-04 - val_root_mean_squared_error: 0.0192
# Epoch 124/200
# 3/3 [==============================] - ETA: 0s - loss: 9.9589e-04 - root_mean_squared_error: 0.0316
# Epoch 124: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 182ms/step - loss: 9.9589e-04 - root_mean_squared_error: 0.0316 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 125/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0332
# Epoch 125: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 4.7430e-04 - val_root_mean_squared_error: 0.0218
# Epoch 126/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0407
# Epoch 126: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0017 - root_mean_squared_error: 0.0407 - val_loss: 4.3165e-04 - val_root_mean_squared_error: 0.0208
# Epoch 127/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0399
# Epoch 127: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 173ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 5.5539e-04 - val_root_mean_squared_error: 0.0236
# Epoch 128/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0396
# Epoch 128: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0398
# Epoch 129/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0022 - root_mean_squared_error: 0.0466
# Epoch 129: val_loss did not improve from 0.00017
# 3/3 [==============================] - 1s 184ms/step - loss: 0.0022 - root_mean_squared_error: 0.0466 - val_loss: 8.8911e-04 - val_root_mean_squared_error: 0.0298
# Epoch 130/200
# 3/3 [==============================] - ETA: 0s - loss: 9.3998e-04 - root_mean_squared_error: 0.0307
# Epoch 130: val_loss did not improve from 0.00017
# 3/3 [==============================] - 0s 177ms/step - loss: 9.3998e-04 - root_mean_squared_error: 0.0307 - val_loss: 2.3265e-04 - val_root_mean_squared_error: 0.0153
# Epoch 131/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0447
# Epoch 131: val_loss improved from 0.00017 to 0.00016, saving model to /content/sample_data/lstm-model-st.pete-24-0.4-1.h5
# 3/3 [==============================] - 1s 195ms/step - loss: 0.0020 - root_mean_squared_error: 0.0447 - val_loss: 1.5877e-04 - val_root_mean_squared_error: 0.0126
# Epoch 132/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0363
# Epoch 132: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0013 - root_mean_squared_error: 0.0363 - val_loss: 7.4683e-04 - val_root_mean_squared_error: 0.0273
# Epoch 133/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0376
# Epoch 133: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 173ms/step - loss: 0.0014 - root_mean_squared_error: 0.0376 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0366
# Epoch 134/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0343
# Epoch 134: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0317
# Epoch 135/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0353
# Epoch 135: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0012 - root_mean_squared_error: 0.0353 - val_loss: 2.4434e-04 - val_root_mean_squared_error: 0.0156
# Epoch 136/200
# 3/3 [==============================] - ETA: 0s - loss: 8.3397e-04 - root_mean_squared_error: 0.0289
# Epoch 136: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 186ms/step - loss: 8.3397e-04 - root_mean_squared_error: 0.0289 - val_loss: 2.1719e-04 - val_root_mean_squared_error: 0.0147
# Epoch 137/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0330
# Epoch 137: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0011 - root_mean_squared_error: 0.0330 - val_loss: 4.2561e-04 - val_root_mean_squared_error: 0.0206
# Epoch 138/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0407
# Epoch 138: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 183ms/step - loss: 0.0017 - root_mean_squared_error: 0.0407 - val_loss: 7.6444e-04 - val_root_mean_squared_error: 0.0276
# Epoch 139/200
# 3/3 [==============================] - ETA: 0s - loss: 8.9334e-04 - root_mean_squared_error: 0.0299
# Epoch 139: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 186ms/step - loss: 8.9334e-04 - root_mean_squared_error: 0.0299 - val_loss: 6.4699e-04 - val_root_mean_squared_error: 0.0254
# Epoch 140/200
# 3/3 [==============================] - ETA: 0s - loss: 9.5377e-04 - root_mean_squared_error: 0.0309
# Epoch 140: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 174ms/step - loss: 9.5377e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.4953e-04 - val_root_mean_squared_error: 0.0234
# Epoch 141/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0336
# Epoch 141: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 176ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 8.5168e-04 - val_root_mean_squared_error: 0.0292
# Epoch 142/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0355
# Epoch 142: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 6.2616e-04 - val_root_mean_squared_error: 0.0250
# Epoch 143/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0359
# Epoch 143: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0013 - root_mean_squared_error: 0.0359 - val_loss: 3.5640e-04 - val_root_mean_squared_error: 0.0189
# Epoch 144/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0347
# Epoch 144: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0012 - root_mean_squared_error: 0.0347 - val_loss: 6.0221e-04 - val_root_mean_squared_error: 0.0245
# Epoch 145/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0326
# Epoch 145: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 9.7040e-04 - val_root_mean_squared_error: 0.0312
# Epoch 146/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0342
# Epoch 146: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 6.5018e-04 - val_root_mean_squared_error: 0.0255
# Epoch 147/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0338
# Epoch 147: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0011 - root_mean_squared_error: 0.0338 - val_loss: 2.6822e-04 - val_root_mean_squared_error: 0.0164
# Epoch 148/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0318
# Epoch 148: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 184ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 3.5556e-04 - val_root_mean_squared_error: 0.0189
# Epoch 149/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0319
# Epoch 149: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 184ms/step - loss: 0.0010 - root_mean_squared_error: 0.0319 - val_loss: 7.7368e-04 - val_root_mean_squared_error: 0.0278
# Epoch 150/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0421
# Epoch 150: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0359
# Epoch 151/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0366
# Epoch 151: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 8.8772e-04 - val_root_mean_squared_error: 0.0298
# Epoch 152/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0328
# Epoch 152: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 184ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 2.8132e-04 - val_root_mean_squared_error: 0.0168
# Epoch 153/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0333
# Epoch 153: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 2.9532e-04 - val_root_mean_squared_error: 0.0172
# Epoch 154/200
# 3/3 [==============================] - ETA: 0s - loss: 8.6494e-04 - root_mean_squared_error: 0.0294
# Epoch 154: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 184ms/step - loss: 8.6494e-04 - root_mean_squared_error: 0.0294 - val_loss: 4.8040e-04 - val_root_mean_squared_error: 0.0219
# Epoch 155/200
# 3/3 [==============================] - ETA: 0s - loss: 7.9405e-04 - root_mean_squared_error: 0.0282
# Epoch 155: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 184ms/step - loss: 7.9405e-04 - root_mean_squared_error: 0.0282 - val_loss: 6.5887e-04 - val_root_mean_squared_error: 0.0257
# Epoch 156/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0335
# Epoch 156: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 181ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 4.5273e-04 - val_root_mean_squared_error: 0.0213
# Epoch 157/200
# 3/3 [==============================] - ETA: 0s - loss: 9.2358e-04 - root_mean_squared_error: 0.0304
# Epoch 157: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 178ms/step - loss: 9.2358e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.4131e-04 - val_root_mean_squared_error: 0.0210
# Epoch 158/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0349
# Epoch 158: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0012 - root_mean_squared_error: 0.0349 - val_loss: 2.8319e-04 - val_root_mean_squared_error: 0.0168
# Epoch 159/200
# 3/3 [==============================] - ETA: 0s - loss: 9.9527e-04 - root_mean_squared_error: 0.0315
# Epoch 159: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 176ms/step - loss: 9.9527e-04 - root_mean_squared_error: 0.0315 - val_loss: 5.4978e-04 - val_root_mean_squared_error: 0.0234
# Epoch 160/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0370
# Epoch 160: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0367
# Epoch 161/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0378
# Epoch 161: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0014 - root_mean_squared_error: 0.0378 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 162/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0349
# Epoch 162: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0012 - root_mean_squared_error: 0.0349 - val_loss: 2.2599e-04 - val_root_mean_squared_error: 0.0150
# Epoch 163/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0337
# Epoch 163: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 174ms/step - loss: 0.0011 - root_mean_squared_error: 0.0337 - val_loss: 3.1452e-04 - val_root_mean_squared_error: 0.0177
# Epoch 164/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0386
# Epoch 164: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 167ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - val_loss: 4.7476e-04 - val_root_mean_squared_error: 0.0218
# Epoch 165/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0366
# Epoch 165: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0360
# Epoch 166/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0355
# Epoch 166: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 185ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 5.7571e-04 - val_root_mean_squared_error: 0.0240
# Epoch 167/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 167: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 180ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 3.8567e-04 - val_root_mean_squared_error: 0.0196
# Epoch 168/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 168: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 175ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 2.9940e-04 - val_root_mean_squared_error: 0.0173
# Epoch 169/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0352
# Epoch 169: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 182ms/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# Epoch 170/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0341
# Epoch 170: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 173ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 8.5793e-04 - val_root_mean_squared_error: 0.0293
# Epoch 171/200
# 3/3 [==============================] - ETA: 0s - loss: 9.9507e-04 - root_mean_squared_error: 0.0315
# Epoch 171: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 183ms/step - loss: 9.9507e-04 - root_mean_squared_error: 0.0315 - val_loss: 3.1358e-04 - val_root_mean_squared_error: 0.0177
# Epoch 172/200
# 3/3 [==============================] - ETA: 0s - loss: 9.3954e-04 - root_mean_squared_error: 0.0307
# Epoch 172: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 175ms/step - loss: 9.3954e-04 - root_mean_squared_error: 0.0307 - val_loss: 3.2858e-04 - val_root_mean_squared_error: 0.0181
# Epoch 173/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0329
# Epoch 173: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 173ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 4.2138e-04 - val_root_mean_squared_error: 0.0205
# Epoch 174/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0349
# Epoch 174: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 178ms/step - loss: 0.0012 - root_mean_squared_error: 0.0349 - val_loss: 5.7946e-04 - val_root_mean_squared_error: 0.0241
# Epoch 175/200
# 3/3 [==============================] - ETA: 0s - loss: 7.0531e-04 - root_mean_squared_error: 0.0266
# Epoch 175: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 173ms/step - loss: 7.0531e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.2073e-04 - val_root_mean_squared_error: 0.0205
# Epoch 176/200
# 3/3 [==============================] - ETA: 0s - loss: 8.6522e-04 - root_mean_squared_error: 0.0294
# Epoch 176: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 181ms/step - loss: 8.6522e-04 - root_mean_squared_error: 0.0294 - val_loss: 3.3041e-04 - val_root_mean_squared_error: 0.0182
# Epoch 177/200
# 3/3 [==============================] - ETA: 0s - loss: 9.5784e-04 - root_mean_squared_error: 0.0309
# Epoch 177: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 186ms/step - loss: 9.5784e-04 - root_mean_squared_error: 0.0309 - val_loss: 7.7275e-04 - val_root_mean_squared_error: 0.0278
# Epoch 178/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0391
# Epoch 178: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 177ms/step - loss: 0.0015 - root_mean_squared_error: 0.0391 - val_loss: 4.6261e-04 - val_root_mean_squared_error: 0.0215
# Epoch 179/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0394
# Epoch 179: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 3.4843e-04 - val_root_mean_squared_error: 0.0187
# Epoch 180/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0350
# Epoch 180: val_loss did not improve from 0.00016
# 3/3 [==============================] - 0s 179ms/step - loss: 0.0012 - root_mean_squared_error: 0.0350 - val_loss: 9.9541e-04 - val_root_mean_squared_error: 0.0316
# Epoch 181/200
# 3/3 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0383
# Epoch 181: val_loss did not improve from 0.00016
# 3/3 [==============================] - 1s 182ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 181: early stopping

# %%
# Visualize loss

# Visualize training and validation loss.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training Loss VS Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
model = keras.models.load_model('/content/lstm-model-st.pete-24-1.h5')

# %%
# Model evaluation
test_predicted = model.predict(X_pred)

# %%
test_predicted
# Out:
# array([[0.17531219],
#        [0.17067975],
#        [0.16559586],
#        [0.16042817],
#        [0.15545595],
#        [0.1507828 ],
#        [0.14651692],
#        [0.14282086],
#        [0.13991994],
#        [0.13798165],
#        [0.13693044],
#        [0.13654913],
#        [0.13657257],
#        [0.13643444],
#        [0.1355775 ],
#        [0.13346139],
#        [0.12998334],
#        [0.12520283],
#        [0.11942362],
#        [0.1131153 ],
#        [0.10686171],
#        [0.10128058],
#        [0.09677786],
#        [0.09361032],
#        [0.09187451],
#        [0.09141094],
#        [0.09192013],
#        [0.0929762 ],
#        [0.09428416],
#        [0.0955893 ],
#        [0.09692411],
#        [0.09827273],
#        [0.09977301],
#        [0.10151041],
#        [0.10371961],
#        [0.10655538],
#        [0.11000774],
#        [0.11399961],
#        [0.11835282],
#        [0.1230029 ],
#        [0.1279229 ],
#        [0.13320944],
#        [0.13909847],
#        [0.1456666 ],
#        [0.15295412],
#        [0.16089204],
#        [0.1693832 ],
#        [0.17825812],
#        [0.18723059],
#        [0.19600505],
#        [0.20426768],
#        [0.21180978],
#        [0.21852148],
#        [0.22442904],
#        [0.22971329],
#        [0.2344895 ],
#        [0.23890632],
#        [0.24305403],
#        [0.2470088 ],
#        [0.2507832 ],
#        [0.2543656 ],
#        [0.25779733],
#        [0.2611397 ],
#        [0.26454666],
#        [0.26810056],
#        [0.27192116],
#        [0.2761219 ],
#        [0.28081068],
#        [0.28604397],
#        [0.29176652],
#        [0.29783285],
#        [0.30401862],
#        [0.31009445],
#        [0.3159094 ],
#        [0.32137224],
#        [0.32650477],
#        [0.33139926],
#        [0.33622605],
#        [0.3411485 ],
#        [0.34628052],
#        [0.3516643 ],
#        [0.35729584],
#        [0.3631525 ],
#        [0.3691833 ],
#        [0.37527472],
#        [0.38125908],
#        [0.3869571 ],
#        [0.39227283],
#        [0.39722565],
#        [0.40194303],
#        [0.40654576],
#        [0.41109544],
#        [0.41558427],
#        [0.41998297],
#        [0.4242364 ],
#        [0.42828083],
#        [0.4320895 ],
#        [0.4357106 ],
#        [0.43925208],
#        [0.44280487],
#        [0.44646388],
#        [0.4503026 ],
#        [0.45435387],
#        [0.4585593 ],
#        [0.46279874],
#        [0.46685076],
#        [0.4704463 ],
#        [0.47331983],
#        [0.47538188],
#        [0.47668976],
#        [0.4774394 ],
#        [0.4778058 ],
#        [0.47803038],
#        [0.4783373 ],
#        [0.47901642],
#        [0.4802655 ],
#        [0.48221615],
#        [0.48487958],
#        [0.4881543 ],
#        [0.491853  ],
#        [0.495705  ],
#        [0.49950218],
#        [0.5030868 ],
#        [0.5063491 ],
#        [0.5092089 ],
#        [0.5116224 ],
#        [0.5137042 ],
#        [0.51562047],
#        [0.5175869 ],
#        [0.51992685],
#        [0.5228681 ],
#        [0.5265667 ],
#        [0.531049  ],
#        [0.53642946],
#        [0.5427916 ],
#        [0.55039823],
#        [0.5596004 ],
#        [0.5707427 ],
#        [0.58406526],
#        [0.5996959 ],
#        [0.61753625],
#        [0.6371924 ]], dtype=float32)

# %%
# Apply inverse transformation
test_predicted= scaler.inverse_transform(test_predicted)
#Y_test = scaler.inverse_transform(Y_test)
#test_predicted = test_predicted.reshape(test_predicted.shape[0],test_predicted.shape[1])
#test_predicted.shape

# %%
#Y_test.shape
#test_predicted.shape
#test_predicted = test_predicted.reshape(test_predicted.shape[0])
test_predicted
# Out:
# array([[199.6017 ],
#        [198.32643],
#        [196.9269 ],
#        [195.50427],
#        [194.13547],
#        [192.849  ],
#        [191.67464],
#        [190.65717],
#        [189.85855],
#        [189.32497],
#        [189.03558],
#        [188.9306 ],
#        [188.93707],
#        [188.89903],
#        [188.66313],
#        [188.0806 ],
#        [187.12312],
#        [185.80708],
#        [184.21613],
#        [182.4795 ],
#        [180.75795],
#        [179.22153],
#        [177.98198],
#        [177.10999],
#        [176.63214],
#        [176.50452],
#        [176.64468],
#        [176.93542],
#        [177.29549],
#        [177.65477],
#        [178.02223],
#        [178.3935 ],
#        [178.80652],
#        [179.28479],
#        [179.89297],
#        [180.67363],
#        [181.62404],
#        [182.72295],
#        [183.92134],
#        [185.20146],
#        [186.5559 ],
#        [188.01123],
#        [189.63242],
#        [191.44055],
#        [193.44673],
#        [195.63197],
#        [197.96951],
#        [200.41267],
#        [202.8827 ],
#        [205.29823],
#        [207.57285],
#        [209.64912],
#        [211.49678],
#        [213.12308],
#        [214.57777],
#        [215.89261],
#        [217.10852],
#        [218.25034],
#        [219.33905],
#        [220.3781 ],
#        [221.3643 ],
#        [222.30904],
#        [223.22914],
#        [224.16705],
#        [225.1454 ],
#        [226.19717],
#        [227.35359],
#        [228.64438],
#        [230.08505],
#        [231.6604 ],
#        [233.3304 ],
#        [235.03328],
#        [236.7059 ],
#        [238.30669],
#        [239.81056],
#        [241.2235 ],
#        [242.57089],
#        [243.89966],
#        [245.25476],
#        [246.66756],
#        [248.14966],
#        [249.69998],
#        [251.31226],
#        [252.97247],
#        [254.64937],
#        [256.2968 ],
#        [257.86542],
#        [259.3288 ],
#        [260.69226],
#        [261.9909 ],
#        [263.25797],
#        [264.51047],
#        [265.7462 ],
#        [266.95712],
#        [268.12805],
#        [269.24142],
#        [270.28992],
#        [271.28677],
#        [272.2617 ],
#        [273.23975],
#        [274.24704],
#        [275.3038 ],
#        [276.41907],
#        [277.57678],
#        [278.74387],
#        [279.85934],
#        [280.84915],
#        [281.6402 ],
#        [282.2079 ],
#        [282.56793],
#        [282.7743 ],
#        [282.87515],
#        [282.93698],
#        [283.02148],
#        [283.20844],
#        [283.5523 ],
#        [284.0893 ],
#        [284.82248],
#        [285.724  ],
#        [286.74222],
#        [287.80264],
#        [288.84796],
#        [289.83478],
#        [290.73285],
#        [291.52014],
#        [292.18454],
#        [292.75763],
#        [293.2852 ],
#        [293.82648],
#        [294.47067],
#        [295.28036],
#        [296.29855],
#        [297.5325 ],
#        [299.01367],
#        [300.7651 ],
#        [302.85913],
#        [305.3924 ],
#        [308.45978],
#        [312.12732],
#        [316.4303 ],
#        [321.34155],
#        [326.7527 ]], dtype=float32)

# %%
# Re-populate Y_test
#X_test, Y_test = create_dmatrix(test_set, time_step)
#Y_test = Y_test.reshape(test_predicted.shape[0],1)
#Y_test = scaler.inverse_transform(Y_test)
#Y_test = Y_test.reshape(-1)
Y_test
# Out:
# array([321.58      , 324.19      , 326.8       , 329.41      ,
#        332.29      , 335.17      , 338.05      , 342.43666667,
#        346.82333333, 351.21      , 359.34666667, 367.48333333,
#        375.62      , 385.03      , 394.44      , 403.85      ,
#        411.44333333, 419.03666667])

# %%
# Reshape Y_test to 2D
Y_test = Y_test.reshape(test_predicted.shape[0],1)
Y_test = scaler.inverse_transform(Y_test)

# Reshape back to 1D
Y_test = Y_test.reshape(test_predicted.shape[0])
Y_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-32248f1e433d> in <module>()
#       1 # Reshape Y_test to 2D
# ----> 2 Y_test = Y_test.reshape(test_predicted.shape[0],1)
#       3 Y_test = scaler.inverse_transform(Y_test)
#       4
#       5 # Reshape back to 1D
#
# ValueError: cannot reshape array of size 18 into shape (118,1)

# %%
# Reshape Y_pred to 2D
Y_pred = Y_pred.reshape(test_predicted.shape[0],1)
Y_pred = scaler.inverse_transform(Y_pred)

# Reshape back to 1D
Y_pred = Y_pred.reshape(test_predicted.shape[0])
Y_pred
# Out:
# array([187.81333333, 187.16      , 184.77666667, 182.39333333,
#        180.01      , 180.64666667, 181.28333333, 181.92      ,
#        180.26333333, 178.60666667, 176.95      , 174.49333333,
#        172.03666667, 169.58      , 168.26      , 166.94      ,
#        165.62      , 166.28666667, 166.95333333, 167.62      ,
#        167.53333333, 167.44666667, 167.36      , 166.55      ,
#        165.74      , 164.93      , 164.61333333, 164.29666667,
#        163.98      , 165.57      , 167.16      , 168.75      ,
#        169.52      , 170.29      , 171.06      , 171.16333333,
#        171.26666667, 171.37      , 173.82      , 176.27      ,
#        178.72      , 180.66      , 182.6       , 184.54      ,
#        186.05666667, 187.57333333, 189.09      , 189.72333333,
#        190.35666667, 190.99      , 192.70666667, 194.42333333,
#        196.14      , 197.68      , 199.22      , 200.76      ,
#        201.48666667, 202.21333333, 202.94      , 204.28666667,
#        205.63333333, 206.98      , 209.05333333, 211.12666667,
#        213.2       , 215.17666667, 217.15333333, 219.13      ,
#        220.17333333, 221.21666667, 222.26      , 223.88666667,
#        225.51333333, 227.14      , 229.70333333, 232.26666667,
#        234.83      , 236.69      , 238.55      , 240.41      ,
#        242.51      , 244.61      , 246.71      , 248.11      ,
#        249.51      , 250.91      , 253.77      , 256.63      ,
#        259.49      , 261.06333333, 262.63666667, 264.21      ,
#        265.84      , 267.47      , 269.1       , 271.56      ,
#        274.02      , 276.48      , 278.81333333, 281.14666667,
#        283.48      , 285.11      , 286.74      , 288.37      ,
#        288.93      , 289.49      , 290.05      , 292.03333333,
#        294.01666667, 296.        , 297.66      , 299.32      ,
#        300.98      , 303.14333333, 305.30666667, 307.47      ,
#        308.89666667, 310.32333333, 311.75      , 313.56666667,
#        315.38333333, 317.2       , 318.66      , 320.12      ,
#        321.58      , 324.19      , 326.8       , 329.41      ,
#        332.29      , 335.17      , 338.05      , 342.43666667,
#        346.82333333, 351.21      , 359.34666667, 367.48333333,
#        375.62      , 385.03      , 394.44      , 403.85      ,
#        411.44333333, 419.03666667])

# %%
# Calculate RMSE
math.sqrt(mean_squared_error(Y_pred,test_predicted))
# Out:
# 24.950336344888946

# %%
print(test_predicted[141])
print(Y_pred[141])
# Out:
# [326.7527]
# 419.0366666666667

# %%
#test_predicted = test_predicted.reshape(-1, 1)
#test_predicted
test_predicted

# %%
from numpy import savetxt
np.savetxt('test_predicted.txt', test_predicted, fmt='%s')
files.download('test_predicted.txt')

# %%
files.download('test_predicted.txt')

# %%
training_predicted = model.predict(X_train)
validation_predicted = model.predict(X_val)

# %%
training_predicted = scaler.inverse_transform(training_predicted)
#training_predicted.shape
validation_predicted = scaler.inverse_transform(validation_predicted)
#validation_predicted.shape
print(scaler.inverse_transform(validation_set))
# Out:
# [[223.88666667]
#  [225.51333333]
#  [227.14      ]
#  [229.70333333]
#  [232.26666667]
#  [234.83      ]
#  [236.69      ]
#  [238.55      ]
#  [240.41      ]
#  [242.51      ]
#  [244.61      ]
#  [246.71      ]
#  [248.11      ]
#  [249.51      ]
#  [250.91      ]
#  [253.77      ]
#  [256.63      ]
#  [259.49      ]
#  [261.06333333]
#  [262.63666667]
#  [264.21      ]
#  [265.84      ]
#  [267.47      ]
#  [269.1       ]
#  [271.56      ]
#  [274.02      ]
#  [276.48      ]
#  [278.81333333]
#  [281.14666667]]

# %%
# Plotting everything together
# Setting the intervals 

# shift training predictions for plotting
training_predicted_plot = np.empty_like(df1)
training_predicted_plot[:, :] = np.nan
#training_predicted.shape
#training_predicted_plot[14:167, :] = training_predicted
training_predicted_plot[24:165, :] = training_predicted

#training_predicted_plot[24:143, :] = training_predicted
# shift validation predictions for plotting
val_predicted_plot = np.empty_like(df1)
val_predicted_plot[:, :] = np.nan
#validation_predicted.shape
#val_predicted_plot[181:214, :] = validation_predicted
#val_predicted_plot[192:203, :] = validation_predicted
#val_predicted_plot[168:191, :] = validation_predicted
val_predicted_plot[189:193, :] = validation_predicted
# shift test predictions for plotting
test_predicted_plot = np.empty_like(df1)
test_predicted_plot[:, :] = np.nan
#test_predicted.shape
#test_predicted_plot[230:239, :] = test_predicted
#test_predicted_plot[228:239, :] = test_predicted
#test_predicted_plot[216:239, :] = test_predicted
test_predicted_plot[220:239, :] = test_predicted

# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1), label = "Real Data")
plt.plot(test_predicted_plot, label = "Predicted Data for Test Set")
plt.plot(val_predicted_plot, label = "Predicted Data for Validation Set")
plt.plot(training_predicted_plot, label = "Predicted Data for Training Set")
plt.legend()
plt.show()

# %%
#math.sqrt(mean_squared_error(Y_test,test_predicted))
#print(scaler.inverse_transform(train_set))
#print(scaler.inverse_transform(training_predicted))
#train_set_invers = scaler.inverse_transform(Y_train)
#math.sqrt(mean_squared_error(_test,test_predicted))
#Y_train_sh = Y_train.reshape(training_predicted.shape[0],1)
#train_set_invers = scaler.inverse_transform(Y_train_sh)

#Y_train_d = Y_train.reshape(-1, 1)
#train_set_invers = scaler.inverse_transform(Y_train_d)
#math.sqrt(mean_squared_error(train_set_invers, training_predicted))
#print(scaler.inverse_transform(X_test))
#test_predicted
# Out:
# array([[237.0811 ],
#        [240.32011],
#        [243.95862],
#        [248.07315],
#        [252.65337],
#        [257.63763],
#        [262.94397],
#        [268.51364],
#        [274.28806]], dtype=float32)

# %%
# Create new array for future predictions

# Explanation. Since we have been predicting using timestep = 24, meaning we have used the past 24 prices to predict the 25th, now we will use the test_set data as that is the latest data to predict further INTO THE UNKNOWN!
# The size of the future_input array needs to be equal to timestep, so if you change the test_data size and timestep make sure to reflect those changes here as well.

pred_input=test_set[19:].reshape(1,-1)
pred_input
# Out:
# array([[0.58929371, 0.59589282, 0.60249192, 0.60779542, 0.61309891,
#         0.61840241, 0.62788332, 0.63736423, 0.64684515, 0.65730684,
#         0.66776853, 0.67823023, 0.69416494, 0.71009965, 0.72603436,
#         0.75559107, 0.78514778, 0.81470449, 0.84888663, 0.88306876,
#         0.9172509 , 0.94483393, 0.97241697, 1.        ]])

# %%
# Add that to temp input
temp_input = []
temp_input=list(pred_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.589293714507126,
#  0.5958928160606392,
#  0.6024919176141523,
#  0.6077954157433978,
#  0.6130989138726435,
#  0.618402412001889,
#  0.6278833230411567,
#  0.6373642340804244,
#  0.6468451451196922,
#  0.6573068400595736,
#  0.6677685349994553,
#  0.6782302299393368,
#  0.6941649412135082,
#  0.7100996524876797,
#  0.7260343637618512,
#  0.7555910736556601,
#  0.7851477835494691,
#  0.8147044934432781,
#  0.8488866286461552,
#  0.883068763849032,
#  0.917250899051909,
#  0.9448339327012727,
#  0.9724169663506366,
#  1.0000000000000002]

# %%
# Predict in the future

from numpy import array

list_output=[]
n_steps=24
i=0
while(i<12):
    
    if(len(temp_input)>24):
        print('Entering main condition')
        #print(temp_input)
        pred_input=np.array(temp_input[1:]) # Shift one to the right
        print("{} month input {}".format(i,pred_input))
        pred_input=pred_input.reshape(1,-1)
        pred_input = pred_input.reshape(1, n_steps, 1)
        print('Pred_input shape is:', pred_input.shape)
        fut_pred = model.predict(pred_input, verbose=0)
        print("{} month output {}".format(i,fut_pred))
        temp_input.extend(fut_pred[0].tolist()) # Add that prediction to the temp input list as that will be used in the next prediction 
        temp_input=temp_input[1:] #Shift the temp_input to remove the first element which was already used in a sequence
        #print(temp_input)
        list_output.extend(fut_pred.tolist())
        i=i+1
    else:
        print('Entering else condition')
        pred_input = pred_input.reshape((1, n_steps,1))
        fut_pred = model.predict(pred_input, verbose=0)
        print('The predicted value is:',fut_pred[0])
        temp_input.extend(fut_pred[0].tolist())
        print(len(temp_input))
        list_output.extend(fut_pred.tolist())
        i=i+1
    

print(list_output)
# Out:
# Entering else condition
# The predicted value is: [0.905854]
# 25
# Entering main condition
# 1 month input [0.59589282 0.60249192 0.60779542 0.61309891 0.61840241 0.62788332
#  0.63736423 0.64684515 0.65730684 0.66776853 0.67823023 0.69416494
#  0.71009965 0.72603436 0.75559107 0.78514778 0.81470449 0.84888663
#  0.88306876 0.9172509  0.94483393 0.97241697 1.         0.90585399]
# Pred_input shape is: (1, 24, 1)
# 1 month output [[0.8948424]]
# Entering main condition
# 2 month input [0.60249192 0.60779542 0.61309891 0.61840241 0.62788332 0.63736423
#  0.64684515 0.65730684 0.66776853 0.67823023 0.69416494 0.71009965
#  0.72603436 0.75559107 0.78514778 0.81470449 0.84888663 0.88306876
#  0.9172509  0.94483393 0.97241697 1.         0.90585399 0.89484239]
# Pred_input shape is: (1, 24, 1)
# 2 month output [[0.8619143]]
# Entering main condition
# 3 month input [0.60779542 0.61309891 0.61840241 0.62788332 0.63736423 0.64684515
#  0.65730684 0.66776853 0.67823023 0.69416494 0.71009965 0.72603436
#  0.75559107 0.78514778 0.81470449 0.84888663 0.88306876 0.9172509
#  0.94483393 0.97241697 1.         0.90585399 0.89484239 0.86191428]
# Pred_input shape is: (1, 24, 1)
# 3 month output [[0.8180777]]
# Entering main condition
# 4 month input [0.61309891 0.61840241 0.62788332 0.63736423 0.64684515 0.65730684
#  0.66776853 0.67823023 0.69416494 0.71009965 0.72603436 0.75559107
#  0.78514778 0.81470449 0.84888663 0.88306876 0.9172509  0.94483393
#  0.97241697 1.         0.90585399 0.89484239 0.86191428 0.81807768]
# Pred_input shape is: (1, 24, 1)
# 4 month output [[0.7684288]]
# Entering main condition
# 5 month input [0.61840241 0.62788332 0.63736423 0.64684515 0.65730684 0.66776853
#  0.67823023 0.69416494 0.71009965 0.72603436 0.75559107 0.78514778
#  0.81470449 0.84888663 0.88306876 0.9172509  0.94483393 0.97241697
#  1.         0.90585399 0.89484239 0.86191428 0.81807768 0.7684288 ]
# Pred_input shape is: (1, 24, 1)
# 5 month output [[0.7145884]]
# Entering main condition
# 6 month input [0.62788332 0.63736423 0.64684515 0.65730684 0.66776853 0.67823023
#  0.69416494 0.71009965 0.72603436 0.75559107 0.78514778 0.81470449
#  0.84888663 0.88306876 0.9172509  0.94483393 0.97241697 1.
#  0.90585399 0.89484239 0.86191428 0.81807768 0.7684288  0.7145884 ]
# Pred_input shape is: (1, 24, 1)
# 6 month output [[0.6572262]]
# Entering main condition
# 7 month input [0.63736423 0.64684515 0.65730684 0.66776853 0.67823023 0.69416494
#  0.71009965 0.72603436 0.75559107 0.78514778 0.81470449 0.84888663
#  0.88306876 0.9172509  0.94483393 0.97241697 1.         0.90585399
#  0.89484239 0.86191428 0.81807768 0.7684288  0.7145884  0.6572262 ]
# Pred_input shape is: (1, 24, 1)
# 7 month output [[0.5969274]]
# Entering main condition
# 8 month input [0.64684515 0.65730684 0.66776853 0.67823023 0.69416494 0.71009965
#  0.72603436 0.75559107 0.78514778 0.81470449 0.84888663 0.88306876
#  0.9172509  0.94483393 0.97241697 1.         0.90585399 0.89484239
#  0.86191428 0.81807768 0.7684288  0.7145884  0.6572262  0.5969274 ]
# Pred_input shape is: (1, 24, 1)
# 8 month output [[0.5343931]]
# Entering main condition
# 9 month input [0.65730684 0.66776853 0.67823023 0.69416494 0.71009965 0.72603436
#  0.75559107 0.78514778 0.81470449 0.84888663 0.88306876 0.9172509
#  0.94483393 0.97241697 1.         0.90585399 0.89484239 0.86191428
#  0.81807768 0.7684288  0.7145884  0.6572262  0.5969274  0.53439307]
# Pred_input shape is: (1, 24, 1)
# 9 month output [[0.47030303]]
# Entering main condition
# 10 month input [0.66776853 0.67823023 0.69416494 0.71009965 0.72603436 0.75559107
#  0.78514778 0.81470449 0.84888663 0.88306876 0.9172509  0.94483393
#  0.97241697 1.         0.90585399 0.89484239 0.86191428 0.81807768
#  0.7684288  0.7145884  0.6572262  0.5969274  0.53439307 0.47030303]
# Pred_input shape is: (1, 24, 1)
# 10 month output [[0.40522498]]
# Entering main condition
# 11 month input [0.67823023 0.69416494 0.71009965 0.72603436 0.75559107 0.78514778
#  0.81470449 0.84888663 0.88306876 0.9172509  0.94483393 0.97241697
#  1.         0.90585399 0.89484239 0.86191428 0.81807768 0.7684288
#  0.7145884  0.6572262  0.5969274  0.53439307 0.47030303 0.40522498]
# Pred_input shape is: (1, 24, 1)
# 11 month output [[0.33958644]]
# [[0.9058539867401123], [0.8948423862457275], [0.8619142770767212], [0.8180776834487915], [0.7684288024902344], [0.7145884037017822], [0.6572262048721313], [0.5969274044036865], [0.5343930721282959], [0.4703030288219452], [0.4052249789237976], [0.33958643674850464]]

# %%
month_new = np.arange(1, 24)
month_pred = np.arange(24,36)

# %%
plt.plot(month_new,scaler.inverse_transform(df1[215:]))
plt.plot(month_pred,scaler.inverse_transform(list_output))

# %%
df3 = df1.tolist()
df3.extend(list_output)
plt.plot(df3[238:])

# %%
print(scaler.inverse_transform(list_output))
# Out:
# [[400.71254401]
#  [397.68116051]
#  [388.61638134]
#  [376.54860548]
#  [362.88076504]
#  [348.05904166]
#  [332.26780194]
#  [315.66814516]
#  [298.45306883]
#  [280.8097208 ]
#  [262.89438445]
#  [244.82475017]]

# %%
df3=scaler.inverse_transform(df3).tolist()
plt.plot(df3)

# %%
# Make copy of original data
df_orig33 = pd.read_csv('/content/Model_Tampa_Prediction_6months.csv')
df_orig33
# Out:
#            DATE      TPXRSA
# 0    2002-01-01  120.395793
# 1    2002-02-01  120.700034
# 2    2002-03-01  122.958147
# 3    2002-04-01  123.707047
# 4    2002-05-01  124.950321
# ..          ...         ...
# 241  2022-02-01  295.493895
# 242  2022-03-01  285.777483
# 243  2022-04-01  272.348633
# 244  2022-05-01  257.288102
# 245  2022-06-01  241.530343
#
# [246 rows x 2 columns]

# %%
output1_df = pd.DataFrame(df3, columns=['Sale Price'])
output1_df
# Out:
#      Sale Price
# 0    151.340000
# 1    152.713333
# 2    154.086667
# 3    155.460000
# 4    156.823333
# ..          ...
# 245  315.668145
# 246  298.453069
# 247  280.809721
# 248  262.894384
# 249  244.824750
#
# [250 rows x 1 columns]

# %%
test_df = df_orig.copy()
test_df['TXP'] = output1_df

# %%
result = [output1_df, df_orig]
new_df = pd.concat(result, axis =1)

# %%
new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
new_df
# Out:
#      Sale Price        DATE
# 0    120.395793  2002-01-01
# 1    120.700034  2002-02-01
# 2    122.958147  2002-03-01
# 3    123.707047  2002-04-01
# 4    124.950321  2002-05-01
# ..          ...         ...
# 241  295.493895         NaN
# 242  285.777483         NaN
# 243  272.348633         NaN
# 244  257.288102         NaN
# 245  241.530343         NaN
#
# [246 rows x 2 columns]

# %%
#new_df['DATE'] = pd.to_datetime(new_df['DATE'])
#new_df = new_df.set_index('DATE')
#new_df.index = new_df.index.to_period("1M")

# %%
#new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
#new_date_range = pd.date_range(start="2002-01", end='2023-01', freq="M")
#new_date_range = pd.Series(pd.date_range("1/1/2002", freq="M", periods=len(df3)))
#new_df = new_df.reindex(new_date_range, fill_value=0)

# %%
#new_df['Sale Price'] = output1_df['Sale Price']

#new_df = new_df.append(output1_df, ignore_index = True)

# %%
#df_orig1 = df_orig.copy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-a5f9668e6f2b> in <module>()
#       1 df_orig1 = df_orig.copy()
# ----> 2 df_orig1 = pd.concat(output1_df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     328         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     329             raise TypeError(
# --> 330                 "first argument must be an iterable of pandas "
#     331                 f'objects, you passed an object of type "{type(objs).__name__}"'
#     332             )
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
result1 = [new_df, output_df]
new_df = pd.concat(result1, axis =1)

# %%
df.to_csv('Model_Prediction_StPete_12months.csv')
files.download('Model_Prediction_StPete_12months.csv')
