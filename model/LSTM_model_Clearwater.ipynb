# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive, files # google colab specific
import requests
import pandas as pd
import os
import warnings
import sys
import matplotlib.pyplot as plt
import json
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from tensorflow import keras
from keras import layers
import math
from sklearn.metrics import mean_squared_error

# %%
# Read in the csv file that contains the time series data of the Shiller Index
# Create the dataframe

# Quarterly Data

#df = pd.read_csv('/content/ATNHPIUS45300Q (1).csv')
#df.head()
# Out:
#          DATE  ATNHPIUS45300Q
# 0  2002-01-01          151.34
# 1  2002-04-01          155.46
# 2  2002-07-01          159.55
# 3  2002-10-01          162.39
# 4  2003-01-01          165.24

# %%
filePath = "/content/ATNHPIUS45300Q (1).csv"
df = pd.read_csv(filePath, header = 0)
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.set_index('DATE')
df.index = df.index.to_period("1M")
df = df.resample('1M').interpolate()

# %%
# Out:
#          ATNHPIUS45300Q
# DATE
# 2002-01      151.340000
# 2002-02      152.713333
# 2002-03      154.086667
# 2002-04      155.460000
# 2002-05      156.823333
# ...                 ...
# 2021-06      394.440000
# 2021-07      403.850000
# 2021-08      411.443333
# 2021-09      419.036667
# 2021-10      426.630000
#
# [238 rows x 1 columns]

# %%
# Reset the index based on the prices
df1 = df.reset_index()['ATNHPIUS45300Q']
df1
# Out:
# 0      151.340000
# 1      152.713333
# 2      154.086667
# 3      155.460000
# 4      156.823333
#           ...
# 233    394.440000
# 234    403.850000
# 235    411.443333
# 236    419.036667
# 237    426.630000
# Name: ATNHPIUS45300Q, Length: 238, dtype: float64

# %%
# Visualize the data for reference. 
plt.plot(df1)

# %%
# Normalize the data with the range 0 - 1
scaler = MinMaxScaler(feature_range=(0,1))

# Apply the scaler to the dataframe
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# Print df1 to check the change
print(df1)
# Out:
# [[0.        ]
#  [0.00498868]
#  [0.00997736]
#  [0.01496604]
#  [0.01991839]
#  [0.02487074]
#  [0.0298231 ]
#  [0.03326189]
#  [0.03670069]
#  [0.04013949]
#  [0.0435904 ]
#  [0.0470413 ]
#  [0.05049221]
#  [0.05394311]
#  [0.05739402]
#  [0.06084493]
#  [0.06597891]
#  [0.07111289]
#  [0.07624687]
#  [0.08473489]
#  [0.0932229 ]
#  [0.10171092]
#  [0.10777725]
#  [0.11384358]
#  [0.11990991]
#  [0.12975408]
#  [0.13959824]
#  [0.14944241]
#  [0.16238633]
#  [0.17533026]
#  [0.18827418]
#  [0.19821522]
#  [0.20815625]
#  [0.21809728]
#  [0.22946711]
#  [0.24083694]
#  [0.25220676]
#  [0.2700425 ]
#  [0.28787824]
#  [0.30571397]
#  [0.32385242]
#  [0.34199087]
#  [0.36012932]
#  [0.37928488]
#  [0.39844043]
#  [0.41759599]
#  [0.43158124]
#  [0.44556649]
#  [0.45955175]
#  [0.46805187]
#  [0.476552  ]
#  [0.48505213]
#  [0.48846671]
#  [0.49188129]
#  [0.49529587]
#  [0.4982019 ]
#  [0.50110792]
#  [0.50401395]
#  [0.50176178]
#  [0.49950961]
#  [0.49725744]
#  [0.49291051]
#  [0.48856358]
#  [0.48421664]
#  [0.47104266]
#  [0.45786867]
#  [0.44469469]
#  [0.43815613]
#  [0.43161757]
#  [0.42507901]
#  [0.41123906]
#  [0.39739911]
#  [0.38355916]
#  [0.36262366]
#  [0.34168816]
#  [0.32075266]
#  [0.30097957]
#  [0.28120649]
#  [0.2614334 ]
#  [0.24892538]
#  [0.23641735]
#  [0.22390933]
#  [0.22656108]
#  [0.22921283]
#  [0.23186458]
#  [0.21818204]
#  [0.2044995 ]
#  [0.19081696]
#  [0.17896279]
#  [0.16710862]
#  [0.15525446]
#  [0.14924867]
#  [0.14324288]
#  [0.1372371 ]
#  [0.13486384]
#  [0.13249059]
#  [0.13011733]
#  [0.12145979]
#  [0.11280226]
#  [0.10414472]
#  [0.10645743]
#  [0.10877015]
#  [0.11108286]
#  [0.10506496]
#  [0.09904707]
#  [0.09302917]
#  [0.08410525]
#  [0.07518132]
#  [0.0662574 ]
#  [0.06146246]
#  [0.05666751]
#  [0.05187257]
#  [0.05429426]
#  [0.05671595]
#  [0.05913764]
#  [0.05882282]
#  [0.058508  ]
#  [0.05819318]
#  [0.05525083]
#  [0.05230847]
#  [0.04936612]
#  [0.04821582]
#  [0.04706552]
#  [0.04591522]
#  [0.05169094]
#  [0.05746667]
#  [0.0632424 ]
#  [0.06603945]
#  [0.0688365 ]
#  [0.07163355]
#  [0.07200891]
#  [0.07238427]
#  [0.07275964]
#  [0.08165934]
#  [0.09055905]
#  [0.09945875]
#  [0.10650587]
#  [0.11355298]
#  [0.12060009]
#  [0.12610944]
#  [0.13161878]
#  [0.13712812]
#  [0.13942872]
#  [0.14172933]
#  [0.14402993]
#  [0.15026578]
#  [0.15650163]
#  [0.16273748]
#  [0.16833158]
#  [0.17392568]
#  [0.17951978]
#  [0.18215942]
#  [0.18479906]
#  [0.1874387 ]
#  [0.19233051]
#  [0.19722232]
#  [0.20211413]
#  [0.20964559]
#  [0.21717704]
#  [0.22470849]
#  [0.2318888 ]
#  [0.2390691 ]
#  [0.24624941]
#  [0.25003935]
#  [0.2538293 ]
#  [0.25761924]
#  [0.26352816]
#  [0.26943708]
#  [0.275346  ]
#  [0.28465739]
#  [0.29396878]
#  [0.30328018]
#  [0.31003669]
#  [0.3167932 ]
#  [0.32354971]
#  [0.33117803]
#  [0.33880635]
#  [0.34643467]
#  [0.35152022]
#  [0.35660576]
#  [0.36169131]
#  [0.37208035]
#  [0.3824694 ]
#  [0.39285844]
#  [0.39857363]
#  [0.40428881]
#  [0.410004  ]
#  [0.41592502]
#  [0.42184605]
#  [0.42776708]
#  [0.43670311]
#  [0.44563914]
#  [0.45457518]
#  [0.46305109]
#  [0.471527  ]
#  [0.48000291]
#  [0.48592393]
#  [0.49184496]
#  [0.49776599]
#  [0.49980021]
#  [0.50183443]
#  [0.50386865]
#  [0.51107317]
#  [0.5182777 ]
#  [0.52548222]
#  [0.53151222]
#  [0.53754223]
#  [0.54357223]
#  [0.55143061]
#  [0.55928899]
#  [0.56714737]
#  [0.57232979]
#  [0.5775122 ]
#  [0.58269461]
#  [0.58929371]
#  [0.59589282]
#  [0.60249192]
#  [0.60779542]
#  [0.61309891]
#  [0.61840241]
#  [0.62788332]
#  [0.63736423]
#  [0.64684515]
#  [0.65730684]
#  [0.66776853]
#  [0.67823023]
#  [0.69416494]
#  [0.71009965]
#  [0.72603436]
#  [0.75559107]
#  [0.78514778]
#  [0.81470449]
#  [0.84888663]
#  [0.88306876]
#  [0.9172509 ]
#  [0.94483393]
#  [0.97241697]
#  [1.        ]]

# %%
# Split data into train, validation and test set. Ratio: 6/1/3
training_size = int(len(df1)*0.7)
validation_size = int(len(df1)*0.82) 
test_size = int(len(df1))

train_set = df1[0:training_size,:]
validation_set = df1[training_size:validation_size,:]
test_set = df1[validation_size:test_size,:1]

# %%
df1.shape
# Out:
# (238, 1)

# %%
# Check sizes and set sizes
#training_size
#validation_size 
#test_size
print(train_set.shape)
print(validation_set.shape)
print(test_set.shape)
# Out:
# (166, 1)
# (29, 1)
# (43, 1)

# %%
# The current array of values needs to be converted into a dataset matrix
def create_dmatrix(dataset, time_step=1):
  data_X, data_Y = [], []
  for i in range(len(dataset)-time_step-1):
    k = dataset[i:(i + time_step), 0]
    data_X.append(k)
    data_Y.append(dataset[i + time_step, 0])
  return np.array(data_X), np.array(data_Y)

# %%
# Using the function already created for the conversion, convert training, validation and test sets. 
time_step = 24
X_train, Y_train = create_dmatrix(train_set, time_step)
X_val, Y_val = create_dmatrix(validation_set, time_step)
X_test, Y_test = create_dmatrix(test_set, time_step)

print('X Train set shape:', X_train.shape)
print('y Train set shape:', Y_train.shape)

print('X Validation set shape:', X_val.shape)
print('y Validation set shape:', Y_val.shape)

print('X Test set shape:', X_test.shape)
print('y Test set shape:', Y_test.shape)
# Out:
# X Train set shape: (141, 24)
# y Train set shape: (141,)
# X Validation set shape: (4, 24)
# y Validation set shape: (4,)
# X Test set shape: (18, 24)
# y Test set shape: (18,)

# %%
# Check the matrixes created
X_test

# %%
# In order to feed the dataset to the neural network the data must be in 3D

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Hyperparameters
batch_size = 16
epochs = 200
learning_rate = 0.001

# %%
# LSTM MODEL ARCHITECTURE

model = keras.models.Sequential([
  keras.Input(shape=(24, 1)),
  # Masking layer, to ignore zeros.
  # keras.layers.Masking(),
  # 4 LSTM Layers with 16 units.
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250),
  keras.layers.Dropout(0.5),
  # Fully Connected Layer
  keras.layers.Dense(units=1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 250)           252000
#
#  lstm_1 (LSTM)               (None, 24, 250)           501000
#
#  lstm_2 (LSTM)               (None, 24, 250)           501000
#
#  lstm_3 (LSTM)               (None, 250)               501000
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense (Dense)               (None, 1)                 251
#
# =================================================================
# Total params: 1,755,251
# Trainable params: 1,755,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Loss and Optimizer Functions
mse = tf.keras.losses.MeanSquaredError()
rmse = tf.keras.metrics.RootMeanSquaredError()
model.compile(loss=mse, optimizer=keras.optimizers.Adam(learning_rate=learning_rate), metrics=[rmse])

# %%
# Callbacks.

callbacks = [EarlyStopping(monitor='val_loss', patience=100, verbose=1), 
            ModelCheckpoint(filepath='/content/sample_data/lstm-model-clearwater-24-1.h5', verbose=1, monitor='val_loss', save_best_only=True, save_weights_only=False)]

# Train the model
history = model.fit(x=X_train, y=Y_train, validation_data =(X_val, Y_val), epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=callbacks)
# Out:
# Epoch 1/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0287 - root_mean_squared_error: 0.1696
# Epoch 1: val_loss improved from inf to 0.01921, saving model to /content/sample_data/lstm-model-clearwater-24-1.h5
# 9/9 [==============================] - 12s 514ms/step - loss: 0.0287 - root_mean_squared_error: 0.1696 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1386
# Epoch 2/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0106 - root_mean_squared_error: 0.1032
# Epoch 2: val_loss did not improve from 0.01921
# 9/9 [==============================] - 2s 270ms/step - loss: 0.0106 - root_mean_squared_error: 0.1032 - val_loss: 0.0465 - val_root_mean_squared_error: 0.2156
# Epoch 3/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0108 - root_mean_squared_error: 0.1040
# Epoch 3: val_loss did not improve from 0.01921
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2036
# Epoch 4/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0919
# Epoch 4: val_loss did not improve from 0.01921
# 9/9 [==============================] - 2s 270ms/step - loss: 0.0084 - root_mean_squared_error: 0.0919 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1892
# Epoch 5/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0062 - root_mean_squared_error: 0.0786
# Epoch 5: val_loss improved from 0.01921 to 0.00765, saving model to /content/sample_data/lstm-model-clearwater-24-1.h5
# 9/9 [==============================] - 2s 278ms/step - loss: 0.0062 - root_mean_squared_error: 0.0786 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 6/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0519
# Epoch 6: val_loss improved from 0.00765 to 0.00173, saving model to /content/sample_data/lstm-model-clearwater-24-1.h5
# 9/9 [==============================] - 3s 382ms/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0415
# Epoch 7/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0447
# Epoch 7: val_loss did not improve from 0.00173
# 9/9 [==============================] - 3s 313ms/step - loss: 0.0020 - root_mean_squared_error: 0.0447 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0603
# Epoch 8/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0412
# Epoch 8: val_loss did not improve from 0.00173
# 9/9 [==============================] - 2s 271ms/step - loss: 0.0017 - root_mean_squared_error: 0.0412 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0465
# Epoch 9/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0377
# Epoch 9: val_loss improved from 0.00173 to 0.00002, saving model to /content/sample_data/lstm-model-clearwater-24-1.h5
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 1.7787e-05 - val_root_mean_squared_error: 0.0042
# Epoch 10/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0402
# Epoch 10: val_loss did not improve from 0.00002
# 9/9 [==============================] - 2s 270ms/step - loss: 0.0016 - root_mean_squared_error: 0.0402 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 11/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 11: val_loss did not improve from 0.00002
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 12/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0022 - root_mean_squared_error: 0.0474
# Epoch 12: val_loss did not improve from 0.00002
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0022 - root_mean_squared_error: 0.0474 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0495
# Epoch 13/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0374
# Epoch 13: val_loss improved from 0.00002 to 0.00001, saving model to /content/sample_data/lstm-model-clearwater-24-1.h5
# 9/9 [==============================] - 3s 304ms/step - loss: 0.0014 - root_mean_squared_error: 0.0374 - val_loss: 1.3594e-05 - val_root_mean_squared_error: 0.0037
# Epoch 14/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0330
# Epoch 14: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 286ms/step - loss: 0.0011 - root_mean_squared_error: 0.0330 - val_loss: 2.3923e-04 - val_root_mean_squared_error: 0.0155
# Epoch 15/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0425
# Epoch 15: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# Epoch 16/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0030 - root_mean_squared_error: 0.0549
# Epoch 16: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 282ms/step - loss: 0.0030 - root_mean_squared_error: 0.0549 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0764
# Epoch 17/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0383
# Epoch 17: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 305ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 18/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0397
# Epoch 18: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 286ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0525
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0398
# Epoch 19: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 277ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0359
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0335
# Epoch 20: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 296ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 1.9263e-04 - val_root_mean_squared_error: 0.0139
# Epoch 21/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0361
# Epoch 21: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 294ms/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 4.2228e-04 - val_root_mean_squared_error: 0.0205
# Epoch 22/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0382
# Epoch 22: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 296ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 23/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0399
# Epoch 23: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 273ms/step - loss: 0.0016 - root_mean_squared_error: 0.0399 - val_loss: 9.9389e-04 - val_root_mean_squared_error: 0.0315
# Epoch 24/200
# 9/9 [==============================] - ETA: 0s - loss: 9.1592e-04 - root_mean_squared_error: 0.0303
# Epoch 24: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 9.1592e-04 - root_mean_squared_error: 0.0303 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0384
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 6.8010e-04 - root_mean_squared_error: 0.0261
# Epoch 25: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 273ms/step - loss: 6.8010e-04 - root_mean_squared_error: 0.0261 - val_loss: 6.5951e-04 - val_root_mean_squared_error: 0.0257
# Epoch 26/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0324
# Epoch 26: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 279ms/step - loss: 0.0010 - root_mean_squared_error: 0.0324 - val_loss: 3.5975e-05 - val_root_mean_squared_error: 0.0060
# Epoch 27/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0376
# Epoch 27: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0014 - root_mean_squared_error: 0.0376 - val_loss: 6.8710e-04 - val_root_mean_squared_error: 0.0262
# Epoch 28/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 28: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 274ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 6.0641e-04 - val_root_mean_squared_error: 0.0246
# Epoch 29/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0352
# Epoch 29: val_loss improved from 0.00001 to 0.00001, saving model to /content/sample_data/lstm-model-clearwater-24-1.h5
# 9/9 [==============================] - 3s 287ms/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 1.1715e-05 - val_root_mean_squared_error: 0.0034
# Epoch 30/200
# 9/9 [==============================] - ETA: 0s - loss: 9.2735e-04 - root_mean_squared_error: 0.0305
# Epoch 30: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 334ms/step - loss: 9.2735e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.5556e-04 - val_root_mean_squared_error: 0.0236
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 31: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 264ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 3.2329e-04 - val_root_mean_squared_error: 0.0180
# Epoch 32/200
# 9/9 [==============================] - ETA: 0s - loss: 9.0238e-04 - root_mean_squared_error: 0.0300
# Epoch 32: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 274ms/step - loss: 9.0238e-04 - root_mean_squared_error: 0.0300 - val_loss: 4.4631e-05 - val_root_mean_squared_error: 0.0067
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0351
# Epoch 33: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 272ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 2.4294e-04 - val_root_mean_squared_error: 0.0156
# Epoch 34/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0333
# Epoch 34: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 2.6138e-05 - val_root_mean_squared_error: 0.0051
# Epoch 35/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0323
# Epoch 35: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0010 - root_mean_squared_error: 0.0323 - val_loss: 2.6232e-04 - val_root_mean_squared_error: 0.0162
# Epoch 36/200
# 9/9 [==============================] - ETA: 0s - loss: 7.7420e-04 - root_mean_squared_error: 0.0278
# Epoch 36: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 7.7420e-04 - root_mean_squared_error: 0.0278 - val_loss: 7.1837e-04 - val_root_mean_squared_error: 0.0268
# Epoch 37/200
# 9/9 [==============================] - ETA: 0s - loss: 7.1966e-04 - root_mean_squared_error: 0.0268
# Epoch 37: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 7.1966e-04 - root_mean_squared_error: 0.0268 - val_loss: 2.1034e-04 - val_root_mean_squared_error: 0.0145
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0377
# Epoch 38: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 39/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0020 - root_mean_squared_error: 0.0444
# Epoch 39: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0020 - root_mean_squared_error: 0.0444 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0495
# Epoch 40/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0395
# Epoch 40: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0742
# Epoch 41/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0379
# Epoch 41: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 273ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0561
# Epoch 42/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0328
# Epoch 42: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 1.3236e-05 - val_root_mean_squared_error: 0.0036
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0331
# Epoch 43: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 262ms/step - loss: 0.0011 - root_mean_squared_error: 0.0331 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 44/200
# 9/9 [==============================] - ETA: 0s - loss: 8.6494e-04 - root_mean_squared_error: 0.0294
# Epoch 44: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 263ms/step - loss: 8.6494e-04 - root_mean_squared_error: 0.0294 - val_loss: 6.9455e-04 - val_root_mean_squared_error: 0.0264
# Epoch 45/200
# 9/9 [==============================] - ETA: 0s - loss: 7.6574e-04 - root_mean_squared_error: 0.0277
# Epoch 45: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 262ms/step - loss: 7.6574e-04 - root_mean_squared_error: 0.0277 - val_loss: 1.2708e-05 - val_root_mean_squared_error: 0.0036
# Epoch 46/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0369
# Epoch 46: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 260ms/step - loss: 0.0014 - root_mean_squared_error: 0.0369 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0512
# Epoch 47/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 47: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 48/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 48: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412
# Epoch 49/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0350
# Epoch 49: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 0.0012 - root_mean_squared_error: 0.0350 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0495
# Epoch 50/200
# 9/9 [==============================] - ETA: 0s - loss: 8.3944e-04 - root_mean_squared_error: 0.0290
# Epoch 50: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 259ms/step - loss: 8.3944e-04 - root_mean_squared_error: 0.0290 - val_loss: 4.3184e-04 - val_root_mean_squared_error: 0.0208
# Epoch 51/200
# 9/9 [==============================] - ETA: 0s - loss: 8.5690e-04 - root_mean_squared_error: 0.0293
# Epoch 51: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 272ms/step - loss: 8.5690e-04 - root_mean_squared_error: 0.0293 - val_loss: 1.5023e-04 - val_root_mean_squared_error: 0.0123
# Epoch 52/200
# 9/9 [==============================] - ETA: 0s - loss: 8.2761e-04 - root_mean_squared_error: 0.0288
# Epoch 52: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 8.2761e-04 - root_mean_squared_error: 0.0288 - val_loss: 4.4653e-05 - val_root_mean_squared_error: 0.0067
# Epoch 53/200
# 9/9 [==============================] - ETA: 0s - loss: 6.5318e-04 - root_mean_squared_error: 0.0256
# Epoch 53: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 262ms/step - loss: 6.5318e-04 - root_mean_squared_error: 0.0256 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0423
# Epoch 54/200
# 9/9 [==============================] - ETA: 0s - loss: 7.9242e-04 - root_mean_squared_error: 0.0281
# Epoch 54: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 7.9242e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.5990e-04 - val_root_mean_squared_error: 0.0214
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 9.3881e-04 - root_mean_squared_error: 0.0306
# Epoch 55: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 9.3881e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.2132e-04 - val_root_mean_squared_error: 0.0205
# Epoch 56/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 56: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 1.8256e-04 - val_root_mean_squared_error: 0.0135
# Epoch 57/200
# 9/9 [==============================] - ETA: 0s - loss: 9.7261e-04 - root_mean_squared_error: 0.0312
# Epoch 57: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 9.7261e-04 - root_mean_squared_error: 0.0312 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 58/200
# 9/9 [==============================] - ETA: 0s - loss: 5.8141e-04 - root_mean_squared_error: 0.0241
# Epoch 58: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 5.8141e-04 - root_mean_squared_error: 0.0241 - val_loss: 3.3864e-04 - val_root_mean_squared_error: 0.0184
# Epoch 59/200
# 9/9 [==============================] - ETA: 0s - loss: 8.8055e-04 - root_mean_squared_error: 0.0297
# Epoch 59: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 8.8055e-04 - root_mean_squared_error: 0.0297 - val_loss: 1.7580e-05 - val_root_mean_squared_error: 0.0042
# Epoch 60/200
# 9/9 [==============================] - ETA: 0s - loss: 7.2608e-04 - root_mean_squared_error: 0.0269
# Epoch 60: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 277ms/step - loss: 7.2608e-04 - root_mean_squared_error: 0.0269 - val_loss: 1.5208e-04 - val_root_mean_squared_error: 0.0123
# Epoch 61/200
# 9/9 [==============================] - ETA: 0s - loss: 6.2506e-04 - root_mean_squared_error: 0.0250
# Epoch 61: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 275ms/step - loss: 6.2506e-04 - root_mean_squared_error: 0.0250 - val_loss: 2.1250e-04 - val_root_mean_squared_error: 0.0146
# Epoch 62/200
# 9/9 [==============================] - ETA: 0s - loss: 6.8333e-04 - root_mean_squared_error: 0.0261
# Epoch 62: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 6.8333e-04 - root_mean_squared_error: 0.0261 - val_loss: 1.1395e-04 - val_root_mean_squared_error: 0.0107
# Epoch 63/200
# 9/9 [==============================] - ETA: 0s - loss: 8.8911e-04 - root_mean_squared_error: 0.0298
# Epoch 63: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 264ms/step - loss: 8.8911e-04 - root_mean_squared_error: 0.0298 - val_loss: 2.3782e-04 - val_root_mean_squared_error: 0.0154
# Epoch 64/200
# 9/9 [==============================] - ETA: 0s - loss: 6.8584e-04 - root_mean_squared_error: 0.0262
# Epoch 64: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 6.8584e-04 - root_mean_squared_error: 0.0262 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 65/200
# 9/9 [==============================] - ETA: 0s - loss: 4.7372e-04 - root_mean_squared_error: 0.0218
# Epoch 65: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 4.7372e-04 - root_mean_squared_error: 0.0218 - val_loss: 2.3575e-05 - val_root_mean_squared_error: 0.0049
# Epoch 66/200
# 9/9 [==============================] - ETA: 0s - loss: 7.2488e-04 - root_mean_squared_error: 0.0269
# Epoch 66: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 7.2488e-04 - root_mean_squared_error: 0.0269 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0441
# Epoch 67/200
# 9/9 [==============================] - ETA: 0s - loss: 6.3921e-04 - root_mean_squared_error: 0.0253
# Epoch 67: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 6.3921e-04 - root_mean_squared_error: 0.0253 - val_loss: 4.2216e-04 - val_root_mean_squared_error: 0.0205
# Epoch 68/200
# 9/9 [==============================] - ETA: 0s - loss: 7.0360e-04 - root_mean_squared_error: 0.0265
# Epoch 68: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 7.0360e-04 - root_mean_squared_error: 0.0265 - val_loss: 1.9897e-04 - val_root_mean_squared_error: 0.0141
# Epoch 69/200
# 9/9 [==============================] - ETA: 0s - loss: 5.7918e-04 - root_mean_squared_error: 0.0241
# Epoch 69: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 5.7918e-04 - root_mean_squared_error: 0.0241 - val_loss: 2.4720e-04 - val_root_mean_squared_error: 0.0157
# Epoch 70/200
# 9/9 [==============================] - ETA: 0s - loss: 5.6542e-04 - root_mean_squared_error: 0.0238
# Epoch 70: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 270ms/step - loss: 5.6542e-04 - root_mean_squared_error: 0.0238 - val_loss: 1.3634e-04 - val_root_mean_squared_error: 0.0117
# Epoch 71/200
# 9/9 [==============================] - ETA: 0s - loss: 6.4342e-04 - root_mean_squared_error: 0.0254
# Epoch 71: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 6.4342e-04 - root_mean_squared_error: 0.0254 - val_loss: 7.3220e-04 - val_root_mean_squared_error: 0.0271
# Epoch 72/200
# 9/9 [==============================] - ETA: 0s - loss: 6.6387e-04 - root_mean_squared_error: 0.0258
# Epoch 72: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 6.6387e-04 - root_mean_squared_error: 0.0258 - val_loss: 4.7744e-04 - val_root_mean_squared_error: 0.0219
# Epoch 73/200
# 9/9 [==============================] - ETA: 0s - loss: 6.7094e-04 - root_mean_squared_error: 0.0259
# Epoch 73: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 272ms/step - loss: 6.7094e-04 - root_mean_squared_error: 0.0259 - val_loss: 5.5799e-04 - val_root_mean_squared_error: 0.0236
# Epoch 74/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0332
# Epoch 74: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 345ms/step - loss: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 5.0885e-04 - val_root_mean_squared_error: 0.0226
# Epoch 75/200
# 9/9 [==============================] - ETA: 0s - loss: 9.0739e-04 - root_mean_squared_error: 0.0301
# Epoch 75: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 274ms/step - loss: 9.0739e-04 - root_mean_squared_error: 0.0301 - val_loss: 1.0974e-04 - val_root_mean_squared_error: 0.0105
# Epoch 76/200
# 9/9 [==============================] - ETA: 0s - loss: 9.5150e-04 - root_mean_squared_error: 0.0308
# Epoch 76: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 276ms/step - loss: 9.5150e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.4599e-04 - val_root_mean_squared_error: 0.0234
# Epoch 77/200
# 9/9 [==============================] - ETA: 0s - loss: 7.5411e-04 - root_mean_squared_error: 0.0275
# Epoch 77: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 278ms/step - loss: 7.5411e-04 - root_mean_squared_error: 0.0275 - val_loss: 6.7564e-05 - val_root_mean_squared_error: 0.0082
# Epoch 78/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 78: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 277ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0448
# Epoch 79/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0358
# Epoch 79: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 3.9188e-04 - val_root_mean_squared_error: 0.0198
# Epoch 80/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0344
# Epoch 80: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0012 - root_mean_squared_error: 0.0344 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 81/200
# 9/9 [==============================] - ETA: 0s - loss: 9.3019e-04 - root_mean_squared_error: 0.0305
# Epoch 81: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 9.3019e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.6838e-04 - val_root_mean_squared_error: 0.0216
# Epoch 82/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0322
# Epoch 82: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 0.0010 - root_mean_squared_error: 0.0322 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0704
# Epoch 83/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0341
# Epoch 83: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 261ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0461
# Epoch 84/200
# 9/9 [==============================] - ETA: 0s - loss: 6.9794e-04 - root_mean_squared_error: 0.0264
# Epoch 84: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 6.9794e-04 - root_mean_squared_error: 0.0264 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 85/200
# 9/9 [==============================] - ETA: 0s - loss: 6.2637e-04 - root_mean_squared_error: 0.0250
# Epoch 85: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 6.2637e-04 - root_mean_squared_error: 0.0250 - val_loss: 7.3308e-04 - val_root_mean_squared_error: 0.0271
# Epoch 86/200
# 9/9 [==============================] - ETA: 0s - loss: 7.1133e-04 - root_mean_squared_error: 0.0267
# Epoch 86: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 7.1133e-04 - root_mean_squared_error: 0.0267 - val_loss: 3.3088e-04 - val_root_mean_squared_error: 0.0182
# Epoch 87/200
# 9/9 [==============================] - ETA: 0s - loss: 7.3281e-04 - root_mean_squared_error: 0.0271
# Epoch 87: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 7.3281e-04 - root_mean_squared_error: 0.0271 - val_loss: 9.9442e-04 - val_root_mean_squared_error: 0.0315
# Epoch 88/200
# 9/9 [==============================] - ETA: 0s - loss: 7.6206e-04 - root_mean_squared_error: 0.0276
# Epoch 88: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 270ms/step - loss: 7.6206e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.0153e-05 - val_root_mean_squared_error: 0.0071
# Epoch 89/200
# 9/9 [==============================] - ETA: 0s - loss: 5.7218e-04 - root_mean_squared_error: 0.0239
# Epoch 89: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 270ms/step - loss: 5.7218e-04 - root_mean_squared_error: 0.0239 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0385
# Epoch 90/200
# 9/9 [==============================] - ETA: 0s - loss: 8.5851e-04 - root_mean_squared_error: 0.0293
# Epoch 90: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 8.5851e-04 - root_mean_squared_error: 0.0293 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0680
# Epoch 91/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0326
# Epoch 91: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0424
# Epoch 92/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0379
# Epoch 92: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379 - val_loss: 1.3237e-05 - val_root_mean_squared_error: 0.0036
# Epoch 93/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0356
# Epoch 93: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 270ms/step - loss: 0.0013 - root_mean_squared_error: 0.0356 - val_loss: 3.0349e-05 - val_root_mean_squared_error: 0.0055
# Epoch 94/200
# 9/9 [==============================] - ETA: 0s - loss: 7.0636e-04 - root_mean_squared_error: 0.0266
# Epoch 94: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 7.0636e-04 - root_mean_squared_error: 0.0266 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0401
# Epoch 95/200
# 9/9 [==============================] - ETA: 0s - loss: 8.0757e-04 - root_mean_squared_error: 0.0284
# Epoch 95: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 8.0757e-04 - root_mean_squared_error: 0.0284 - val_loss: 1.7330e-04 - val_root_mean_squared_error: 0.0132
# Epoch 96/200
# 9/9 [==============================] - ETA: 0s - loss: 7.3115e-04 - root_mean_squared_error: 0.0270
# Epoch 96: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 7.3115e-04 - root_mean_squared_error: 0.0270 - val_loss: 1.7267e-04 - val_root_mean_squared_error: 0.0131
# Epoch 97/200
# 9/9 [==============================] - ETA: 0s - loss: 7.3345e-04 - root_mean_squared_error: 0.0271
# Epoch 97: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 263ms/step - loss: 7.3345e-04 - root_mean_squared_error: 0.0271 - val_loss: 8.5746e-04 - val_root_mean_squared_error: 0.0293
# Epoch 98/200
# 9/9 [==============================] - ETA: 0s - loss: 7.5980e-04 - root_mean_squared_error: 0.0276
# Epoch 98: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 7.5980e-04 - root_mean_squared_error: 0.0276 - val_loss: 3.4742e-04 - val_root_mean_squared_error: 0.0186
# Epoch 99/200
# 9/9 [==============================] - ETA: 0s - loss: 5.8087e-04 - root_mean_squared_error: 0.0241
# Epoch 99: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 5.8087e-04 - root_mean_squared_error: 0.0241 - val_loss: 7.6958e-04 - val_root_mean_squared_error: 0.0277
# Epoch 100/200
# 9/9 [==============================] - ETA: 0s - loss: 6.5068e-04 - root_mean_squared_error: 0.0255
# Epoch 100: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 6.5068e-04 - root_mean_squared_error: 0.0255 - val_loss: 7.3783e-04 - val_root_mean_squared_error: 0.0272
# Epoch 101/200
# 9/9 [==============================] - ETA: 0s - loss: 7.2160e-04 - root_mean_squared_error: 0.0269
# Epoch 101: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 7.2160e-04 - root_mean_squared_error: 0.0269 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0370
# Epoch 102/200
# 9/9 [==============================] - ETA: 0s - loss: 7.1995e-04 - root_mean_squared_error: 0.0268
# Epoch 102: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 272ms/step - loss: 7.1995e-04 - root_mean_squared_error: 0.0268 - val_loss: 9.6690e-05 - val_root_mean_squared_error: 0.0098
# Epoch 103/200
# 9/9 [==============================] - ETA: 0s - loss: 7.4907e-04 - root_mean_squared_error: 0.0274
# Epoch 103: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 7.4907e-04 - root_mean_squared_error: 0.0274 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0380
# Epoch 104/200
# 9/9 [==============================] - ETA: 0s - loss: 7.5498e-04 - root_mean_squared_error: 0.0275
# Epoch 104: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 7.5498e-04 - root_mean_squared_error: 0.0275 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0433
# Epoch 105/200
# 9/9 [==============================] - ETA: 0s - loss: 5.1093e-04 - root_mean_squared_error: 0.0226
# Epoch 105: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 269ms/step - loss: 5.1093e-04 - root_mean_squared_error: 0.0226 - val_loss: 5.4669e-05 - val_root_mean_squared_error: 0.0074
# Epoch 106/200
# 9/9 [==============================] - ETA: 0s - loss: 5.7700e-04 - root_mean_squared_error: 0.0240
# Epoch 106: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 5.7700e-04 - root_mean_squared_error: 0.0240 - val_loss: 4.8994e-04 - val_root_mean_squared_error: 0.0221
# Epoch 107/200
# 9/9 [==============================] - ETA: 0s - loss: 5.2057e-04 - root_mean_squared_error: 0.0228
# Epoch 107: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 265ms/step - loss: 5.2057e-04 - root_mean_squared_error: 0.0228 - val_loss: 3.0193e-04 - val_root_mean_squared_error: 0.0174
# Epoch 108/200
# 9/9 [==============================] - ETA: 0s - loss: 4.9632e-04 - root_mean_squared_error: 0.0223
# Epoch 108: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 4.9632e-04 - root_mean_squared_error: 0.0223 - val_loss: 2.4478e-04 - val_root_mean_squared_error: 0.0156
# Epoch 109/200
# 9/9 [==============================] - ETA: 0s - loss: 5.7315e-04 - root_mean_squared_error: 0.0239
# Epoch 109: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 272ms/step - loss: 5.7315e-04 - root_mean_squared_error: 0.0239 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0393
# Epoch 110/200
# 9/9 [==============================] - ETA: 0s - loss: 6.0343e-04 - root_mean_squared_error: 0.0246
# Epoch 110: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 270ms/step - loss: 6.0343e-04 - root_mean_squared_error: 0.0246 - val_loss: 8.3989e-04 - val_root_mean_squared_error: 0.0290
# Epoch 111/200
# 9/9 [==============================] - ETA: 0s - loss: 4.3256e-04 - root_mean_squared_error: 0.0208
# Epoch 111: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 4.3256e-04 - root_mean_squared_error: 0.0208 - val_loss: 8.7065e-04 - val_root_mean_squared_error: 0.0295
# Epoch 112/200
# 9/9 [==============================] - ETA: 0s - loss: 6.0089e-04 - root_mean_squared_error: 0.0245
# Epoch 112: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 6.0089e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 113/200
# 9/9 [==============================] - ETA: 0s - loss: 6.6709e-04 - root_mean_squared_error: 0.0258
# Epoch 113: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 272ms/step - loss: 6.6709e-04 - root_mean_squared_error: 0.0258 - val_loss: 7.8732e-04 - val_root_mean_squared_error: 0.0281
# Epoch 114/200
# 9/9 [==============================] - ETA: 0s - loss: 6.2722e-04 - root_mean_squared_error: 0.0250
# Epoch 114: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 273ms/step - loss: 6.2722e-04 - root_mean_squared_error: 0.0250 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# Epoch 115/200
# 9/9 [==============================] - ETA: 0s - loss: 6.3331e-04 - root_mean_squared_error: 0.0252
# Epoch 115: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 284ms/step - loss: 6.3331e-04 - root_mean_squared_error: 0.0252 - val_loss: 5.3815e-04 - val_root_mean_squared_error: 0.0232
# Epoch 116/200
# 9/9 [==============================] - ETA: 0s - loss: 4.9018e-04 - root_mean_squared_error: 0.0221
# Epoch 116: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 275ms/step - loss: 4.9018e-04 - root_mean_squared_error: 0.0221 - val_loss: 7.9398e-05 - val_root_mean_squared_error: 0.0089
# Epoch 117/200
# 9/9 [==============================] - ETA: 0s - loss: 5.5535e-04 - root_mean_squared_error: 0.0236
# Epoch 117: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 270ms/step - loss: 5.5535e-04 - root_mean_squared_error: 0.0236 - val_loss: 7.5622e-04 - val_root_mean_squared_error: 0.0275
# Epoch 118/200
# 9/9 [==============================] - ETA: 0s - loss: 4.0602e-04 - root_mean_squared_error: 0.0201
# Epoch 118: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 4.0602e-04 - root_mean_squared_error: 0.0201 - val_loss: 2.2978e-05 - val_root_mean_squared_error: 0.0048
# Epoch 119/200
# 9/9 [==============================] - ETA: 0s - loss: 5.4873e-04 - root_mean_squared_error: 0.0234
# Epoch 119: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 268ms/step - loss: 5.4873e-04 - root_mean_squared_error: 0.0234 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 120/200
# 9/9 [==============================] - ETA: 0s - loss: 5.2812e-04 - root_mean_squared_error: 0.0230
# Epoch 120: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 266ms/step - loss: 5.2812e-04 - root_mean_squared_error: 0.0230 - val_loss: 7.5489e-04 - val_root_mean_squared_error: 0.0275
# Epoch 121/200
# 9/9 [==============================] - ETA: 0s - loss: 8.3512e-04 - root_mean_squared_error: 0.0289
# Epoch 121: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 275ms/step - loss: 8.3512e-04 - root_mean_squared_error: 0.0289 - val_loss: 4.3742e-04 - val_root_mean_squared_error: 0.0209
# Epoch 122/200
# 9/9 [==============================] - ETA: 0s - loss: 5.1022e-04 - root_mean_squared_error: 0.0226
# Epoch 122: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 264ms/step - loss: 5.1022e-04 - root_mean_squared_error: 0.0226 - val_loss: 7.7498e-05 - val_root_mean_squared_error: 0.0088
# Epoch 123/200
# 9/9 [==============================] - ETA: 0s - loss: 9.0341e-04 - root_mean_squared_error: 0.0301
# Epoch 123: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 273ms/step - loss: 9.0341e-04 - root_mean_squared_error: 0.0301 - val_loss: 4.2432e-04 - val_root_mean_squared_error: 0.0206
# Epoch 124/200
# 9/9 [==============================] - ETA: 0s - loss: 5.0332e-04 - root_mean_squared_error: 0.0224
# Epoch 124: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 267ms/step - loss: 5.0332e-04 - root_mean_squared_error: 0.0224 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 125/200
# 9/9 [==============================] - ETA: 0s - loss: 5.7564e-04 - root_mean_squared_error: 0.0240
# Epoch 125: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 275ms/step - loss: 5.7564e-04 - root_mean_squared_error: 0.0240 - val_loss: 1.6778e-05 - val_root_mean_squared_error: 0.0041
# Epoch 126/200
# 9/9 [==============================] - ETA: 0s - loss: 5.2687e-04 - root_mean_squared_error: 0.0230
# Epoch 126: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 271ms/step - loss: 5.2687e-04 - root_mean_squared_error: 0.0230 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 127/200
# 9/9 [==============================] - ETA: 0s - loss: 4.8730e-04 - root_mean_squared_error: 0.0221
# Epoch 127: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 272ms/step - loss: 4.8730e-04 - root_mean_squared_error: 0.0221 - val_loss: 2.0019e-04 - val_root_mean_squared_error: 0.0141
# Epoch 128/200
# 9/9 [==============================] - ETA: 0s - loss: 3.7195e-04 - root_mean_squared_error: 0.0193
# Epoch 128: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 275ms/step - loss: 3.7195e-04 - root_mean_squared_error: 0.0193 - val_loss: 2.2268e-04 - val_root_mean_squared_error: 0.0149
# Epoch 129/200
# 9/9 [==============================] - ETA: 0s - loss: 4.2562e-04 - root_mean_squared_error: 0.0206
# Epoch 129: val_loss did not improve from 0.00001
# 9/9 [==============================] - 2s 274ms/step - loss: 4.2562e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1151e-04 - val_root_mean_squared_error: 0.0176
# Epoch 129: early stopping

# %%
# Visualize loss

# Visualize training and validation loss.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training Loss VS Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
# Model evaluation
test_predicted = model.predict(X_test)

# %%
test_predicted
# Out:
# array([[0.54968405],
#        [0.5529062 ],
#        [0.55624133],
#        [0.56013846],
#        [0.56484616],
#        [0.5705288 ],
#        [0.5771412 ],
#        [0.5845094 ],
#        [0.5928473 ],
#        [0.6024257 ],
#        [0.6132528 ],
#        [0.6264109 ],
#        [0.64278924],
#        [0.66248685],
#        [0.6852789 ],
#        [0.71053636],
#        [0.73728156],
#        [0.7638081 ]], dtype=float32)

# %%
# Apply inverse transformation
test_predicted= scaler.inverse_transform(test_predicted)
#Y_test = scaler.inverse_transform(Y_test)
#test_predicted = test_predicted.reshape(test_predicted.shape[0],test_predicted.shape[1])
#test_predicted.shape

# %%
#Y_test.shape
#test_predicted.shape
#test_predicted = test_predicted.reshape(test_predicted.shape[0])
test_predicted
# Out:
# array([[302.66254],
#        [303.54956],
#        [304.46768],
#        [305.54053],
#        [306.83652],
#        [308.40088],
#        [310.2212 ],
#        [312.2496 ],
#        [314.54492],
#        [317.1818 ],
#        [320.16235],
#        [323.78467],
#        [328.29346],
#        [333.716  ],
#        [339.99045],
#        [346.94357],
#        [354.30624],
#        [361.60873]], dtype=float32)

# %%
# Re-populate Y_test
#X_test, Y_test = create_dmatrix(test_set, time_step)
#Y_test = Y_test.reshape(test_predicted.shape[0],1)
#Y_test = scaler.inverse_transform(Y_test)
#Y_test = Y_test.reshape(-1)
Y_test
# Out:
# array([321.58      , 324.19      , 326.8       , 329.41      ,
#        332.29      , 335.17      , 338.05      , 342.43666667,
#        346.82333333, 351.21      , 359.34666667, 367.48333333,
#        375.62      , 385.03      , 394.44      , 403.85      ,
#        411.44333333, 419.03666667])

# %%
# Reshape Y_test to 2D
Y_test = Y_test.reshape(test_predicted.shape[0],1)
Y_test = scaler.inverse_transform(Y_test)

# Reshape back to 1D
Y_test = Y_test.reshape(test_predicted.shape[0])
Y_test
# Out:
# array([321.58      , 324.19      , 326.8       , 329.41      ,
#        332.29      , 335.17      , 338.05      , 342.43666667,
#        346.82333333, 351.21      , 359.34666667, 367.48333333,
#        375.62      , 385.03      , 394.44      , 403.85      ,
#        411.44333333, 419.03666667])

# %%
# Calculate RMSE
math.sqrt(mean_squared_error(Y_test,test_predicted))
# Out:
# 39.57130362375624

# %%
#test_predicted = test_predicted.reshape(-1, 1)
#test_predicted
test_predicted
# Out:
# array([[237.0811 ],
#        [240.32011],
#        [243.95862],
#        [248.07315],
#        [252.65337],
#        [257.63763],
#        [262.94397],
#        [268.51364],
#        [274.28806]], dtype=float32)

# %%
training_predicted = model.predict(X_train)
validation_predicted = model.predict(X_val)

# %%
training_predicted = scaler.inverse_transform(training_predicted)
#training_predicted.shape
validation_predicted = scaler.inverse_transform(validation_predicted)
#validation_predicted.shape
print(scaler.inverse_transform(validation_set))
# Out:
# [[223.88666667]
#  [225.51333333]
#  [227.14      ]
#  [229.70333333]
#  [232.26666667]
#  [234.83      ]
#  [236.69      ]
#  [238.55      ]
#  [240.41      ]
#  [242.51      ]
#  [244.61      ]
#  [246.71      ]
#  [248.11      ]
#  [249.51      ]
#  [250.91      ]
#  [253.77      ]
#  [256.63      ]
#  [259.49      ]
#  [261.06333333]
#  [262.63666667]
#  [264.21      ]
#  [265.84      ]
#  [267.47      ]
#  [269.1       ]
#  [271.56      ]
#  [274.02      ]
#  [276.48      ]
#  [278.81333333]
#  [281.14666667]]

# %%
# Plotting everything together
# Setting the intervals 

# shift training predictions for plotting
training_predicted_plot = np.empty_like(df1)
training_predicted_plot[:, :] = np.nan
#training_predicted.shape
#training_predicted_plot[14:167, :] = training_predicted
training_predicted_plot[24:165, :] = training_predicted

#training_predicted_plot[24:143, :] = training_predicted
# shift validation predictions for plotting
val_predicted_plot = np.empty_like(df1)
val_predicted_plot[:, :] = np.nan
#validation_predicted.shape
#val_predicted_plot[181:214, :] = validation_predicted
#val_predicted_plot[192:203, :] = validation_predicted
#val_predicted_plot[168:191, :] = validation_predicted
val_predicted_plot[189:193, :] = validation_predicted
# shift test predictions for plotting
test_predicted_plot = np.empty_like(df1)
test_predicted_plot[:, :] = np.nan
#test_predicted.shape
#test_predicted_plot[230:239, :] = test_predicted
#test_predicted_plot[228:239, :] = test_predicted
#test_predicted_plot[216:239, :] = test_predicted
test_predicted_plot[220:239, :] = test_predicted

# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1), label = "Real Data")
plt.plot(test_predicted_plot, label = "Predicted Data for Test Set")
plt.plot(val_predicted_plot, label = "Predicted Data for Validation Set")
plt.plot(training_predicted_plot, label = "Predicted Data for Training Set")
plt.legend()
plt.show()

# %%
#math.sqrt(mean_squared_error(Y_test,test_predicted))
#print(scaler.inverse_transform(train_set))
#print(scaler.inverse_transform(training_predicted))
#train_set_invers = scaler.inverse_transform(Y_train)
#math.sqrt(mean_squared_error(_test,test_predicted))
#Y_train_sh = Y_train.reshape(training_predicted.shape[0],1)
#train_set_invers = scaler.inverse_transform(Y_train_sh)

#Y_train_d = Y_train.reshape(-1, 1)
#train_set_invers = scaler.inverse_transform(Y_train_d)
#math.sqrt(mean_squared_error(train_set_invers, training_predicted))
#print(scaler.inverse_transform(X_test))
#test_predicted
# Out:
# array([[237.0811 ],
#        [240.32011],
#        [243.95862],
#        [248.07315],
#        [252.65337],
#        [257.63763],
#        [262.94397],
#        [268.51364],
#        [274.28806]], dtype=float32)

# %%
# Create new array for future predictions

# Explanation. Since we have been predicting using timestep = 24, meaning we have used the past 24 prices to predict the 25th, now we will use the test_set data as that is the latest data to predict further INTO THE UNKNOWN!
# The size of the future_input array needs to be equal to timestep, so if you change the test_data size and timestep make sure to reflect those changes here as well.

pred_input=test_set[19:].reshape(1,-1)
pred_input
# Out:
# array([[0.58929371, 0.59589282, 0.60249192, 0.60779542, 0.61309891,
#         0.61840241, 0.62788332, 0.63736423, 0.64684515, 0.65730684,
#         0.66776853, 0.67823023, 0.69416494, 0.71009965, 0.72603436,
#         0.75559107, 0.78514778, 0.81470449, 0.84888663, 0.88306876,
#         0.9172509 , 0.94483393, 0.97241697, 1.        ]])

# %%
# Add that to temp input
temp_input = []
temp_input=list(pred_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.589293714507126,
#  0.5958928160606392,
#  0.6024919176141523,
#  0.6077954157433978,
#  0.6130989138726435,
#  0.618402412001889,
#  0.6278833230411567,
#  0.6373642340804244,
#  0.6468451451196922,
#  0.6573068400595736,
#  0.6677685349994553,
#  0.6782302299393368,
#  0.6941649412135082,
#  0.7100996524876797,
#  0.7260343637618512,
#  0.7555910736556601,
#  0.7851477835494691,
#  0.8147044934432781,
#  0.8488866286461552,
#  0.883068763849032,
#  0.917250899051909,
#  0.9448339327012727,
#  0.9724169663506366,
#  1.0000000000000002]

# %%
# Predict in the future

from numpy import array

list_output=[]
n_steps=24
i=0
while(i<12):
    
    if(len(temp_input)>24):
        print('Entering main condition')
        #print(temp_input)
        pred_input=np.array(temp_input[1:]) # Shift one to the right
        print("{} month input {}".format(i,pred_input))
        pred_input=pred_input.reshape(1,-1)
        pred_input = pred_input.reshape(1, n_steps, 1)
        print('Pred_input shape is:', pred_input.shape)
        fut_pred = model.predict(pred_input, verbose=0)
        print("{} month output {}".format(i,fut_pred))
        temp_input.extend(fut_pred[0].tolist()) # Add that prediction to the temp input list as that will be used in the next prediction 
        temp_input=temp_input[1:] #Shift the temp_input to remove the first element which was already used in a sequence
        #print(temp_input)
        list_output.extend(fut_pred.tolist())
        i=i+1
    else:
        print('Entering else condition')
        pred_input = pred_input.reshape((1, n_steps,1))
        fut_pred = model.predict(pred_input, verbose=0)
        print('The predicted value is:',fut_pred[0])
        temp_input.extend(fut_pred[0].tolist())
        print(len(temp_input))
        list_output.extend(fut_pred.tolist())
        i=i+1
    

print(list_output)
# Out:
# Entering else condition
# The predicted value is: [0.81028384]
# 25
# Entering main condition
# 1 month input [0.59589282 0.60249192 0.60779542 0.61309891 0.61840241 0.62788332
#  0.63736423 0.64684515 0.65730684 0.66776853 0.67823023 0.69416494
#  0.71009965 0.72603436 0.75559107 0.78514778 0.81470449 0.84888663
#  0.88306876 0.9172509  0.94483393 0.97241697 1.         0.81028384]
# Pred_input shape is: (1, 24, 1)
# 1 month output [[0.8079994]]
# Entering main condition
# 2 month input [0.60249192 0.60779542 0.61309891 0.61840241 0.62788332 0.63736423
#  0.64684515 0.65730684 0.66776853 0.67823023 0.69416494 0.71009965
#  0.72603436 0.75559107 0.78514778 0.81470449 0.84888663 0.88306876
#  0.9172509  0.94483393 0.97241697 1.         0.81028384 0.80799937]
# Pred_input shape is: (1, 24, 1)
# 2 month output [[0.7810251]]
# Entering main condition
# 3 month input [0.60779542 0.61309891 0.61840241 0.62788332 0.63736423 0.64684515
#  0.65730684 0.66776853 0.67823023 0.69416494 0.71009965 0.72603436
#  0.75559107 0.78514778 0.81470449 0.84888663 0.88306876 0.9172509
#  0.94483393 0.97241697 1.         0.81028384 0.80799937 0.78102511]
# Pred_input shape is: (1, 24, 1)
# 3 month output [[0.73694736]]
# Entering main condition
# 4 month input [0.61309891 0.61840241 0.62788332 0.63736423 0.64684515 0.65730684
#  0.66776853 0.67823023 0.69416494 0.71009965 0.72603436 0.75559107
#  0.78514778 0.81470449 0.84888663 0.88306876 0.9172509  0.94483393
#  0.97241697 1.         0.81028384 0.80799937 0.78102511 0.73694736]
# Pred_input shape is: (1, 24, 1)
# 4 month output [[0.68290824]]
# Entering main condition
# 5 month input [0.61840241 0.62788332 0.63736423 0.64684515 0.65730684 0.66776853
#  0.67823023 0.69416494 0.71009965 0.72603436 0.75559107 0.78514778
#  0.81470449 0.84888663 0.88306876 0.9172509  0.94483393 0.97241697
#  1.         0.81028384 0.80799937 0.78102511 0.73694736 0.68290824]
# Pred_input shape is: (1, 24, 1)
# 5 month output [[0.62338215]]
# Entering main condition
# 6 month input [0.62788332 0.63736423 0.64684515 0.65730684 0.66776853 0.67823023
#  0.69416494 0.71009965 0.72603436 0.75559107 0.78514778 0.81470449
#  0.84888663 0.88306876 0.9172509  0.94483393 0.97241697 1.
#  0.81028384 0.80799937 0.78102511 0.73694736 0.68290824 0.62338215]
# Pred_input shape is: (1, 24, 1)
# 6 month output [[0.56081545]]
# Entering main condition
# 7 month input [0.63736423 0.64684515 0.65730684 0.66776853 0.67823023 0.69416494
#  0.71009965 0.72603436 0.75559107 0.78514778 0.81470449 0.84888663
#  0.88306876 0.9172509  0.94483393 0.97241697 1.         0.81028384
#  0.80799937 0.78102511 0.73694736 0.68290824 0.62338215 0.56081545]
# Pred_input shape is: (1, 24, 1)
# 7 month output [[0.4965366]]
# Entering main condition
# 8 month input [0.64684515 0.65730684 0.66776853 0.67823023 0.69416494 0.71009965
#  0.72603436 0.75559107 0.78514778 0.81470449 0.84888663 0.88306876
#  0.9172509  0.94483393 0.97241697 1.         0.81028384 0.80799937
#  0.78102511 0.73694736 0.68290824 0.62338215 0.56081545 0.49653661]
# Pred_input shape is: (1, 24, 1)
# 8 month output [[0.4315667]]
# Entering main condition
# 9 month input [0.65730684 0.66776853 0.67823023 0.69416494 0.71009965 0.72603436
#  0.75559107 0.78514778 0.81470449 0.84888663 0.88306876 0.9172509
#  0.94483393 0.97241697 1.         0.81028384 0.80799937 0.78102511
#  0.73694736 0.68290824 0.62338215 0.56081545 0.49653661 0.43156669]
# Pred_input shape is: (1, 24, 1)
# 9 month output [[0.36676487]]
# Entering main condition
# 10 month input [0.66776853 0.67823023 0.69416494 0.71009965 0.72603436 0.75559107
#  0.78514778 0.81470449 0.84888663 0.88306876 0.9172509  0.94483393
#  0.97241697 1.         0.81028384 0.80799937 0.78102511 0.73694736
#  0.68290824 0.62338215 0.56081545 0.49653661 0.43156669 0.36676487]
# Pred_input shape is: (1, 24, 1)
# 10 month output [[0.3028371]]
# Entering main condition
# 11 month input [0.67823023 0.69416494 0.71009965 0.72603436 0.75559107 0.78514778
#  0.81470449 0.84888663 0.88306876 0.9172509  0.94483393 0.97241697
#  1.         0.81028384 0.80799937 0.78102511 0.73694736 0.68290824
#  0.62338215 0.56081545 0.49653661 0.43156669 0.36676487 0.3028371 ]
# Pred_input shape is: (1, 24, 1)
# 11 month output [[0.24034911]]
# [[0.8102838397026062], [0.8079993724822998], [0.7810251116752625], [0.7369473576545715], [0.6829082369804382], [0.6233821511268616], [0.5608154535293579], [0.49653661251068115], [0.43156668543815613], [0.3667648732662201], [0.3028371036052704], [0.24034911394119263]]

# %%
month_new = np.arange(1, 24)
month_pred = np.arange(24,36)

# %%
plt.plot(month_new,scaler.inverse_transform(df1[215:]))
plt.plot(month_pred,scaler.inverse_transform(list_output))

# %%
df3 = df1.tolist()
df3.extend(list_output)
plt.plot(df3[238:])

# %%
print(scaler.inverse_transform(list_output))
# Out:
# [[374.40303823]
#  [373.77414725]
#  [366.34840299]
#  [354.21423809]
#  [339.33780856]
#  [322.95087238]
#  [305.7268862 ]
#  [288.03156406]
#  [270.14599283]
#  [252.30670196]
#  [234.70802625]
#  [217.50570758]]

# %%
df3=scaler.inverse_transform(df3).tolist()
plt.plot(df3)

# %%
# Make copy of original data
df_orig33 = pd.read_csv('/content/Model_Tampa_Prediction_6months.csv')
df_orig33
# Out:
#            DATE      TPXRSA
# 0    2002-01-01  120.395793
# 1    2002-02-01  120.700034
# 2    2002-03-01  122.958147
# 3    2002-04-01  123.707047
# 4    2002-05-01  124.950321
# ..          ...         ...
# 241  2022-02-01  295.493895
# 242  2022-03-01  285.777483
# 243  2022-04-01  272.348633
# 244  2022-05-01  257.288102
# 245  2022-06-01  241.530343
#
# [246 rows x 2 columns]

# %%
output1_df = pd.DataFrame(df3, columns=['Sale Price'])
output1_df
# Out:
#      Sale Price
# 0    151.340000
# 1    152.713333
# 2    154.086667
# 3    155.460000
# 4    156.823333
# ..          ...
# 245  315.668145
# 246  298.453069
# 247  280.809721
# 248  262.894384
# 249  244.824750
#
# [250 rows x 1 columns]

# %%
test_df = df_orig.copy()
test_df['TXP'] = output1_df

# %%
result = [output1_df, df_orig]
new_df = pd.concat(result, axis =1)

# %%
new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
new_df
# Out:
#      Sale Price        DATE
# 0    120.395793  2002-01-01
# 1    120.700034  2002-02-01
# 2    122.958147  2002-03-01
# 3    123.707047  2002-04-01
# 4    124.950321  2002-05-01
# ..          ...         ...
# 241  295.493895         NaN
# 242  285.777483         NaN
# 243  272.348633         NaN
# 244  257.288102         NaN
# 245  241.530343         NaN
#
# [246 rows x 2 columns]

# %%
#new_df['DATE'] = pd.to_datetime(new_df['DATE'])
#new_df = new_df.set_index('DATE')
#new_df.index = new_df.index.to_period("1M")

# %%
#new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
#new_date_range = pd.date_range(start="2002-01", end='2023-01', freq="M")
#new_date_range = pd.Series(pd.date_range("1/1/2002", freq="M", periods=len(df3)))
#new_df = new_df.reindex(new_date_range, fill_value=0)

# %%
#new_df['Sale Price'] = output1_df['Sale Price']

#new_df = new_df.append(output1_df, ignore_index = True)

# %%
#df_orig1 = df_orig.copy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-a5f9668e6f2b> in <module>()
#       1 df_orig1 = df_orig.copy()
# ----> 2 df_orig1 = pd.concat(output1_df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     328         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     329             raise TypeError(
# --> 330                 "first argument must be an iterable of pandas "
#     331                 f'objects, you passed an object of type "{type(objs).__name__}"'
#     332             )
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
result1 = [new_df, output_df]
new_df = pd.concat(result1, axis =1)

# %%
df.to_csv('Model_Prediction_Clearwater_12months.csv')
files.download('Model_Prediction_Clearwater_12months.csv')
