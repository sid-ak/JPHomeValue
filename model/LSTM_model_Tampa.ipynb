# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive, files # google colab specific
import requests
import pandas as pd
import os
import warnings
import sys
import matplotlib.pyplot as plt
import json
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from tensorflow import keras
from keras import layers
import math
from sklearn.metrics import mean_squared_error

# %%
# Read in the csv file that contains the time series data of the Shiller Index
# Create the dataframe

df = pd.read_csv('/content/drive/MyDrive/JPM/jphomevalue/data/TPXRSA.csv')
df.head()
# Out:
#          DATE      TPXRSA
# 0  2002-01-01  120.395793
# 1  2002-02-01  120.700034
# 2  2002-03-01  122.958147
# 3  2002-04-01  123.707047
# 4  2002-05-01  124.950321

# %%
df.tail()
# Out:
#            DATE      TPXRSA
# 235  2021-08-01  296.829882
# 236  2021-09-01  304.124715
# 237  2021-10-01  309.713391
# 238  2021-11-01  315.997613
# 239  2021-12-01  321.813428

# %%
# Reset the index based on the prices
df1 = df.reset_index()['TPXRSA']
df1
# Out:
# 0      120.395793
# 1      120.700034
# 2      122.958147
# 3      123.707047
# 4      124.950321
#           ...
# 235    296.829882
# 236    304.124715
# 237    309.713391
# 238    315.997613
# 239    321.813428
# Name: TPXRSA, Length: 240, dtype: float64

# %%
# Visualize the data for reference. 
plt.plot(df1)

# %%
# Normalize the data with the range 0 - 1
scaler = MinMaxScaler(feature_range=(0,1))

# Apply the scaler to the dataframe
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# Print df1 to check the change
print(df1)

# %%
# Split data into train, validation and test set. Ratio: 6/1/3
training_size = int(len(df1)*0.7)
validation_size = int(len(df1)*0.82) 
test_size = int(len(df1))

train_set = df1[0:training_size,:]
validation_set = df1[training_size:validation_size,:]
test_set = df1[validation_size:test_size,:1]
prediction_set = df1[167:241,:]

# %%
df1.shape
# Out:
# (240, 1)

# %%
# Check sizes and set sizes
#training_size
#validation_size 
#test_size
print(train_set.shape)
print(validation_set.shape)
print(test_set.shape)
print(prediction_set.shape)
# Out:
# (168, 1)
# (28, 1)
# (44, 1)
# (73, 1)

# %%
# The current array of values needs to be converted into a dataset matrix
def create_dmatrix(dataset, time_step=1):
  data_X, data_Y = [], []
  for i in range(len(dataset)-time_step-1):
    k = dataset[i:(i + time_step), 0]
    data_X.append(k)
    data_Y.append(dataset[i + time_step, 0])
  return np.array(data_X), np.array(data_Y)

# %%
# Using the function already created for the conversion, convert training, validation and test sets. 
time_step = 24
X_train, Y_train = create_dmatrix(train_set, time_step)
X_val, Y_val = create_dmatrix(validation_set, time_step)
X_test, Y_test = create_dmatrix(test_set, time_step)
X_pred, Y_pred = create_dmatrix(prediction_set, time_step)

print('X Train set shape:', X_train.shape)
print('y Train set shape:', Y_train.shape)

print('X Validation set shape:', X_val.shape)
print('y Validation set shape:', Y_val.shape)

print('X Test set shape:', X_test.shape)
print('y Test set shape:', Y_test.shape)

print('X Pred set shape:', X_pred.shape)
print('y Pred set shape:', Y_pred.shape)
# Out:
# X Train set shape: (143, 24)
# y Train set shape: (143,)
# X Validation set shape: (3, 24)
# y Validation set shape: (3,)
# X Test set shape: (19, 24)
# y Test set shape: (19,)
# X Pred set shape: (48, 24)
# y Pred set shape: (48,)

# %%
# Check the matrixes created
X_test

# %%
# In order to feed the dataset to the neural network the data must be in 3D

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[1], 1)

# %%
# Hyperparameters
batch_size = 16
epochs = 200
learning_rate = 0.001

# %%
# LSTM MODEL ARCHITECTURE

model = keras.models.Sequential([
  keras.Input(shape=(24, 1)),
  # Masking layer, to ignore zeros.
  # keras.layers.Masking(),
  # 4 LSTM Layers with 16 units.
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250),
  keras.layers.Dropout(0.5),
  # Fully Connected Layer
  keras.layers.Dense(units=1)
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 24, 250)           252000
#
#  lstm_5 (LSTM)               (None, 24, 250)           501000
#
#  lstm_6 (LSTM)               (None, 24, 250)           501000
#
#  lstm_7 (LSTM)               (None, 250)               501000
#
#  dropout_1 (Dropout)         (None, 250)               0
#
#  dense_3 (Dense)             (None, 1)                 251
#
# =================================================================
# Total params: 1,755,251
# Trainable params: 1,755,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Loss and Optimizer Functions
mse = tf.keras.losses.MeanSquaredError()
rmse = tf.keras.metrics.RootMeanSquaredError()
model.compile(loss=mse, optimizer=keras.optimizers.Adam(learning_rate=learning_rate), metrics=[rmse])

# %%
# Callbacks.

callbacks = [EarlyStopping(monitor='val_loss', patience=100, verbose=1), 
            ModelCheckpoint(filepath='/content/sample_data/lstm-model-tampa-24-0.4-2.h5', verbose=1, monitor='val_loss', save_best_only=True, save_weights_only=False)]

# Train the model
history = model.fit(x=X_train, y=Y_train, validation_data =(X_val, Y_val), epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=callbacks)
# Out:
# Epoch 1/200
# 4/5 [=======================>......] - ETA: 0s - loss: 8.9179e-04 - root_mean_squared_error: 0.0299
# Epoch 1: val_loss improved from inf to 0.00066, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 61ms/step - loss: 8.4358e-04 - root_mean_squared_error: 0.0290 - val_loss: 6.5939e-04 - val_root_mean_squared_error: 0.0257
# Epoch 2/200
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0370
# Epoch 2: val_loss improved from 0.00066 to 0.00064, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 6.4079e-04 - val_root_mean_squared_error: 0.0253
# Epoch 3/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0375
# Epoch 3: val_loss improved from 0.00064 to 0.00064, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0014 - root_mean_squared_error: 0.0375 - val_loss: 6.3872e-04 - val_root_mean_squared_error: 0.0253
# Epoch 4/200
# 5/5 [==============================] - ETA: 0s - loss: 9.5097e-04 - root_mean_squared_error: 0.0308
# Epoch 4: val_loss did not improve from 0.00064
# 5/5 [==============================] - 0s 28ms/step - loss: 9.5097e-04 - root_mean_squared_error: 0.0308 - val_loss: 6.4606e-04 - val_root_mean_squared_error: 0.0254
# Epoch 5/200
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0370
# Epoch 5: val_loss improved from 0.00064 to 0.00037, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0016 - root_mean_squared_error: 0.0402 - val_loss: 3.7345e-04 - val_root_mean_squared_error: 0.0193
# Epoch 6/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0332
# Epoch 6: val_loss did not improve from 0.00037
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 6.9558e-04 - val_root_mean_squared_error: 0.0264
# Epoch 7/200
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0325
# Epoch 7: val_loss did not improve from 0.00037
# 5/5 [==============================] - 0s 43ms/step - loss: 9.7025e-04 - root_mean_squared_error: 0.0311 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0321
# Epoch 8/200
# 5/5 [==============================] - ETA: 0s - loss: 9.8426e-04 - root_mean_squared_error: 0.0314
# Epoch 8: val_loss did not improve from 0.00037
# 5/5 [==============================] - 0s 32ms/step - loss: 9.8426e-04 - root_mean_squared_error: 0.0314 - val_loss: 8.4122e-04 - val_root_mean_squared_error: 0.0290
# Epoch 9/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 9: val_loss improved from 0.00037 to 0.00025, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 2.4980e-04 - val_root_mean_squared_error: 0.0158
# Epoch 10/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0364
# Epoch 10: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0013 - root_mean_squared_error: 0.0364 - val_loss: 5.7520e-04 - val_root_mean_squared_error: 0.0240
# Epoch 11/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0358
# Epoch 11: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 3.5760e-04 - val_root_mean_squared_error: 0.0189
# Epoch 12/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0342
# Epoch 12: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 9.7263e-04 - val_root_mean_squared_error: 0.0312
# Epoch 13/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 13: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 4.1434e-04 - val_root_mean_squared_error: 0.0204
# Epoch 14/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0365
# Epoch 14: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0386
# Epoch 15/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0383
# Epoch 15: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 5.1734e-04 - val_root_mean_squared_error: 0.0227
# Epoch 16/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0355
# Epoch 16: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0433
# Epoch 17/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0395
# Epoch 17: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 5.6715e-04 - val_root_mean_squared_error: 0.0238
# Epoch 18/200
# 5/5 [==============================] - ETA: 0s - loss: 9.5098e-04 - root_mean_squared_error: 0.0308
# Epoch 18: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.5098e-04 - root_mean_squared_error: 0.0308 - val_loss: 6.1640e-04 - val_root_mean_squared_error: 0.0248
# Epoch 19/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0329
# Epoch 19: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 5.4086e-04 - val_root_mean_squared_error: 0.0233
# Epoch 20/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0341
# Epoch 20: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 8.4470e-04 - val_root_mean_squared_error: 0.0291
# Epoch 21/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0325
# Epoch 21: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0325 - val_loss: 7.0777e-04 - val_root_mean_squared_error: 0.0266
# Epoch 22/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0371
# Epoch 22: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 6.4571e-04 - val_root_mean_squared_error: 0.0254
# Epoch 23/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7195e-04 - root_mean_squared_error: 0.0312
# Epoch 23: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.7195e-04 - root_mean_squared_error: 0.0312 - val_loss: 4.2175e-04 - val_root_mean_squared_error: 0.0205
# Epoch 24/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0333
# Epoch 24: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 8.9528e-04 - val_root_mean_squared_error: 0.0299
# Epoch 25/200
# 5/5 [==============================] - ETA: 0s - loss: 8.2289e-04 - root_mean_squared_error: 0.0287
# Epoch 25: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 8.2289e-04 - root_mean_squared_error: 0.0287 - val_loss: 5.4575e-04 - val_root_mean_squared_error: 0.0234
# Epoch 26/200
# 5/5 [==============================] - ETA: 0s - loss: 7.9276e-04 - root_mean_squared_error: 0.0282
# Epoch 26: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 7.9276e-04 - root_mean_squared_error: 0.0282 - val_loss: 9.6431e-04 - val_root_mean_squared_error: 0.0311
# Epoch 27/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 27: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 6.9720e-04 - val_root_mean_squared_error: 0.0264
# Epoch 28/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0326
# Epoch 28: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 4.3650e-04 - val_root_mean_squared_error: 0.0209
# Epoch 29/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0326
# Epoch 29: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 5.0423e-04 - val_root_mean_squared_error: 0.0225
# Epoch 30/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0318
# Epoch 30: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 2.9666e-04 - val_root_mean_squared_error: 0.0172
# Epoch 31/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0360
# Epoch 31: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360 - val_loss: 7.3933e-04 - val_root_mean_squared_error: 0.0272
# Epoch 32/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0318
# Epoch 32: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 3.7145e-04 - val_root_mean_squared_error: 0.0193
# Epoch 33/200
# 5/5 [==============================] - ETA: 0s - loss: 9.0156e-04 - root_mean_squared_error: 0.0300
# Epoch 33: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.0156e-04 - root_mean_squared_error: 0.0300 - val_loss: 4.3907e-04 - val_root_mean_squared_error: 0.0210
# Epoch 34/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0343
# Epoch 34: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 5.9269e-04 - val_root_mean_squared_error: 0.0243
# Epoch 35/200
# 5/5 [==============================] - ETA: 0s - loss: 8.7785e-04 - root_mean_squared_error: 0.0296
# Epoch 35: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 8.7785e-04 - root_mean_squared_error: 0.0296 - val_loss: 3.3401e-04 - val_root_mean_squared_error: 0.0183
# Epoch 36/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0363
# Epoch 36: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0013 - root_mean_squared_error: 0.0363 - val_loss: 9.1038e-04 - val_root_mean_squared_error: 0.0302
# Epoch 37/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0355
# Epoch 37: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 5.2250e-04 - val_root_mean_squared_error: 0.0229
# Epoch 38/200
# 5/5 [==============================] - ETA: 0s - loss: 8.0435e-04 - root_mean_squared_error: 0.0284
# Epoch 38: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 8.0435e-04 - root_mean_squared_error: 0.0284 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 39/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0374
# Epoch 39: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0014 - root_mean_squared_error: 0.0374 - val_loss: 5.6581e-04 - val_root_mean_squared_error: 0.0238
# Epoch 40/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0353
# Epoch 40: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0353 - val_loss: 4.3903e-04 - val_root_mean_squared_error: 0.0210
# Epoch 41/200
# 5/5 [==============================] - ETA: 0s - loss: 8.1691e-04 - root_mean_squared_error: 0.0286
# Epoch 41: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 8.1691e-04 - root_mean_squared_error: 0.0286 - val_loss: 6.8287e-04 - val_root_mean_squared_error: 0.0261
# Epoch 42/200
# 5/5 [==============================] - ETA: 0s - loss: 9.9933e-04 - root_mean_squared_error: 0.0316
# Epoch 42: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.9933e-04 - root_mean_squared_error: 0.0316 - val_loss: 6.3221e-04 - val_root_mean_squared_error: 0.0251
# Epoch 43/200
# 5/5 [==============================] - ETA: 0s - loss: 9.1607e-04 - root_mean_squared_error: 0.0303
# Epoch 43: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.1607e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.8270e-04 - val_root_mean_squared_error: 0.0241
# Epoch 44/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0364
# Epoch 44: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0364 - val_loss: 4.9051e-04 - val_root_mean_squared_error: 0.0221
# Epoch 45/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0319
# Epoch 45: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0319 - val_loss: 7.2557e-04 - val_root_mean_squared_error: 0.0269
# Epoch 46/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 46: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 7.7228e-04 - val_root_mean_squared_error: 0.0278
# Epoch 47/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0398
# Epoch 47: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 9.7232e-04 - val_root_mean_squared_error: 0.0312
# Epoch 48/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0365
# Epoch 48: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - val_loss: 8.6237e-04 - val_root_mean_squared_error: 0.0294
# Epoch 49/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0357
# Epoch 49: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0357 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0499
# Epoch 50/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 50: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 4.8984e-04 - val_root_mean_squared_error: 0.0221
# Epoch 51/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0396
# Epoch 51: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 4.1421e-04 - val_root_mean_squared_error: 0.0204
# Epoch 52/200
# 5/5 [==============================] - ETA: 0s - loss: 7.8750e-04 - root_mean_squared_error: 0.0281
# Epoch 52: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 24ms/step - loss: 7.8750e-04 - root_mean_squared_error: 0.0281 - val_loss: 8.0529e-04 - val_root_mean_squared_error: 0.0284
# Epoch 53/200
# 5/5 [==============================] - ETA: 0s - loss: 9.3083e-04 - root_mean_squared_error: 0.0305
# Epoch 53: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 24ms/step - loss: 9.3083e-04 - root_mean_squared_error: 0.0305 - val_loss: 3.3778e-04 - val_root_mean_squared_error: 0.0184
# Epoch 54/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0351
# Epoch 54: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 5.7950e-04 - val_root_mean_squared_error: 0.0241
# Epoch 55/200
# 5/5 [==============================] - ETA: 0s - loss: 9.6139e-04 - root_mean_squared_error: 0.0310
# Epoch 55: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.6139e-04 - root_mean_squared_error: 0.0310 - val_loss: 7.5990e-04 - val_root_mean_squared_error: 0.0276
# Epoch 56/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0358
# Epoch 56: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - val_loss: 3.5927e-04 - val_root_mean_squared_error: 0.0190
# Epoch 57/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 57: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 3.4728e-04 - val_root_mean_squared_error: 0.0186
# Epoch 58/200
# 5/5 [==============================] - ETA: 0s - loss: 8.6599e-04 - root_mean_squared_error: 0.0294
# Epoch 58: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 8.6599e-04 - root_mean_squared_error: 0.0294 - val_loss: 6.6589e-04 - val_root_mean_squared_error: 0.0258
# Epoch 59/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0365
# Epoch 59: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - val_loss: 5.2759e-04 - val_root_mean_squared_error: 0.0230
# Epoch 60/200
# 5/5 [==============================] - ETA: 0s - loss: 8.1478e-04 - root_mean_squared_error: 0.0285
# Epoch 60: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 8.1478e-04 - root_mean_squared_error: 0.0285 - val_loss: 4.0391e-04 - val_root_mean_squared_error: 0.0201
# Epoch 61/200
# 5/5 [==============================] - ETA: 0s - loss: 9.5200e-04 - root_mean_squared_error: 0.0309
# Epoch 61: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 9.5200e-04 - root_mean_squared_error: 0.0309 - val_loss: 6.7484e-04 - val_root_mean_squared_error: 0.0260
# Epoch 62/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0324
# Epoch 62: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0011 - root_mean_squared_error: 0.0324 - val_loss: 4.5061e-04 - val_root_mean_squared_error: 0.0212
# Epoch 63/200
# 5/5 [==============================] - ETA: 0s - loss: 8.8424e-04 - root_mean_squared_error: 0.0297
# Epoch 63: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 8.8424e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 64/200
# 5/5 [==============================] - ETA: 0s - loss: 8.2842e-04 - root_mean_squared_error: 0.0288
# Epoch 64: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 8.2842e-04 - root_mean_squared_error: 0.0288 - val_loss: 3.9608e-04 - val_root_mean_squared_error: 0.0199
# Epoch 65/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0333
# Epoch 65: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0333 - val_loss: 4.3287e-04 - val_root_mean_squared_error: 0.0208
# Epoch 66/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0330
# Epoch 66: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0330 - val_loss: 4.5482e-04 - val_root_mean_squared_error: 0.0213
# Epoch 67/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0317
# Epoch 67: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0317 - val_loss: 7.5331e-04 - val_root_mean_squared_error: 0.0274
# Epoch 68/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0339
# Epoch 68: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0339 - val_loss: 5.3790e-04 - val_root_mean_squared_error: 0.0232
# Epoch 69/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0378
# Epoch 69: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0014 - root_mean_squared_error: 0.0378 - val_loss: 3.2408e-04 - val_root_mean_squared_error: 0.0180
# Epoch 70/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0335
# Epoch 70: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 8.9461e-04 - val_root_mean_squared_error: 0.0299
# Epoch 71/200
# 5/5 [==============================] - ETA: 0s - loss: 9.2199e-04 - root_mean_squared_error: 0.0304
# Epoch 71: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 9.2199e-04 - root_mean_squared_error: 0.0304 - val_loss: 3.3006e-04 - val_root_mean_squared_error: 0.0182
# Epoch 72/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0359
# Epoch 72: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0359 - val_loss: 4.1034e-04 - val_root_mean_squared_error: 0.0203
# Epoch 73/200
# 5/5 [==============================] - ETA: 0s - loss: 6.1702e-04 - root_mean_squared_error: 0.0248
# Epoch 73: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 6.1702e-04 - root_mean_squared_error: 0.0248 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# Epoch 74/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0330
# Epoch 74: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0330 - val_loss: 7.4485e-04 - val_root_mean_squared_error: 0.0273
# Epoch 75/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0362
# Epoch 75: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0362 - val_loss: 6.6220e-04 - val_root_mean_squared_error: 0.0257
# Epoch 76/200
# 5/5 [==============================] - ETA: 0s - loss: 7.9461e-04 - root_mean_squared_error: 0.0282
# Epoch 76: val_loss did not improve from 0.00025
# 5/5 [==============================] - 0s 25ms/step - loss: 7.9461e-04 - root_mean_squared_error: 0.0282 - val_loss: 7.4148e-04 - val_root_mean_squared_error: 0.0272
# Epoch 77/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0350
# Epoch 77: val_loss improved from 0.00025 to 0.00020, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0012 - root_mean_squared_error: 0.0350 - val_loss: 2.0172e-04 - val_root_mean_squared_error: 0.0142
# Epoch 78/200
# 5/5 [==============================] - ETA: 0s - loss: 8.5471e-04 - root_mean_squared_error: 0.0292
# Epoch 78: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 8.5471e-04 - root_mean_squared_error: 0.0292 - val_loss: 6.2948e-04 - val_root_mean_squared_error: 0.0251
# Epoch 79/200
# 5/5 [==============================] - ETA: 0s - loss: 9.3551e-04 - root_mean_squared_error: 0.0306
# Epoch 79: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 9.3551e-04 - root_mean_squared_error: 0.0306 - val_loss: 2.6204e-04 - val_root_mean_squared_error: 0.0162
# Epoch 80/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0347
# Epoch 80: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0347 - val_loss: 9.4056e-04 - val_root_mean_squared_error: 0.0307
# Epoch 81/200
# 5/5 [==============================] - ETA: 0s - loss: 9.4002e-04 - root_mean_squared_error: 0.0307
# Epoch 81: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 9.4002e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.0480e-04 - val_root_mean_squared_error: 0.0201
# Epoch 82/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0350
# Epoch 82: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0012 - root_mean_squared_error: 0.0350 - val_loss: 8.6369e-04 - val_root_mean_squared_error: 0.0294
# Epoch 83/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0394
# Epoch 83: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0016 - root_mean_squared_error: 0.0394 - val_loss: 4.2629e-04 - val_root_mean_squared_error: 0.0206
# Epoch 84/200
# 5/5 [==============================] - ETA: 0s - loss: 6.4068e-04 - root_mean_squared_error: 0.0253
# Epoch 84: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 6.4068e-04 - root_mean_squared_error: 0.0253 - val_loss: 4.3262e-04 - val_root_mean_squared_error: 0.0208
# Epoch 85/200
# 5/5 [==============================] - ETA: 0s - loss: 8.9772e-04 - root_mean_squared_error: 0.0300
# Epoch 85: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 8.9772e-04 - root_mean_squared_error: 0.0300 - val_loss: 6.6095e-04 - val_root_mean_squared_error: 0.0257
# Epoch 86/200
# 5/5 [==============================] - ETA: 0s - loss: 9.1218e-04 - root_mean_squared_error: 0.0302
# Epoch 86: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 9.1218e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9292e-04 - val_root_mean_squared_error: 0.0222
# Epoch 87/200
# 5/5 [==============================] - ETA: 0s - loss: 6.3807e-04 - root_mean_squared_error: 0.0253
# Epoch 87: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 6.3807e-04 - root_mean_squared_error: 0.0253 - val_loss: 5.2317e-04 - val_root_mean_squared_error: 0.0229
# Epoch 88/200
# 5/5 [==============================] - ETA: 0s - loss: 7.0932e-04 - root_mean_squared_error: 0.0266
# Epoch 88: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 7.0932e-04 - root_mean_squared_error: 0.0266 - val_loss: 6.6198e-04 - val_root_mean_squared_error: 0.0257
# Epoch 89/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0337
# Epoch 89: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0337 - val_loss: 4.2976e-04 - val_root_mean_squared_error: 0.0207
# Epoch 90/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0328
# Epoch 90: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - val_loss: 2.4984e-04 - val_root_mean_squared_error: 0.0158
# Epoch 91/200
# 5/5 [==============================] - ETA: 0s - loss: 7.5113e-04 - root_mean_squared_error: 0.0274
# Epoch 91: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 7.5113e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.4953e-04 - val_root_mean_squared_error: 0.0212
# Epoch 92/200
# 5/5 [==============================] - ETA: 0s - loss: 7.0607e-04 - root_mean_squared_error: 0.0266
# Epoch 92: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 7.0607e-04 - root_mean_squared_error: 0.0266 - val_loss: 6.5693e-04 - val_root_mean_squared_error: 0.0256
# Epoch 93/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 93: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367 - val_loss: 4.4688e-04 - val_root_mean_squared_error: 0.0211
# Epoch 94/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0335
# Epoch 94: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 6.9674e-04 - val_root_mean_squared_error: 0.0264
# Epoch 95/200
# 5/5 [==============================] - ETA: 0s - loss: 8.5833e-04 - root_mean_squared_error: 0.0293
# Epoch 95: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 8.5833e-04 - root_mean_squared_error: 0.0293 - val_loss: 5.8480e-04 - val_root_mean_squared_error: 0.0242
# Epoch 96/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0348
# Epoch 96: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0348 - val_loss: 4.4079e-04 - val_root_mean_squared_error: 0.0210
# Epoch 97/200
# 5/5 [==============================] - ETA: 0s - loss: 8.8112e-04 - root_mean_squared_error: 0.0297
# Epoch 97: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 24ms/step - loss: 8.8112e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 98/200
# 5/5 [==============================] - ETA: 0s - loss: 5.0515e-04 - root_mean_squared_error: 0.0225
# Epoch 98: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 5.0515e-04 - root_mean_squared_error: 0.0225 - val_loss: 4.4198e-04 - val_root_mean_squared_error: 0.0210
# Epoch 99/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0351
# Epoch 99: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0351 - val_loss: 3.3373e-04 - val_root_mean_squared_error: 0.0183
# Epoch 100/200
# 5/5 [==============================] - ETA: 0s - loss: 9.8439e-04 - root_mean_squared_error: 0.0314
# Epoch 100: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 9.8439e-04 - root_mean_squared_error: 0.0314 - val_loss: 6.4495e-04 - val_root_mean_squared_error: 0.0254
# Epoch 101/200
# 5/5 [==============================] - ETA: 0s - loss: 9.9288e-04 - root_mean_squared_error: 0.0315
# Epoch 101: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 9.9288e-04 - root_mean_squared_error: 0.0315 - val_loss: 2.6750e-04 - val_root_mean_squared_error: 0.0164
# Epoch 102/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 102: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 103/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0329
# Epoch 103: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 2.1039e-04 - val_root_mean_squared_error: 0.0145
# Epoch 104/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0320
# Epoch 104: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0010 - root_mean_squared_error: 0.0320 - val_loss: 5.7965e-04 - val_root_mean_squared_error: 0.0241
# Epoch 105/200
# 5/5 [==============================] - ETA: 0s - loss: 7.8481e-04 - root_mean_squared_error: 0.0280
# Epoch 105: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 24ms/step - loss: 7.8481e-04 - root_mean_squared_error: 0.0280 - val_loss: 2.7526e-04 - val_root_mean_squared_error: 0.0166
# Epoch 106/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7776e-04 - root_mean_squared_error: 0.0313
# Epoch 106: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 25ms/step - loss: 9.7776e-04 - root_mean_squared_error: 0.0313 - val_loss: 5.0953e-04 - val_root_mean_squared_error: 0.0226
# Epoch 107/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0336
# Epoch 107: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 5.0902e-04 - val_root_mean_squared_error: 0.0226
# Epoch 108/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0346
# Epoch 108: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 5.0494e-04 - val_root_mean_squared_error: 0.0225
# Epoch 109/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0335
# Epoch 109: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 3.1738e-04 - val_root_mean_squared_error: 0.0178
# Epoch 110/200
# 5/5 [==============================] - ETA: 0s - loss: 8.6252e-04 - root_mean_squared_error: 0.0294
# Epoch 110: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 8.6252e-04 - root_mean_squared_error: 0.0294 - val_loss: 9.7860e-04 - val_root_mean_squared_error: 0.0313
# Epoch 111/200
# 5/5 [==============================] - ETA: 0s - loss: 7.7041e-04 - root_mean_squared_error: 0.0278
# Epoch 111: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 7.7041e-04 - root_mean_squared_error: 0.0278 - val_loss: 4.3766e-04 - val_root_mean_squared_error: 0.0209
# Epoch 112/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0337
# Epoch 112: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0011 - root_mean_squared_error: 0.0337 - val_loss: 9.9390e-04 - val_root_mean_squared_error: 0.0315
# Epoch 113/200
# 5/5 [==============================] - ETA: 0s - loss: 8.1056e-04 - root_mean_squared_error: 0.0285
# Epoch 113: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 8.1056e-04 - root_mean_squared_error: 0.0285 - val_loss: 5.1435e-04 - val_root_mean_squared_error: 0.0227
# Epoch 114/200
# 5/5 [==============================] - ETA: 0s - loss: 8.7011e-04 - root_mean_squared_error: 0.0295
# Epoch 114: val_loss did not improve from 0.00020
# 5/5 [==============================] - 0s 26ms/step - loss: 8.7011e-04 - root_mean_squared_error: 0.0295 - val_loss: 3.5246e-04 - val_root_mean_squared_error: 0.0188
# Epoch 115/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0317
# Epoch 115: val_loss improved from 0.00020 to 0.00017, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0010 - root_mean_squared_error: 0.0317 - val_loss: 1.6665e-04 - val_root_mean_squared_error: 0.0129
# Epoch 116/200
# 5/5 [==============================] - ETA: 0s - loss: 9.9729e-04 - root_mean_squared_error: 0.0316
# Epoch 116: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.9729e-04 - root_mean_squared_error: 0.0316 - val_loss: 7.5194e-04 - val_root_mean_squared_error: 0.0274
# Epoch 117/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0349
# Epoch 117: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0012 - root_mean_squared_error: 0.0349 - val_loss: 2.2196e-04 - val_root_mean_squared_error: 0.0149
# Epoch 118/200
# 5/5 [==============================] - ETA: 0s - loss: 9.6572e-04 - root_mean_squared_error: 0.0311
# Epoch 118: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.6572e-04 - root_mean_squared_error: 0.0311 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 119/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 119: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 3.1594e-04 - val_root_mean_squared_error: 0.0178
# Epoch 120/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0348
# Epoch 120: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - root_mean_squared_error: 0.0348 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 121/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 121: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 4.0789e-04 - val_root_mean_squared_error: 0.0202
# Epoch 122/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0319
# Epoch 122: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0319 - val_loss: 3.4562e-04 - val_root_mean_squared_error: 0.0186
# Epoch 123/200
# 5/5 [==============================] - ETA: 0s - loss: 8.7962e-04 - root_mean_squared_error: 0.0297
# Epoch 123: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 8.7962e-04 - root_mean_squared_error: 0.0297 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0397
# Epoch 124/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0336
# Epoch 124: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 2.5723e-04 - val_root_mean_squared_error: 0.0160
# Epoch 125/200
# 5/5 [==============================] - ETA: 0s - loss: 8.5371e-04 - root_mean_squared_error: 0.0292
# Epoch 125: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 8.5371e-04 - root_mean_squared_error: 0.0292 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0427
# Epoch 126/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 126: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 1.9612e-04 - val_root_mean_squared_error: 0.0140
# Epoch 127/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 127: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 5.4179e-04 - val_root_mean_squared_error: 0.0233
# Epoch 128/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0327
# Epoch 128: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 1.9564e-04 - val_root_mean_squared_error: 0.0140
# Epoch 129/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0340
# Epoch 129: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0012 - root_mean_squared_error: 0.0340 - val_loss: 3.6167e-04 - val_root_mean_squared_error: 0.0190
# Epoch 130/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0320
# Epoch 130: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0320 - val_loss: 4.9203e-04 - val_root_mean_squared_error: 0.0222
# Epoch 131/200
# 5/5 [==============================] - ETA: 0s - loss: 6.8326e-04 - root_mean_squared_error: 0.0261
# Epoch 131: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 6.8326e-04 - root_mean_squared_error: 0.0261 - val_loss: 5.3110e-04 - val_root_mean_squared_error: 0.0230
# Epoch 132/200
# 5/5 [==============================] - ETA: 0s - loss: 7.5313e-04 - root_mean_squared_error: 0.0274
# Epoch 132: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 7.5313e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.6559e-04 - val_root_mean_squared_error: 0.0216
# Epoch 133/200
# 5/5 [==============================] - ETA: 0s - loss: 9.8120e-04 - root_mean_squared_error: 0.0313
# Epoch 133: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 27ms/step - loss: 9.8120e-04 - root_mean_squared_error: 0.0313 - val_loss: 2.0138e-04 - val_root_mean_squared_error: 0.0142
# Epoch 134/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0341
# Epoch 134: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 7.5223e-04 - val_root_mean_squared_error: 0.0274
# Epoch 135/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7538e-04 - root_mean_squared_error: 0.0312
# Epoch 135: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 9.7538e-04 - root_mean_squared_error: 0.0312 - val_loss: 5.9576e-04 - val_root_mean_squared_error: 0.0244
# Epoch 136/200
# 5/5 [==============================] - ETA: 0s - loss: 9.4009e-04 - root_mean_squared_error: 0.0307
# Epoch 136: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 24ms/step - loss: 9.4009e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.1276e-04 - val_root_mean_squared_error: 0.0203
# Epoch 137/200
# 5/5 [==============================] - ETA: 0s - loss: 9.6263e-04 - root_mean_squared_error: 0.0310
# Epoch 137: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.6263e-04 - root_mean_squared_error: 0.0310 - val_loss: 7.6039e-04 - val_root_mean_squared_error: 0.0276
# Epoch 138/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0323
# Epoch 138: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0323 - val_loss: 2.0915e-04 - val_root_mean_squared_error: 0.0145
# Epoch 139/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0355
# Epoch 139: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0355 - val_loss: 4.5809e-04 - val_root_mean_squared_error: 0.0214
# Epoch 140/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0343
# Epoch 140: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0012 - root_mean_squared_error: 0.0343 - val_loss: 3.4633e-04 - val_root_mean_squared_error: 0.0186
# Epoch 141/200
# 5/5 [==============================] - ETA: 0s - loss: 8.9060e-04 - root_mean_squared_error: 0.0298
# Epoch 141: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 8.9060e-04 - root_mean_squared_error: 0.0298 - val_loss: 2.8916e-04 - val_root_mean_squared_error: 0.0170
# Epoch 142/200
# 5/5 [==============================] - ETA: 0s - loss: 6.9005e-04 - root_mean_squared_error: 0.0263
# Epoch 142: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 35ms/step - loss: 6.9005e-04 - root_mean_squared_error: 0.0263 - val_loss: 3.1487e-04 - val_root_mean_squared_error: 0.0177
# Epoch 143/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0331
# Epoch 143: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0331 - val_loss: 7.4242e-04 - val_root_mean_squared_error: 0.0272
# Epoch 144/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 144: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 4.4232e-04 - val_root_mean_squared_error: 0.0210
# Epoch 145/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0361
# Epoch 145: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - root_mean_squared_error: 0.0361 - val_loss: 5.6317e-04 - val_root_mean_squared_error: 0.0237
# Epoch 146/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0320
# Epoch 146: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0320 - val_loss: 5.4808e-04 - val_root_mean_squared_error: 0.0234
# Epoch 147/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0339
# Epoch 147: val_loss did not improve from 0.00017
# ...
# 5/5 [==============================] - 0s 26ms/step - loss: 9.5749e-04 - root_mean_squared_error: 0.0309 - val_loss: 2.6377e-04 - val_root_mean_squared_error: 0.0162
# Epoch 153/200
# 5/5 [==============================] - ETA: 0s - loss: 9.1454e-04 - root_mean_squared_error: 0.0302
# Epoch 153: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.1454e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.9000e-04 - val_root_mean_squared_error: 0.0243
# Epoch 154/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0326
# Epoch 154: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 1.9172e-04 - val_root_mean_squared_error: 0.0138
# Epoch 155/200
# 5/5 [==============================] - ETA: 0s - loss: 9.6255e-04 - root_mean_squared_error: 0.0310
# Epoch 155: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.6255e-04 - root_mean_squared_error: 0.0310 - val_loss: 3.2810e-04 - val_root_mean_squared_error: 0.0181
# Epoch 156/200
# 5/5 [==============================] - ETA: 0s - loss: 6.8553e-04 - root_mean_squared_error: 0.0262
# Epoch 156: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 6.8553e-04 - root_mean_squared_error: 0.0262 - val_loss: 3.5324e-04 - val_root_mean_squared_error: 0.0188
# Epoch 157/200
# 5/5 [==============================] - ETA: 0s - loss: 8.1670e-04 - root_mean_squared_error: 0.0286
# Epoch 157: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 8.1670e-04 - root_mean_squared_error: 0.0286 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 158/200
# 5/5 [==============================] - ETA: 0s - loss: 7.1537e-04 - root_mean_squared_error: 0.0267
# Epoch 158: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 7.1537e-04 - root_mean_squared_error: 0.0267 - val_loss: 3.4109e-04 - val_root_mean_squared_error: 0.0185
# Epoch 159/200
# 5/5 [==============================] - ETA: 0s - loss: 9.2485e-04 - root_mean_squared_error: 0.0304
# Epoch 159: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 9.2485e-04 - root_mean_squared_error: 0.0304 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 160/200
# 5/5 [==============================] - ETA: 0s - loss: 8.7192e-04 - root_mean_squared_error: 0.0295
# Epoch 160: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 8.7192e-04 - root_mean_squared_error: 0.0295 - val_loss: 2.7664e-04 - val_root_mean_squared_error: 0.0166
# Epoch 161/200
# 5/5 [==============================] - ETA: 0s - loss: 5.8152e-04 - root_mean_squared_error: 0.0241
# Epoch 161: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 5.8152e-04 - root_mean_squared_error: 0.0241 - val_loss: 9.7245e-04 - val_root_mean_squared_error: 0.0312
# Epoch 162/200
# 5/5 [==============================] - ETA: 0s - loss: 7.4262e-04 - root_mean_squared_error: 0.0273
# Epoch 162: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 7.4262e-04 - root_mean_squared_error: 0.0273 - val_loss: 3.4753e-04 - val_root_mean_squared_error: 0.0186
# Epoch 163/200
# 5/5 [==============================] - ETA: 0s - loss: 8.8581e-04 - root_mean_squared_error: 0.0298
# Epoch 163: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 8.8581e-04 - root_mean_squared_error: 0.0298 - val_loss: 3.1028e-04 - val_root_mean_squared_error: 0.0176
# Epoch 164/200
# 5/5 [==============================] - ETA: 0s - loss: 7.3168e-04 - root_mean_squared_error: 0.0270
# Epoch 164: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 24ms/step - loss: 7.3168e-04 - root_mean_squared_error: 0.0270 - val_loss: 3.3918e-04 - val_root_mean_squared_error: 0.0184
# Epoch 165/200
# 5/5 [==============================] - ETA: 0s - loss: 6.9308e-04 - root_mean_squared_error: 0.0263
# Epoch 165: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 6.9308e-04 - root_mean_squared_error: 0.0263 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0368
# Epoch 166/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7837e-04 - root_mean_squared_error: 0.0313
# Epoch 166: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 9.7837e-04 - root_mean_squared_error: 0.0313 - val_loss: 3.2308e-04 - val_root_mean_squared_error: 0.0180
# Epoch 167/200
# 5/5 [==============================] - ETA: 0s - loss: 6.9853e-04 - root_mean_squared_error: 0.0264
# Epoch 167: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 6.9853e-04 - root_mean_squared_error: 0.0264 - val_loss: 2.3606e-04 - val_root_mean_squared_error: 0.0154
# Epoch 168/200
# 5/5 [==============================] - ETA: 0s - loss: 9.5970e-04 - root_mean_squared_error: 0.0310
# Epoch 168: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.5970e-04 - root_mean_squared_error: 0.0310 - val_loss: 4.2283e-04 - val_root_mean_squared_error: 0.0206
# Epoch 169/200
# 5/5 [==============================] - ETA: 0s - loss: 8.9067e-04 - root_mean_squared_error: 0.0298
# Epoch 169: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 8.9067e-04 - root_mean_squared_error: 0.0298 - val_loss: 5.8966e-04 - val_root_mean_squared_error: 0.0243
# Epoch 170/200
# 5/5 [==============================] - ETA: 0s - loss: 8.3046e-04 - root_mean_squared_error: 0.0288
# Epoch 170: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 24ms/step - loss: 8.3046e-04 - root_mean_squared_error: 0.0288 - val_loss: 3.0217e-04 - val_root_mean_squared_error: 0.0174
# Epoch 171/200
# 5/5 [==============================] - ETA: 0s - loss: 6.8298e-04 - root_mean_squared_error: 0.0261
# Epoch 171: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 24ms/step - loss: 6.8298e-04 - root_mean_squared_error: 0.0261 - val_loss: 3.7859e-04 - val_root_mean_squared_error: 0.0195
# Epoch 172/200
# 5/5 [==============================] - ETA: 0s - loss: 5.8391e-04 - root_mean_squared_error: 0.0242
# Epoch 172: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 24ms/step - loss: 5.8391e-04 - root_mean_squared_error: 0.0242 - val_loss: 3.2491e-04 - val_root_mean_squared_error: 0.0180
# Epoch 173/200
# 5/5 [==============================] - ETA: 0s - loss: 6.2068e-04 - root_mean_squared_error: 0.0249
# Epoch 173: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 6.2068e-04 - root_mean_squared_error: 0.0249 - val_loss: 5.7039e-04 - val_root_mean_squared_error: 0.0239
# Epoch 174/200
# 5/5 [==============================] - ETA: 0s - loss: 4.7808e-04 - root_mean_squared_error: 0.0219
# Epoch 174: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 4.7808e-04 - root_mean_squared_error: 0.0219 - val_loss: 2.2689e-04 - val_root_mean_squared_error: 0.0151
# Epoch 175/200
# 5/5 [==============================] - ETA: 0s - loss: 8.2920e-04 - root_mean_squared_error: 0.0288
# Epoch 175: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 27ms/step - loss: 8.2920e-04 - root_mean_squared_error: 0.0288 - val_loss: 3.6969e-04 - val_root_mean_squared_error: 0.0192
# Epoch 176/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7549e-04 - root_mean_squared_error: 0.0312
# Epoch 176: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 26ms/step - loss: 9.7549e-04 - root_mean_squared_error: 0.0312 - val_loss: 2.0461e-04 - val_root_mean_squared_error: 0.0143
# Epoch 177/200
# 5/5 [==============================] - ETA: 0s - loss: 7.6791e-04 - root_mean_squared_error: 0.0277
# Epoch 177: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 7.6791e-04 - root_mean_squared_error: 0.0277 - val_loss: 3.6482e-04 - val_root_mean_squared_error: 0.0191
# Epoch 178/200
# 5/5 [==============================] - ETA: 0s - loss: 6.8228e-04 - root_mean_squared_error: 0.0261
# Epoch 178: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 28ms/step - loss: 6.8228e-04 - root_mean_squared_error: 0.0261 - val_loss: 5.5043e-04 - val_root_mean_squared_error: 0.0235
# Epoch 179/200
# 5/5 [==============================] - ETA: 0s - loss: 9.1800e-04 - root_mean_squared_error: 0.0303
# Epoch 179: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.1800e-04 - root_mean_squared_error: 0.0303 - val_loss: 2.7815e-04 - val_root_mean_squared_error: 0.0167
# Epoch 180/200
# 5/5 [==============================] - ETA: 0s - loss: 9.2240e-04 - root_mean_squared_error: 0.0304
# Epoch 180: val_loss did not improve from 0.00017
# 5/5 [==============================] - 0s 25ms/step - loss: 9.2240e-04 - root_mean_squared_error: 0.0304 - val_loss: 6.5948e-04 - val_root_mean_squared_error: 0.0257
# Epoch 181/200
# 5/5 [==============================] - ETA: 0s - loss: 8.5891e-04 - root_mean_squared_error: 0.0293
# Epoch 181: val_loss improved from 0.00017 to 0.00016, saving model to /content/sample_data/lstm-model-tampa-24-0.4-2.h5
# 5/5 [==============================] - 0s 49ms/step - loss: 8.5891e-04 - root_mean_squared_error: 0.0293 - val_loss: 1.5867e-04 - val_root_mean_squared_error: 0.0126
# Epoch 182/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0327
# Epoch 182: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 7.7399e-04 - val_root_mean_squared_error: 0.0278
# Epoch 183/200
# 5/5 [==============================] - ETA: 0s - loss: 7.7524e-04 - root_mean_squared_error: 0.0278
# Epoch 183: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 26ms/step - loss: 7.7524e-04 - root_mean_squared_error: 0.0278 - val_loss: 1.8800e-04 - val_root_mean_squared_error: 0.0137
# Epoch 184/200
# 5/5 [==============================] - ETA: 0s - loss: 6.1246e-04 - root_mean_squared_error: 0.0247
# Epoch 184: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 6.1246e-04 - root_mean_squared_error: 0.0247 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# Epoch 185/200
# 5/5 [==============================] - ETA: 0s - loss: 5.8857e-04 - root_mean_squared_error: 0.0243
# Epoch 185: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 5.8857e-04 - root_mean_squared_error: 0.0243 - val_loss: 4.0699e-04 - val_root_mean_squared_error: 0.0202
# Epoch 186/200
# 5/5 [==============================] - ETA: 0s - loss: 9.9663e-04 - root_mean_squared_error: 0.0316
# Epoch 186: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 26ms/step - loss: 9.9663e-04 - root_mean_squared_error: 0.0316 - val_loss: 6.3292e-04 - val_root_mean_squared_error: 0.0252
# Epoch 187/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7833e-04 - root_mean_squared_error: 0.0313
# Epoch 187: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 9.7833e-04 - root_mean_squared_error: 0.0313 - val_loss: 2.6896e-04 - val_root_mean_squared_error: 0.0164
# Epoch 188/200
# 5/5 [==============================] - ETA: 0s - loss: 9.6306e-04 - root_mean_squared_error: 0.0310
# Epoch 188: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 26ms/step - loss: 9.6306e-04 - root_mean_squared_error: 0.0310 - val_loss: 3.5036e-04 - val_root_mean_squared_error: 0.0187
# Epoch 189/200
# 5/5 [==============================] - ETA: 0s - loss: 9.7654e-04 - root_mean_squared_error: 0.0312
# Epoch 189: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 9.7654e-04 - root_mean_squared_error: 0.0312 - val_loss: 4.4754e-04 - val_root_mean_squared_error: 0.0212
# Epoch 190/200
# 5/5 [==============================] - ETA: 0s - loss: 8.0586e-04 - root_mean_squared_error: 0.0284
# Epoch 190: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 27ms/step - loss: 8.0586e-04 - root_mean_squared_error: 0.0284 - val_loss: 4.2324e-04 - val_root_mean_squared_error: 0.0206
# Epoch 191/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0322
# Epoch 191: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0010 - root_mean_squared_error: 0.0322 - val_loss: 2.8756e-04 - val_root_mean_squared_error: 0.0170
# Epoch 192/200
# 5/5 [==============================] - ETA: 0s - loss: 5.9133e-04 - root_mean_squared_error: 0.0243
# Epoch 192: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 26ms/step - loss: 5.9133e-04 - root_mean_squared_error: 0.0243 - val_loss: 3.7484e-04 - val_root_mean_squared_error: 0.0194
# Epoch 193/200
# 5/5 [==============================] - ETA: 0s - loss: 6.8938e-04 - root_mean_squared_error: 0.0263
# Epoch 193: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 26ms/step - loss: 6.8938e-04 - root_mean_squared_error: 0.0263 - val_loss: 5.0384e-04 - val_root_mean_squared_error: 0.0224
# Epoch 194/200
# 5/5 [==============================] - ETA: 0s - loss: 6.0637e-04 - root_mean_squared_error: 0.0246
# Epoch 194: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 27ms/step - loss: 6.0637e-04 - root_mean_squared_error: 0.0246 - val_loss: 2.4447e-04 - val_root_mean_squared_error: 0.0156
# Epoch 195/200
# 5/5 [==============================] - ETA: 0s - loss: 7.7005e-04 - root_mean_squared_error: 0.0277
# Epoch 195: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 7.7005e-04 - root_mean_squared_error: 0.0277 - val_loss: 6.6811e-04 - val_root_mean_squared_error: 0.0258
# Epoch 196/200
# 5/5 [==============================] - ETA: 0s - loss: 9.0968e-04 - root_mean_squared_error: 0.0302
# Epoch 196: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 26ms/step - loss: 9.0968e-04 - root_mean_squared_error: 0.0302 - val_loss: 2.1035e-04 - val_root_mean_squared_error: 0.0145
# Epoch 197/200
# 5/5 [==============================] - ETA: 0s - loss: 5.6633e-04 - root_mean_squared_error: 0.0238
# Epoch 197: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 5.6633e-04 - root_mean_squared_error: 0.0238 - val_loss: 5.4743e-04 - val_root_mean_squared_error: 0.0234
# Epoch 198/200
# 5/5 [==============================] - ETA: 0s - loss: 5.9267e-04 - root_mean_squared_error: 0.0243
# Epoch 198: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 5.9267e-04 - root_mean_squared_error: 0.0243 - val_loss: 5.1357e-04 - val_root_mean_squared_error: 0.0227
# Epoch 199/200
# 5/5 [==============================] - ETA: 0s - loss: 7.0370e-04 - root_mean_squared_error: 0.0265
# Epoch 199: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 7.0370e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.4329e-04 - val_root_mean_squared_error: 0.0211
# Epoch 200/200
# 5/5 [==============================] - ETA: 0s - loss: 5.4693e-04 - root_mean_squared_error: 0.0234
# Epoch 200: val_loss did not improve from 0.00016
# 5/5 [==============================] - 0s 25ms/step - loss: 5.4693e-04 - root_mean_squared_error: 0.0234 - val_loss: 6.7340e-04 - val_root_mean_squared_error: 0.0260

# %%
# Visualize loss

# Visualize training and validation loss.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training Loss VS Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
# Load model
model = keras.models.load_model('/content/drive/MyDrive/JPM/jphomevalue/model/lstm-model-tampa-24-15(1).h5')

# %%
# Model evaluation
test_predicted_1 = model.predict(X_test)
test_predicted_2 = model.predict(X_pred)

# %%
test_predicted
# Out:
# array([[0.53790176],
#        [0.5449306 ],
#        [0.5473531 ],
#        [0.5480422 ],
#        [0.55409443],
#        [0.5666542 ],
#        [0.5845383 ],
#        [0.6032047 ],
#        [0.6208849 ],
#        [0.6377298 ],
#        [0.65375406],
#        [0.6712957 ],
#        [0.6934464 ],
#        [0.7227148 ],
#        [0.7599369 ],
#        [0.79994565],
#        [0.83564603],
#        [0.86546886],
#        [0.8879767 ]], dtype=float32)

# %%
# Apply inverse transformation
test_predicted_1= scaler.inverse_transform(test_predicted_1)
test_predicted_2 = scaler.inverse_transform(test_predicted_2)
#Y_test = scaler.inverse_transform(Y_test)
#test_predicted = test_predicted.reshape(test_predicted.shape[0],test_predicted.shape[1])
#test_predicted.shape

# %%
#Y_test.shape
#test_predicted.shape
#test_predicted = test_predicted.reshape(test_predicted.shape[0])
test_predicted
# Out:
# array([[161.14645],
#        [162.10031],
#        [162.77263],
#        [162.92213],
#        [162.82004],
#        [162.98225],
#        [163.64381],
#        [164.58076],
#        [165.49796],
#        [166.27548],
#        [167.11482],
#        [168.29442],
#        [169.6384 ],
#        [170.80418],
#        [171.70427],
#        [172.52597],
#        [173.31535],
#        [173.97609],
#        [174.38528],
#        [174.6876 ],
#        [175.13689],
#        [175.91061],
#        [177.05746],
#        [178.4576 ],
#        [180.04987],
#        [181.67686],
#        [183.25928],
#        [184.68561],
#        [185.90984],
#        [186.88373],
#        [187.60503],
#        [188.15283],
#        [188.70271],
#        [189.40659],
#        [190.43942],
#        [191.8093 ],
#        [193.56517],
#        [195.3996 ],
#        [196.82861],
#        [197.55708],
#        [197.80714],
#        [198.08295],
#        [198.59384],
#        [199.35042],
#        [200.1935 ],
#        [201.16444],
#        [202.23227],
#        [203.47615],
#        [204.80663],
#        [206.17484],
#        [207.43144],
#        [208.45952],
#        [209.19406],
#        [209.69919],
#        [210.2191 ],
#        [210.88203],
#        [211.69464],
#        [212.57913],
#        [213.34734],
#        [213.89034],
#        [214.18932],
#        [214.46129],
#        [214.98358],
#        [215.73854],
#        [216.63826],
#        [217.42567],
#        [217.98006],
#        [218.33928],
#        [218.63095],
#        [219.03133],
#        [219.65297],
#        [220.44098],
#        [221.28156],
#        [222.05031],
#        [222.838  ],
#        [223.87323],
#        [225.18396],
#        [226.50058],
#        [227.50194],
#        [228.15053],
#        [228.91621],
#        [230.18393],
#        [232.21182],
#        [234.8703 ],
#        [237.93478],
#        [241.18661],
#        [244.41565],
#        [247.64177],
#        [251.10358],
#        [255.15842],
#        [260.127  ],
#        [265.8701 ],
#        [271.81766]], dtype=float32)

# %%
# Re-populate Y_test
#X_test, Y_test = create_dmatrix(test_set, time_step)
#Y_test = Y_test.reshape(test_predicted.shape[0],1)
#Y_test = scaler.inverse_transform(Y_test)
#Y_test = Y_test.reshape(-1)
Y_test
# Out:
# array([0.69679428, 0.72444967, 0.75904152, 0.80074996, 0.84023198,
#        0.87596148, 0.91217893, 0.93992563, 0.97112559])

# %%
# Reshape Y_test to 2D
Y_test = Y_test.reshape(test_predicted_1.shape[0],1)
Y_test = scaler.inverse_transform(Y_test)

# Reshape back to 1D
Y_test = Y_test.reshape(test_predicted_1.shape[0])
Y_test
# Out:
# array([231.45046524, 231.83269223, 232.80002415, 235.63291781,
#        238.22681998, 241.91043322, 245.02071711, 248.77551829,
#        252.58926419, 256.19233444, 260.74244789, 266.31273152,
#        273.2801407 , 281.68095655, 289.63333011, 296.82988156,
#        304.12471465, 309.71339095, 315.99761266])

# %%
# Reshape Y_pred to 2D
Y_pred = Y_pred.reshape(test_predicted_2.shape[0],1)
Y_pred = scaler.inverse_transform(Y_pred)

# Reshape back to 1D
Y_pred = Y_pred.reshape(test_predicted_2.shape[0])
Y_pred
# Out:
# array([203.03163447, 204.65713353, 205.50370861, 206.36003519,
#        206.93065877, 207.71988729, 209.17786562, 210.20798447,
#        211.30094292, 212.29424721, 212.69373264, 213.22358458,
#        213.58102977, 214.8471003 , 216.4168269 , 217.1503595 ,
#        218.3270374 , 218.52542493, 219.14463903, 219.79275285,
#        220.57041794, 221.70518811, 222.92313866, 223.79606296,
#        224.7245786 , 225.43047908, 227.02634156, 229.16505202,
#        230.73607244, 231.45046524, 231.83269223, 232.80002415,
#        235.63291781, 238.22681998, 241.91043322, 245.02071711,
#        248.77551829, 252.58926419, 256.19233444, 260.74244789,
#        266.31273152, 273.2801407 , 281.68095655, 289.63333011,
#        296.82988156, 304.12471465, 309.71339095, 315.99761266])

# %%
# Calculate RMSE
print(math.sqrt(mean_squared_error(Y_test,test_predicted_1)))
print(math.sqrt(mean_squared_error(Y_pred,test_predicted_2)))
# Out:
# 10.715759342193525
# 6.8613680637712475

# %%
#test_predicted = test_predicted.reshape(-1, 1)
#test_predicted
#test_predicted
print(test_predicted_2[47])
print(Y_pred[47])
# Out:
# [299.24994]
# 315.997612656474

# %%
from numpy import savetxt
np.savetxt('test_predicted.txt', test_predicted_2, fmt='%s')
files.download('test_predicted.txt')

# %%
training_predicted = model.predict(X_train)
validation_predicted = model.predict(X_val)

# %%
training_predicted = scaler.inverse_transform(training_predicted)
#training_predicted.shape
validation_predicted = scaler.inverse_transform(validation_predicted)
#validation_predicted.shape
print(scaler.inverse_transform(validation_set))
# Out:
# [[177.79124755]
#  [179.30300157]
#  [180.23606116]
#  [181.27301702]
#  [181.906548  ]
#  [182.5129086 ]
#  [183.23624805]
#  [184.32702694]
#  [185.48524594]
#  [187.29957722]
#  [188.81726327]
#  [191.25350939]
#  [192.0606832 ]
#  [192.1530866 ]
#  [192.12507583]
#  [193.18992211]
#  [194.80182656]
#  [195.52227904]
#  [196.56334956]
#  [197.21897219]
#  [198.96773997]
#  [200.01970483]
#  [201.95115829]
#  [203.03163447]
#  [204.65713353]
#  [205.50370861]
#  [206.36003519]
#  [206.93065877]]

# %%
# Plotting everything together
# Setting the intervals 

# shift training predictions for plotting
training_predicted_plot = np.empty_like(df1)
training_predicted_plot[:, :] = np.nan
#training_predicted.shape
#training_predicted_plot[14:167, :] = training_predicted
training_predicted_plot[24:167, :] = training_predicted

#training_predicted_plot[24:143, :] = training_predicted
# shift validation predictions for plotting
val_predicted_plot = np.empty_like(df1)
val_predicted_plot[:, :] = np.nan
#validation_predicted.shape
#val_predicted_plot[181:214, :] = validation_predicted
#val_predicted_plot[192:203, :] = validation_predicted
#val_predicted_plot[168:191, :] = validation_predicted
val_predicted_plot[192:195, :] = validation_predicted
# shift test predictions for plotting
test_predicted_plot = np.empty_like(df1)
test_predicted_plot[:, :] = np.nan
#test_predicted.shape
#test_predicted_plot[230:239, :] = test_predicted
#test_predicted_plot[228:239, :] = test_predicted
#test_predicted_plot[216:239, :] = test_predicted
test_predicted_plot[220:239, :] = test_predicted

# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1), label = "Real Data")
plt.plot(test_predicted_plot, label = "Predicted Data for Test Set")
plt.plot(val_predicted_plot, label = "Predicted Data for Validation Set")
plt.plot(training_predicted_plot, label = "Predicted Data for Training Set")
plt.legend()
plt.show()

# %%
#math.sqrt(mean_squared_error(Y_test,test_predicted))
#print(scaler.inverse_transform(train_set))
#print(scaler.inverse_transform(training_predicted))
#train_set_invers = scaler.inverse_transform(Y_train)
#math.sqrt(mean_squared_error(_test,test_predicted))
#Y_train_sh = Y_train.reshape(training_predicted.shape[0],1)
#train_set_invers = scaler.inverse_transform(Y_train_sh)

#Y_train_d = Y_train.reshape(-1, 1)
#train_set_invers = scaler.inverse_transform(Y_train_d)
#math.sqrt(mean_squared_error(train_set_invers, training_predicted))
#print(scaler.inverse_transform(X_test))
#test_predicted
# Out:
# array([[237.0811 ],
#        [240.32011],
#        [243.95862],
#        [248.07315],
#        [252.65337],
#        [257.63763],
#        [262.94397],
#        [268.51364],
#        [274.28806]], dtype=float32)

# %%
# Create new array for future predictions

# Explanation. Since we have been predicting using timestep = 24, meaning we have used the past 24 prices to predict the 25th, now we will use the test_set data as that is the latest data to predict further INTO THE UNKNOWN!
# The size of the future_input array needs to be equal to timestep, so if you change the test_data size and timestep make sure to reflect those changes here as well.

pred_input=df1[196:220].reshape(1,-1)
print(scaler.inverse_transform(pred_input))
# Out:
# [[207.71988729 209.17786562 210.20798447 211.30094292 212.29424721
#   212.69373264 213.22358458 213.58102977 214.8471003  216.4168269
#   217.1503595  218.3270374  218.52542493 219.14463903 219.79275285
#   220.57041794 221.70518811 222.92313866 223.79606296 224.7245786
#   225.43047908 227.02634156 229.16505202 230.73607244]]

# %%
# Add that to temp input
temp_input=list(pred_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.4335474119811934,
#  0.4407859952970056,
#  0.4459003381674812,
#  0.45132666767068386,
#  0.45625823331864723,
#  0.4582416020009469,
#  0.4608722154630688,
#  0.46264686242109343,
#  0.4689326602366416,
#  0.47672605230864173,
#  0.4803679012609835,
#  0.48620988179066515,
#  0.48719483790195006,
#  0.4902691173302788,
#  0.49348687840513594,
#  0.49734783670823635,
#  0.5029817533584996,
#  0.5090286447137397,
#  0.5133625467560822,
#  0.5179724491413268,
#  0.5214771099328371,
#  0.5294002616466654,
#  0.5400185496809672,
#  0.547818365302882]

# %%
# Predict in the future

from numpy import array

list_output=[]
n_steps=24
i=0
while(i<12):
    
    if(len(temp_input)>24):
        print('Entering main condition')
        #print(temp_input)
        pred_input=np.array(temp_input[1:]) # Shift one to the right
        print("{} month input {}".format(i,pred_input))
        pred_input=pred_input.reshape(1,-1)
        pred_input = pred_input.reshape(1, n_steps, 1)
        print('Pred_input shape is:', pred_input.shape)
        fut_pred = model.predict(pred_input, verbose=0)
        print("{} month output {}".format(i,fut_pred))
        temp_input.extend(fut_pred[0].tolist()) # Add that prediction to the temp input list as that will be used in the next prediction 
        temp_input=temp_input[1:] #Shift the temp_input to remove the first element which was already used in a sequence
        #print(temp_input)
        list_output.extend(fut_pred.tolist())
        i=i+1
    else:
        print('Entering else condition')
        pred_input = pred_input.reshape((1, n_steps,1))
        fut_pred = model.predict(pred_input, verbose=0)
        print('The predicted value is:',fut_pred[0])
        temp_input.extend(fut_pred[0].tolist())
        print(len(temp_input))
        list_output.extend(fut_pred.tolist())
        i=i+1
    

print(list_output)
# Out:
# Entering else condition
# The predicted value is: [0.5379018]
# 25
# Entering main condition
# 1 month input [0.440786   0.44590034 0.45132667 0.45625823 0.4582416  0.46087222
#  0.46264686 0.46893266 0.47672605 0.4803679  0.48620988 0.48719484
#  0.49026912 0.49348688 0.49734784 0.50298175 0.50902864 0.51336255
#  0.51797245 0.52147711 0.52940026 0.54001855 0.54781837 0.53790182]
# Pred_input shape is: (1, 24, 1)
# 1 month output [[0.5389276]]
# Entering main condition
# 2 month input [0.44590034 0.45132667 0.45625823 0.4582416  0.46087222 0.46264686
#  0.46893266 0.47672605 0.4803679  0.48620988 0.48719484 0.49026912
#  0.49348688 0.49734784 0.50298175 0.50902864 0.51336255 0.51797245
#  0.52147711 0.52940026 0.54001855 0.54781837 0.53790182 0.53892761]
# Pred_input shape is: (1, 24, 1)
# 2 month output [[0.53365725]]
# Entering main condition
# 3 month input [0.45132667 0.45625823 0.4582416  0.46087222 0.46264686 0.46893266
#  0.47672605 0.4803679  0.48620988 0.48719484 0.49026912 0.49348688
#  0.49734784 0.50298175 0.50902864 0.51336255 0.51797245 0.52147711
#  0.52940026 0.54001855 0.54781837 0.53790182 0.53892761 0.53365725]
# Pred_input shape is: (1, 24, 1)
# 3 month output [[0.52585226]]
# Entering main condition
# 4 month input [0.45625823 0.4582416  0.46087222 0.46264686 0.46893266 0.47672605
#  0.4803679  0.48620988 0.48719484 0.49026912 0.49348688 0.49734784
#  0.50298175 0.50902864 0.51336255 0.51797245 0.52147711 0.52940026
#  0.54001855 0.54781837 0.53790182 0.53892761 0.53365725 0.52585226]
# Pred_input shape is: (1, 24, 1)
# 4 month output [[0.51715136]]
# Entering main condition
# 5 month input [0.4582416  0.46087222 0.46264686 0.46893266 0.47672605 0.4803679
#  0.48620988 0.48719484 0.49026912 0.49348688 0.49734784 0.50298175
#  0.50902864 0.51336255 0.51797245 0.52147711 0.52940026 0.54001855
#  0.54781837 0.53790182 0.53892761 0.53365725 0.52585226 0.51715136]
# Pred_input shape is: (1, 24, 1)
# 5 month output [[0.50802326]]
# Entering main condition
# 6 month input [0.46087222 0.46264686 0.46893266 0.47672605 0.4803679  0.48620988
#  0.48719484 0.49026912 0.49348688 0.49734784 0.50298175 0.50902864
#  0.51336255 0.51797245 0.52147711 0.52940026 0.54001855 0.54781837
#  0.53790182 0.53892761 0.53365725 0.52585226 0.51715136 0.50802326]
# Pred_input shape is: (1, 24, 1)
# 6 month output [[0.4987195]]
# Entering main condition
# 7 month input [0.46264686 0.46893266 0.47672605 0.4803679  0.48620988 0.48719484
#  0.49026912 0.49348688 0.49734784 0.50298175 0.50902864 0.51336255
#  0.51797245 0.52147711 0.52940026 0.54001855 0.54781837 0.53790182
#  0.53892761 0.53365725 0.52585226 0.51715136 0.50802326 0.49871951]
# Pred_input shape is: (1, 24, 1)
# 7 month output [[0.48947054]]
# Entering main condition
# 8 month input [0.46893266 0.47672605 0.4803679  0.48620988 0.48719484 0.49026912
#  0.49348688 0.49734784 0.50298175 0.50902864 0.51336255 0.51797245
#  0.52147711 0.52940026 0.54001855 0.54781837 0.53790182 0.53892761
#  0.53365725 0.52585226 0.51715136 0.50802326 0.49871951 0.48947054]
# Pred_input shape is: (1, 24, 1)
# 8 month output [[0.48044008]]
# Entering main condition
# 9 month input [0.47672605 0.4803679  0.48620988 0.48719484 0.49026912 0.49348688
#  0.49734784 0.50298175 0.50902864 0.51336255 0.51797245 0.52147711
#  0.52940026 0.54001855 0.54781837 0.53790182 0.53892761 0.53365725
#  0.52585226 0.51715136 0.50802326 0.49871951 0.48947054 0.48044008]
# Pred_input shape is: (1, 24, 1)
# 9 month output [[0.4717039]]
# Entering main condition
# 10 month input [0.4803679  0.48620988 0.48719484 0.49026912 0.49348688 0.49734784
#  0.50298175 0.50902864 0.51336255 0.51797245 0.52147711 0.52940026
#  0.54001855 0.54781837 0.53790182 0.53892761 0.53365725 0.52585226
#  0.51715136 0.50802326 0.49871951 0.48947054 0.48044008 0.47170389]
# Pred_input shape is: (1, 24, 1)
# 10 month output [[0.46328688]]
# Entering main condition
# 11 month input [0.48620988 0.48719484 0.49026912 0.49348688 0.49734784 0.50298175
#  0.50902864 0.51336255 0.51797245 0.52147711 0.52940026 0.54001855
#  0.54781837 0.53790182 0.53892761 0.53365725 0.52585226 0.51715136
#  0.50802326 0.49871951 0.48947054 0.48044008 0.47170389 0.46328688]
# Pred_input shape is: (1, 24, 1)
# 11 month output [[0.45520097]]
# [[0.5379018187522888], [0.5389276146888733], [0.5336572527885437], [0.5258522629737854], [0.5171513557434082], [0.5080232620239258], [0.4987195134162903], [0.48947054147720337], [0.48044008016586304], [0.4717038869857788], [0.4632868766784668], [0.4552009701728821]]

# %%
month_new = np.arange(1, 24)
month_pred = np.arange(24,36)

# %%
plt.plot(month_new,scaler.inverse_transform(df1[196:219]))
plt.plot(month_pred,scaler.inverse_transform(list_output))

# %%
df3 = df1[:217].tolist()
df3.extend(list_output)
plt.plot(df3)

# %%
print(scaler.inverse_transform(list_output))
# Out:
# [[248.84581371]
#  [248.71309372]
#  [246.15000717]
#  [242.59277527]
#  [238.69084356]
#  [234.67559262]
#  [230.67927424]
#  [226.79973265]
#  [223.09095625]
#  [219.56803585]
#  [216.22542496]
#  [213.05312304]]

# %%
print(scaler.inverse_transform(df1[229:242]))
# Out:
# [[256.19233444]
#  [260.74244789]
#  [266.31273152]
#  [273.2801407 ]
#  [281.68095655]
#  [289.63333011]
#  [296.82988156]
#  [304.12471465]
#  [309.71339095]
#  [315.99761266]
#  [321.81342782]]

# %%
df_out = df1[:193].tolist()
df_out.extend(list_output)

print(scaler.inverse_transform(df_out))

# %%
math.sqrt(mean_squared_error(scaler.inverse_transform(df1[228:242]),scaler.inverse_transform(list_output)))
# Out:
# 63.97082842175826

# %%
df3=scaler.inverse_transform(df3).tolist()
plt.plot(df3)

# %%
# Make copy of original data
df_orig33 = pd.read_csv('/content/Model_Tampa_Prediction_6months.csv')
df_orig33
# Out:
#            DATE      TPXRSA
# 0    2002-01-01  120.395793
# 1    2002-02-01  120.700034
# 2    2002-03-01  122.958147
# 3    2002-04-01  123.707047
# 4    2002-05-01  124.950321
# ..          ...         ...
# 241  2022-02-01  295.493895
# 242  2022-03-01  285.777483
# 243  2022-04-01  272.348633
# 244  2022-05-01  257.288102
# 245  2022-06-01  241.530343
#
# [246 rows x 2 columns]

# %%
output1_df = pd.DataFrame(df3, columns=['Sale Price'])
output1_df
# Out:
#      Sale Price
# 0    120.395793
# 1    120.700034
# 2    122.958147
# 3    123.707047
# 4    124.950321
# ..          ...
# 241  295.493895
# 242  285.777483
# 243  272.348633
# 244  257.288102
# 245  241.530343
#
# [246 rows x 1 columns]

# %%
test_df = df_orig.copy()
test_df['TXP'] = output1_df

# %%
result = [output1_df, df_orig]
new_df = pd.concat(result, axis =1)

# %%
new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
new_df
# Out:
#      Sale Price        DATE
# 0    120.395793  2002-01-01
# 1    120.700034  2002-02-01
# 2    122.958147  2002-03-01
# 3    123.707047  2002-04-01
# 4    124.950321  2002-05-01
# ..          ...         ...
# 241  295.493895         NaN
# 242  285.777483         NaN
# 243  272.348633         NaN
# 244  257.288102         NaN
# 245  241.530343         NaN
#
# [246 rows x 2 columns]

# %%
#new_df['DATE'] = pd.to_datetime(new_df['DATE'])
#new_df = new_df.set_index('DATE')
#new_df.index = new_df.index.to_period("1M")

# %%
#new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
#new_date_range = pd.date_range(start="2002-01", end='2023-01', freq="M")
#new_date_range = pd.Series(pd.date_range("1/1/2002", freq="M", periods=len(df3)))
#new_df = new_df.reindex(new_date_range, fill_value=0)

# %%
#new_df['Sale Price'] = output1_df['Sale Price']

#new_df = new_df.append(output1_df, ignore_index = True)

# %%
#df_orig1 = df_orig.copy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-a5f9668e6f2b> in <module>()
#       1 df_orig1 = df_orig.copy()
# ----> 2 df_orig1 = pd.concat(output1_df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     328         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     329             raise TypeError(
# --> 330                 "first argument must be an iterable of pandas "
#     331                 f'objects, you passed an object of type "{type(objs).__name__}"'
#     332             )
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
result1 = [new_df, output_df]
new_df = pd.concat(result1, axis =1)

# %%
# Out:
#            DATE      TPXRSA  Sale Price
# 0    2002-01-01  120.395793         NaN
# 1    2002-02-01  120.700034         NaN
# 2    2002-03-01  122.958147         NaN
# 3    2002-04-01  123.707047         NaN
# 4    2002-05-01  124.950321         NaN
# ..          ...         ...         ...
# 481         NaN         NaN  295.493895
# 482         NaN         NaN  285.777483
# 483         NaN         NaN  272.348633
# 484         NaN         NaN  257.288102
# 485         NaN         NaN  241.530343
#
# [486 rows x 3 columns]
