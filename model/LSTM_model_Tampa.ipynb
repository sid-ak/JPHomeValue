# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive, files # google colab specific
import requests
import pandas as pd
import os
import warnings
import sys
import matplotlib.pyplot as plt
import json
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from tensorflow import keras
from keras import layers
import math
from sklearn.metrics import mean_squared_error

# %%
# Read in the csv file that contains the time series data of the Shiller Index
# Create the dataframe

df = pd.read_csv('/content/TPXRSA.csv')
df.head()
# Out:
#          DATE      TPXRSA
# 0  2002-01-01  120.395793
# 1  2002-02-01  120.700034
# 2  2002-03-01  122.958147
# 3  2002-04-01  123.707047
# 4  2002-05-01  124.950321

# %%
df.tail()
# Out:
#            DATE      TPXRSA
# 235  2021-08-01  296.829882
# 236  2021-09-01  304.124715
# 237  2021-10-01  309.713391
# 238  2021-11-01  315.997613
# 239  2021-12-01  321.813428

# %%
# Reset the index based on the prices
df1 = df.reset_index()['TPXRSA']
df1
# Out:
# 0      120.395793
# 1      120.700034
# 2      122.958147
# 3      123.707047
# 4      124.950321
#           ...
# 235    296.829882
# 236    304.124715
# 237    309.713391
# 238    315.997613
# 239    321.813428
# Name: TPXRSA, Length: 240, dtype: float64

# %%
# Visualize the data for reference. 
plt.plot(df1)

# %%
# Normalize the data with the range 0 - 1
scaler = MinMaxScaler(feature_range=(0,1))

# Apply the scaler to the dataframe
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# Print df1 to check the change
print(df1)

# %%
# Split data into train, validation and test set. Ratio: 6/1/3
training_size = int(len(df1)*0.7)
validation_size = int(len(df1)*0.82) 
test_size = int(len(df1))

train_set = df1[0:training_size,:]
validation_set = df1[training_size:validation_size,:]
test_set = df1[validation_size:test_size,:1]

# %%
df1.shape
# Out:
# (240, 1)

# %%
# Check sizes and set sizes
#training_size
#validation_size 
#test_size
print(train_set.shape)
print(validation_set.shape)
print(test_set.shape)
# Out:
# (168, 1)
# (28, 1)
# (44, 1)

# %%
# The current array of values needs to be converted into a dataset matrix
def create_dmatrix(dataset, time_step=1):
  data_X, data_Y = [], []
  for i in range(len(dataset)-time_step-1):
    k = dataset[i:(i + time_step), 0]
    data_X.append(k)
    data_Y.append(dataset[i + time_step, 0])
  return np.array(data_X), np.array(data_Y)

# %%
# Using the function already created for the conversion, convert training, validation and test sets. 
time_step = 24
X_train, Y_train = create_dmatrix(train_set, time_step)
X_val, Y_val = create_dmatrix(validation_set, time_step)
X_test, Y_test = create_dmatrix(test_set, time_step)

print('X Train set shape:', X_train.shape)
print('y Train set shape:', Y_train.shape)

print('X Validation set shape:', X_val.shape)
print('y Validation set shape:', Y_val.shape)

print('X Test set shape:', X_test.shape)
print('y Test set shape:', Y_test.shape)
# Out:
# X Train set shape: (143, 24)
# y Train set shape: (143,)
# X Validation set shape: (3, 24)
# y Validation set shape: (3,)
# X Test set shape: (19, 24)
# y Test set shape: (19,)

# %%
# Check the matrixes created
X_test

# %%
# In order to feed the dataset to the neural network the data must be in 3D

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Hyperparameters
batch_size = 16
epochs = 200
learning_rate = 0.001

# %%
# LSTM MODEL ARCHITECTURE

model = keras.models.Sequential([
  keras.Input(shape=(24, 1)),
  # Masking layer, to ignore zeros.
  # keras.layers.Masking(),
  # 4 LSTM Layers with 16 units.
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250, return_sequences=True),
  keras.layers.LSTM(units=250),
  keras.layers.Dropout(0.5),
  # Fully Connected Layer
  keras.layers.Dense(units=1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 250)           252000
#
#  lstm_1 (LSTM)               (None, 24, 250)           501000
#
#  lstm_2 (LSTM)               (None, 24, 250)           501000
#
#  lstm_3 (LSTM)               (None, 250)               501000
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense (Dense)               (None, 1)                 251
#
# =================================================================
# Total params: 1,755,251
# Trainable params: 1,755,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Loss and Optimizer Functions
mse = tf.keras.losses.MeanSquaredError()
rmse = tf.keras.metrics.RootMeanSquaredError()
model.compile(loss=mse, optimizer=keras.optimizers.Adam(learning_rate=learning_rate), metrics=[rmse])

# %%
# Callbacks.

callbacks = [EarlyStopping(monitor='val_loss', patience=100, verbose=1), 
            ModelCheckpoint(filepath='/content/sample_data/lstm-model-tampa-24-16.h5', verbose=1, monitor='val_loss', save_best_only=True, save_weights_only=False)]

# Train the model
history = model.fit(x=X_train, y=Y_train, validation_data =(X_val, Y_val), epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=callbacks)
# Out:
# Epoch 1/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0302 - root_mean_squared_error: 0.1739
# Epoch 1: val_loss improved from inf to 0.01388, saving model to /content/sample_data/lstm-model-tampa-24-16.h5
# 9/9 [==============================] - 16s 608ms/step - loss: 0.0302 - root_mean_squared_error: 0.1739 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 2/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0136 - root_mean_squared_error: 0.1168
# Epoch 2: val_loss improved from 0.01388 to 0.00867, saving model to /content/sample_data/lstm-model-tampa-24-16.h5
# 9/9 [==============================] - 3s 360ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0931
# Epoch 3/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0076 - root_mean_squared_error: 0.0874
# Epoch 3: val_loss improved from 0.00867 to 0.00188, saving model to /content/sample_data/lstm-model-tampa-24-16.h5
# 9/9 [==============================] - 3s 366ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 4/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0048 - root_mean_squared_error: 0.0693
# Epoch 4: val_loss did not improve from 0.00188
# 9/9 [==============================] - 3s 347ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0520
# Epoch 5/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0039 - root_mean_squared_error: 0.0624
# Epoch 5: val_loss improved from 0.00188 to 0.00004, saving model to /content/sample_data/lstm-model-tampa-24-16.h5
# 9/9 [==============================] - 3s 337ms/step - loss: 0.0039 - root_mean_squared_error: 0.0624 - val_loss: 4.2196e-05 - val_root_mean_squared_error: 0.0065
# Epoch 6/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0026 - root_mean_squared_error: 0.0514
# Epoch 6: val_loss did not improve from 0.00004
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 1.6846e-04 - val_root_mean_squared_error: 0.0130
# Epoch 7/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0023 - root_mean_squared_error: 0.0476
# Epoch 7: val_loss did not improve from 0.00004
# 9/9 [==============================] - 3s 348ms/step - loss: 0.0023 - root_mean_squared_error: 0.0476 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0393
# Epoch 8/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0023 - root_mean_squared_error: 0.0475
# Epoch 8: val_loss did not improve from 0.00004
# 9/9 [==============================] - 3s 333ms/step - loss: 0.0023 - root_mean_squared_error: 0.0475 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0531
# Epoch 9/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0523
# Epoch 9: val_loss did not improve from 0.00004
# 9/9 [==============================] - 3s 329ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 6.5718e-05 - val_root_mean_squared_error: 0.0081
# Epoch 10/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0463
# Epoch 10: val_loss improved from 0.00004 to 0.00001, saving model to /content/sample_data/lstm-model-tampa-24-16.h5
# 9/9 [==============================] - 3s 334ms/step - loss: 0.0021 - root_mean_squared_error: 0.0463 - val_loss: 9.0275e-06 - val_root_mean_squared_error: 0.0030
# Epoch 11/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0398
# Epoch 11: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0016 - root_mean_squared_error: 0.0398 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0684
# Epoch 12/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0024 - root_mean_squared_error: 0.0488
# Epoch 12: val_loss did not improve from 0.00001
# 9/9 [==============================] - 4s 474ms/step - loss: 0.0024 - root_mean_squared_error: 0.0488 - val_loss: 4.7624e-05 - val_root_mean_squared_error: 0.0069
# Epoch 13/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0523
# Epoch 13: val_loss did not improve from 0.00001
# 9/9 [==============================] - 3s 339ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 6.8204e-04 - val_root_mean_squared_error: 0.0261
# Epoch 14/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0022 - root_mean_squared_error: 0.0466
# Epoch 14: val_loss improved from 0.00001 to 0.00000, saving model to /content/sample_data/lstm-model-tampa-24-16.h5
# 9/9 [==============================] - 3s 351ms/step - loss: 0.0022 - root_mean_squared_error: 0.0466 - val_loss: 3.9058e-06 - val_root_mean_squared_error: 0.0020
# Epoch 15/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0027 - root_mean_squared_error: 0.0520
# Epoch 15: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 347ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 4.8591e-05 - val_root_mean_squared_error: 0.0070
# Epoch 16/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0415
# Epoch 16: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 341ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# Epoch 17/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0388
# Epoch 17: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 336ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 3.0105e-05 - val_root_mean_squared_error: 0.0055
# Epoch 18/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0366
# Epoch 18: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 370ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 7.5033e-05 - val_root_mean_squared_error: 0.0087
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0422
# Epoch 19: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 352ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 8.9975e-05 - val_root_mean_squared_error: 0.0095
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0395
# Epoch 20: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 372ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395 - val_loss: 4.0189e-04 - val_root_mean_squared_error: 0.0200
# Epoch 21/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0368
# Epoch 21: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 374ms/step - loss: 0.0014 - root_mean_squared_error: 0.0368 - val_loss: 1.0182e-04 - val_root_mean_squared_error: 0.0101
# Epoch 22/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 22: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 410ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 2.7649e-04 - val_root_mean_squared_error: 0.0166
# Epoch 23/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0403
# Epoch 23: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 347ms/step - loss: 0.0016 - root_mean_squared_error: 0.0403 - val_loss: 4.8719e-04 - val_root_mean_squared_error: 0.0221
# Epoch 24/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0339
# Epoch 24: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 348ms/step - loss: 0.0011 - root_mean_squared_error: 0.0339 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0418
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0405
# Epoch 25: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 349ms/step - loss: 0.0016 - root_mean_squared_error: 0.0405 - val_loss: 1.6297e-04 - val_root_mean_squared_error: 0.0128
# Epoch 26/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 26: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 399ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 4.2465e-05 - val_root_mean_squared_error: 0.0065
# Epoch 27/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0401
# Epoch 27: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 390ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - val_loss: 6.4641e-04 - val_root_mean_squared_error: 0.0254
# Epoch 28/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0352
# Epoch 28: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 379ms/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 4.3098e-06 - val_root_mean_squared_error: 0.0021
# Epoch 29/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0368
# Epoch 29: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 356ms/step - loss: 0.0014 - root_mean_squared_error: 0.0368 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 30/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0344
# Epoch 30: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 354ms/step - loss: 0.0012 - root_mean_squared_error: 0.0344 - val_loss: 5.7434e-04 - val_root_mean_squared_error: 0.0240
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0458
# Epoch 31: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 348ms/step - loss: 0.0021 - root_mean_squared_error: 0.0458 - val_loss: 4.7092e-04 - val_root_mean_squared_error: 0.0217
# Epoch 32/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0459
# Epoch 32: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 339ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459 - val_loss: 2.0597e-04 - val_root_mean_squared_error: 0.0144
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0404
# Epoch 33: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 355ms/step - loss: 0.0016 - root_mean_squared_error: 0.0404 - val_loss: 4.0788e-04 - val_root_mean_squared_error: 0.0202
# Epoch 34/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0411
# Epoch 34: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0017 - root_mean_squared_error: 0.0411 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 35/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0433
# Epoch 35: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0019 - root_mean_squared_error: 0.0433 - val_loss: 3.1562e-04 - val_root_mean_squared_error: 0.0178
# Epoch 36/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0346
# Epoch 36: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 318ms/step - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0472
# Epoch 37/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0431
# Epoch 37: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 356ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0019 - root_mean_squared_error: 0.0431
# Epoch 38: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 344ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 39/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0029 - root_mean_squared_error: 0.0538
# Epoch 39: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 333ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 40/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0030 - root_mean_squared_error: 0.0545
# Epoch 40: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 334ms/step - loss: 0.0030 - root_mean_squared_error: 0.0545 - val_loss: 1.3868e-04 - val_root_mean_squared_error: 0.0118
# Epoch 41/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0411
# Epoch 41: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 311ms/step - loss: 0.0017 - root_mean_squared_error: 0.0411 - val_loss: 3.4548e-04 - val_root_mean_squared_error: 0.0186
# Epoch 42/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0018 - root_mean_squared_error: 0.0424
# Epoch 42: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 339ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 6.9668e-05 - val_root_mean_squared_error: 0.0083
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0383
# Epoch 43: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 337ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 4.0220e-05 - val_root_mean_squared_error: 0.0063
# Epoch 44/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0377
# Epoch 44: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 347ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 8.2905e-04 - val_root_mean_squared_error: 0.0288
# Epoch 45/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 45: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 348ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0573
# Epoch 46/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0372
# Epoch 46: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 323ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0568
# Epoch 47/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0364
# Epoch 47: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 340ms/step - loss: 0.0013 - root_mean_squared_error: 0.0364 - val_loss: 1.7233e-04 - val_root_mean_squared_error: 0.0131
# Epoch 48/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0336
# Epoch 48: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 343ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 5.2667e-04 - val_root_mean_squared_error: 0.0229
# Epoch 49/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0339
# Epoch 49: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 326ms/step - loss: 0.0011 - root_mean_squared_error: 0.0339 - val_loss: 2.9772e-04 - val_root_mean_squared_error: 0.0173
# Epoch 50/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0327
# Epoch 50: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 332ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 3.2001e-05 - val_root_mean_squared_error: 0.0057
# Epoch 51/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0332
# Epoch 51: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 328ms/step - loss: 0.0011 - root_mean_squared_error: 0.0332 - val_loss: 1.2305e-04 - val_root_mean_squared_error: 0.0111
# Epoch 52/200
# 9/9 [==============================] - ETA: 0s - loss: 9.9770e-04 - root_mean_squared_error: 0.0316
# Epoch 52: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 324ms/step - loss: 9.9770e-04 - root_mean_squared_error: 0.0316 - val_loss: 5.0719e-04 - val_root_mean_squared_error: 0.0225
# Epoch 53/200
# 9/9 [==============================] - ETA: 0s - loss: 6.5512e-04 - root_mean_squared_error: 0.0256
# Epoch 53: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 343ms/step - loss: 6.5512e-04 - root_mean_squared_error: 0.0256 - val_loss: 8.6340e-04 - val_root_mean_squared_error: 0.0294
# Epoch 54/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0012 - root_mean_squared_error: 0.0345
# Epoch 54: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 321ms/step - loss: 0.0012 - root_mean_squared_error: 0.0345 - val_loss: 8.5190e-05 - val_root_mean_squared_error: 0.0092
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0366
# Epoch 55: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 353ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366 - val_loss: 5.2248e-04 - val_root_mean_squared_error: 0.0229
# Epoch 56/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0329
# Epoch 56: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 344ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - val_loss: 4.5636e-05 - val_root_mean_squared_error: 0.0068
# Epoch 57/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8725e-04 - root_mean_squared_error: 0.0281
# Epoch 57: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 332ms/step - loss: 7.8725e-04 - root_mean_squared_error: 0.0281 - val_loss: 1.7950e-04 - val_root_mean_squared_error: 0.0134
# Epoch 58/200
# 9/9 [==============================] - ETA: 0s - loss: 9.4561e-04 - root_mean_squared_error: 0.0308
# Epoch 58: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 337ms/step - loss: 9.4561e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.4025e-04 - val_root_mean_squared_error: 0.0232
# Epoch 59/200
# 9/9 [==============================] - ETA: 0s - loss: 8.3115e-04 - root_mean_squared_error: 0.0288
# Epoch 59: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 332ms/step - loss: 8.3115e-04 - root_mean_squared_error: 0.0288 - val_loss: 8.0323e-05 - val_root_mean_squared_error: 0.0090
# Epoch 60/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0318
# Epoch 60: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 325ms/step - loss: 0.0010 - root_mean_squared_error: 0.0318 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0376
# Epoch 61/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 61: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 355ms/step - loss: 0.0010 - root_mean_squared_error: 0.0321 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 62/200
# 9/9 [==============================] - ETA: 0s - loss: 8.5050e-04 - root_mean_squared_error: 0.0292
# Epoch 62: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 340ms/step - loss: 8.5050e-04 - root_mean_squared_error: 0.0292 - val_loss: 1.2124e-04 - val_root_mean_squared_error: 0.0110
# Epoch 63/200
# 9/9 [==============================] - ETA: 0s - loss: 8.4977e-04 - root_mean_squared_error: 0.0292
# Epoch 63: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 348ms/step - loss: 8.4977e-04 - root_mean_squared_error: 0.0292 - val_loss: 1.1280e-05 - val_root_mean_squared_error: 0.0034
# Epoch 64/200
# 9/9 [==============================] - ETA: 0s - loss: 9.4925e-04 - root_mean_squared_error: 0.0308
# Epoch 64: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 340ms/step - loss: 9.4925e-04 - root_mean_squared_error: 0.0308 - val_loss: 9.0883e-05 - val_root_mean_squared_error: 0.0095
# Epoch 65/200
# 9/9 [==============================] - ETA: 0s - loss: 8.4526e-04 - root_mean_squared_error: 0.0291
# Epoch 65: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 341ms/step - loss: 8.4526e-04 - root_mean_squared_error: 0.0291 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# Epoch 66/200
# 9/9 [==============================] - ETA: 0s - loss: 9.0952e-04 - root_mean_squared_error: 0.0302
# Epoch 66: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 346ms/step - loss: 9.0952e-04 - root_mean_squared_error: 0.0302 - val_loss: 8.1518e-05 - val_root_mean_squared_error: 0.0090
# Epoch 67/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 67: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 328ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367 - val_loss: 2.8100e-04 - val_root_mean_squared_error: 0.0168
# Epoch 68/200
# 9/9 [==============================] - ETA: 0s - loss: 9.2849e-04 - root_mean_squared_error: 0.0305
# Epoch 68: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 343ms/step - loss: 9.2849e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3564e-05 - val_root_mean_squared_error: 0.0073
# Epoch 69/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0338
# Epoch 69: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 333ms/step - loss: 0.0011 - root_mean_squared_error: 0.0338 - val_loss: 6.5745e-04 - val_root_mean_squared_error: 0.0256
# Epoch 70/200
# 9/9 [==============================] - ETA: 0s - loss: 7.7510e-04 - root_mean_squared_error: 0.0278
# Epoch 70: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 324ms/step - loss: 7.7510e-04 - root_mean_squared_error: 0.0278 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0507
# Epoch 71/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0010 - root_mean_squared_error: 0.0319
# Epoch 71: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 320ms/step - loss: 0.0010 - root_mean_squared_error: 0.0319 - val_loss: 2.4362e-04 - val_root_mean_squared_error: 0.0156
# Epoch 72/200
# 9/9 [==============================] - ETA: 0s - loss: 7.0496e-04 - root_mean_squared_error: 0.0266
# Epoch 72: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 326ms/step - loss: 7.0496e-04 - root_mean_squared_error: 0.0266 - val_loss: 1.6479e-05 - val_root_mean_squared_error: 0.0041
# Epoch 73/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8078e-04 - root_mean_squared_error: 0.0279
# Epoch 73: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 325ms/step - loss: 7.8078e-04 - root_mean_squared_error: 0.0279 - val_loss: 4.4173e-05 - val_root_mean_squared_error: 0.0066
# Epoch 74/200
# 9/9 [==============================] - ETA: 0s - loss: 6.7115e-04 - root_mean_squared_error: 0.0259
# Epoch 74: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 327ms/step - loss: 6.7115e-04 - root_mean_squared_error: 0.0259 - val_loss: 1.0551e-04 - val_root_mean_squared_error: 0.0103
# Epoch 75/200
# 9/9 [==============================] - ETA: 0s - loss: 8.9459e-04 - root_mean_squared_error: 0.0299
# Epoch 75: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 338ms/step - loss: 8.9459e-04 - root_mean_squared_error: 0.0299 - val_loss: 4.6834e-04 - val_root_mean_squared_error: 0.0216
# Epoch 76/200
# 9/9 [==============================] - ETA: 0s - loss: 9.7375e-04 - root_mean_squared_error: 0.0312
# Epoch 76: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 337ms/step - loss: 9.7375e-04 - root_mean_squared_error: 0.0312 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0397
# Epoch 77/200
# 9/9 [==============================] - ETA: 0s - loss: 8.3572e-04 - root_mean_squared_error: 0.0289
# Epoch 77: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 325ms/step - loss: 8.3572e-04 - root_mean_squared_error: 0.0289 - val_loss: 5.0703e-04 - val_root_mean_squared_error: 0.0225
# Epoch 78/200
# 9/9 [==============================] - ETA: 0s - loss: 8.7128e-04 - root_mean_squared_error: 0.0295
# Epoch 78: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 330ms/step - loss: 8.7128e-04 - root_mean_squared_error: 0.0295 - val_loss: 7.0152e-06 - val_root_mean_squared_error: 0.0026
# Epoch 79/200
# 9/9 [==============================] - ETA: 0s - loss: 8.7019e-04 - root_mean_squared_error: 0.0295
# Epoch 79: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 341ms/step - loss: 8.7019e-04 - root_mean_squared_error: 0.0295 - val_loss: 1.3647e-04 - val_root_mean_squared_error: 0.0117
# Epoch 80/200
# 9/9 [==============================] - ETA: 0s - loss: 8.4533e-04 - root_mean_squared_error: 0.0291
# Epoch 80: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 359ms/step - loss: 8.4533e-04 - root_mean_squared_error: 0.0291 - val_loss: 1.1208e-04 - val_root_mean_squared_error: 0.0106
# Epoch 81/200
# 9/9 [==============================] - ETA: 0s - loss: 9.2989e-04 - root_mean_squared_error: 0.0305
# Epoch 81: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 390ms/step - loss: 9.2989e-04 - root_mean_squared_error: 0.0305 - val_loss: 3.7870e-05 - val_root_mean_squared_error: 0.0062
# Epoch 82/200
# 9/9 [==============================] - ETA: 0s - loss: 8.5834e-04 - root_mean_squared_error: 0.0293
# Epoch 82: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 411ms/step - loss: 8.5834e-04 - root_mean_squared_error: 0.0293 - val_loss: 5.5505e-05 - val_root_mean_squared_error: 0.0075
# Epoch 83/200
# 9/9 [==============================] - ETA: 0s - loss: 8.9922e-04 - root_mean_squared_error: 0.0300
# Epoch 83: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 383ms/step - loss: 8.9922e-04 - root_mean_squared_error: 0.0300 - val_loss: 2.1383e-05 - val_root_mean_squared_error: 0.0046
# Epoch 84/200
# 9/9 [==============================] - ETA: 0s - loss: 7.9525e-04 - root_mean_squared_error: 0.0282
# Epoch 84: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 375ms/step - loss: 7.9525e-04 - root_mean_squared_error: 0.0282 - val_loss: 2.0048e-04 - val_root_mean_squared_error: 0.0142
# Epoch 85/200
# 9/9 [==============================] - ETA: 0s - loss: 7.3060e-04 - root_mean_squared_error: 0.0270
# Epoch 85: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 349ms/step - loss: 7.3060e-04 - root_mean_squared_error: 0.0270 - val_loss: 2.9564e-04 - val_root_mean_squared_error: 0.0172
# Epoch 86/200
# 9/9 [==============================] - ETA: 0s - loss: 6.6346e-04 - root_mean_squared_error: 0.0258
# Epoch 86: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 341ms/step - loss: 6.6346e-04 - root_mean_squared_error: 0.0258 - val_loss: 4.8600e-05 - val_root_mean_squared_error: 0.0070
# Epoch 87/200
# 9/9 [==============================] - ETA: 0s - loss: 8.6309e-04 - root_mean_squared_error: 0.0294
# Epoch 87: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 360ms/step - loss: 8.6309e-04 - root_mean_squared_error: 0.0294 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# Epoch 88/200
# 9/9 [==============================] - ETA: 0s - loss: 6.7549e-04 - root_mean_squared_error: 0.0260
# Epoch 88: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 415ms/step - loss: 6.7549e-04 - root_mean_squared_error: 0.0260 - val_loss: 1.3064e-04 - val_root_mean_squared_error: 0.0114
# Epoch 89/200
# 9/9 [==============================] - ETA: 0s - loss: 9.3430e-04 - root_mean_squared_error: 0.0306
# Epoch 89: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 385ms/step - loss: 9.3430e-04 - root_mean_squared_error: 0.0306 - val_loss: 8.2805e-05 - val_root_mean_squared_error: 0.0091
# Epoch 90/200
# 9/9 [==============================] - ETA: 0s - loss: 7.6854e-04 - root_mean_squared_error: 0.0277
# Epoch 90: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 374ms/step - loss: 7.6854e-04 - root_mean_squared_error: 0.0277 - val_loss: 4.3670e-04 - val_root_mean_squared_error: 0.0209
# Epoch 91/200
# 9/9 [==============================] - ETA: 0s - loss: 8.9588e-04 - root_mean_squared_error: 0.0299
# Epoch 91: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 372ms/step - loss: 8.9588e-04 - root_mean_squared_error: 0.0299 - val_loss: 2.9367e-05 - val_root_mean_squared_error: 0.0054
# Epoch 92/200
# 9/9 [==============================] - ETA: 0s - loss: 7.2889e-04 - root_mean_squared_error: 0.0270
# Epoch 92: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 356ms/step - loss: 7.2889e-04 - root_mean_squared_error: 0.0270 - val_loss: 3.9095e-05 - val_root_mean_squared_error: 0.0063
# Epoch 93/200
# 9/9 [==============================] - ETA: 0s - loss: 6.6167e-04 - root_mean_squared_error: 0.0257
# Epoch 93: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 403ms/step - loss: 6.6167e-04 - root_mean_squared_error: 0.0257 - val_loss: 1.5661e-04 - val_root_mean_squared_error: 0.0125
# Epoch 94/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8980e-04 - root_mean_squared_error: 0.0281
# Epoch 94: val_loss did not improve from 0.00000
# 9/9 [==============================] - 4s 428ms/step - loss: 7.8980e-04 - root_mean_squared_error: 0.0281 - val_loss: 9.3052e-06 - val_root_mean_squared_error: 0.0031
# Epoch 95/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0327
# Epoch 95: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 352ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 3.8494e-05 - val_root_mean_squared_error: 0.0062
# Epoch 96/200
# 9/9 [==============================] - ETA: 0s - loss: 7.1711e-04 - root_mean_squared_error: 0.0268
# Epoch 96: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 344ms/step - loss: 7.1711e-04 - root_mean_squared_error: 0.0268 - val_loss: 1.1623e-05 - val_root_mean_squared_error: 0.0034
# Epoch 97/200
# 9/9 [==============================] - ETA: 0s - loss: 7.3362e-04 - root_mean_squared_error: 0.0271
# Epoch 97: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 352ms/step - loss: 7.3362e-04 - root_mean_squared_error: 0.0271 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0324
# Epoch 98/200
# 9/9 [==============================] - ETA: 0s - loss: 9.0229e-04 - root_mean_squared_error: 0.0300
# Epoch 98: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 334ms/step - loss: 9.0229e-04 - root_mean_squared_error: 0.0300 - val_loss: 6.0031e-06 - val_root_mean_squared_error: 0.0025
# Epoch 99/200
# 9/9 [==============================] - ETA: 0s - loss: 8.1929e-04 - root_mean_squared_error: 0.0286
# Epoch 99: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 340ms/step - loss: 8.1929e-04 - root_mean_squared_error: 0.0286 - val_loss: 2.8237e-04 - val_root_mean_squared_error: 0.0168
# Epoch 100/200
# 9/9 [==============================] - ETA: 0s - loss: 5.9760e-04 - root_mean_squared_error: 0.0244
# Epoch 100: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 356ms/step - loss: 5.9760e-04 - root_mean_squared_error: 0.0244 - val_loss: 4.8722e-04 - val_root_mean_squared_error: 0.0221
# Epoch 101/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8186e-04 - root_mean_squared_error: 0.0280
# Epoch 101: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 329ms/step - loss: 7.8186e-04 - root_mean_squared_error: 0.0280 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0382
# Epoch 102/200
# 9/9 [==============================] - ETA: 0s - loss: 7.0371e-04 - root_mean_squared_error: 0.0265
# Epoch 102: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 345ms/step - loss: 7.0371e-04 - root_mean_squared_error: 0.0265 - val_loss: 8.4528e-06 - val_root_mean_squared_error: 0.0029
# Epoch 103/200
# 9/9 [==============================] - ETA: 0s - loss: 7.0761e-04 - root_mean_squared_error: 0.0266
# Epoch 103: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 331ms/step - loss: 7.0761e-04 - root_mean_squared_error: 0.0266 - val_loss: 7.4684e-04 - val_root_mean_squared_error: 0.0273
# Epoch 104/200
# 9/9 [==============================] - ETA: 0s - loss: 9.0938e-04 - root_mean_squared_error: 0.0302
# Epoch 104: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 357ms/step - loss: 9.0938e-04 - root_mean_squared_error: 0.0302 - val_loss: 1.9313e-04 - val_root_mean_squared_error: 0.0139
# Epoch 105/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8809e-04 - root_mean_squared_error: 0.0281
# Epoch 105: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 335ms/step - loss: 7.8809e-04 - root_mean_squared_error: 0.0281 - val_loss: 1.3458e-04 - val_root_mean_squared_error: 0.0116
# Epoch 106/200
# 9/9 [==============================] - ETA: 0s - loss: 6.1548e-04 - root_mean_squared_error: 0.0248
# Epoch 106: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 349ms/step - loss: 6.1548e-04 - root_mean_squared_error: 0.0248 - val_loss: 1.8999e-04 - val_root_mean_squared_error: 0.0138
# Epoch 107/200
# 9/9 [==============================] - ETA: 0s - loss: 8.5965e-04 - root_mean_squared_error: 0.0293
# Epoch 107: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 346ms/step - loss: 8.5965e-04 - root_mean_squared_error: 0.0293 - val_loss: 7.6612e-05 - val_root_mean_squared_error: 0.0088
# Epoch 108/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0334
# Epoch 108: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 348ms/step - loss: 0.0011 - root_mean_squared_error: 0.0334 - val_loss: 3.7327e-04 - val_root_mean_squared_error: 0.0193
# Epoch 109/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8012e-04 - root_mean_squared_error: 0.0279
# Epoch 109: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 347ms/step - loss: 7.8012e-04 - root_mean_squared_error: 0.0279 - val_loss: 2.1247e-04 - val_root_mean_squared_error: 0.0146
# Epoch 110/200
# 9/9 [==============================] - ETA: 0s - loss: 7.2808e-04 - root_mean_squared_error: 0.0270
# Epoch 110: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 362ms/step - loss: 7.2808e-04 - root_mean_squared_error: 0.0270 - val_loss: 1.7718e-05 - val_root_mean_squared_error: 0.0042
# Epoch 111/200
# 9/9 [==============================] - ETA: 0s - loss: 4.9868e-04 - root_mean_squared_error: 0.0223
# Epoch 111: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 321ms/step - loss: 4.9868e-04 - root_mean_squared_error: 0.0223 - val_loss: 7.6193e-06 - val_root_mean_squared_error: 0.0028
# Epoch 112/200
# 9/9 [==============================] - ETA: 0s - loss: 4.9548e-04 - root_mean_squared_error: 0.0223
# Epoch 112: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 327ms/step - loss: 4.9548e-04 - root_mean_squared_error: 0.0223 - val_loss: 8.0198e-05 - val_root_mean_squared_error: 0.0090
# Epoch 113/200
# 9/9 [==============================] - ETA: 0s - loss: 7.8654e-04 - root_mean_squared_error: 0.0280
# Epoch 113: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 354ms/step - loss: 7.8654e-04 - root_mean_squared_error: 0.0280 - val_loss: 2.4897e-04 - val_root_mean_squared_error: 0.0158
# Epoch 114/200
# 9/9 [==============================] - ETA: 0s - loss: 7.2416e-04 - root_mean_squared_error: 0.0269
# Epoch 114: val_loss did not improve from 0.00000
# 9/9 [==============================] - 3s 339ms/step - loss: 7.2416e-04 - root_mean_squared_error: 0.0269 - val_loss: 3.4123e-04 - val_root_mean_squared_error: 0.0185
# Epoch 114: early stopping

# %%
# Visualize loss

# Visualize training and validation loss.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training Loss VS Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
# Model evaluation
test_predicted = model.predict(X_test)

# %%
test_predicted
# Out:
# array([[0.5083533 ],
#        [0.51599574],
#        [0.5213698 ],
#        [0.5242958 ],
#        [0.52806604],
#        [0.53541046],
#        [0.5479371 ],
#        [0.5644563 ],
#        [0.5830883 ],
#        [0.60219324],
#        [0.6204705 ],
#        [0.63834864],
#        [0.65778595],
#        [0.68147814],
#        [0.7116803 ],
#        [0.74730194],
#        [0.7841143 ],
#        [0.8182831 ],
#        [0.846313  ]], dtype=float32)

# %%
# Apply inverse transformation
test_predicted= scaler.inverse_transform(test_predicted)
#Y_test = scaler.inverse_transform(Y_test)
#test_predicted = test_predicted.reshape(test_predicted.shape[0],test_predicted.shape[1])
#test_predicted.shape

# %%
#Y_test.shape
#test_predicted.shape
#test_predicted = test_predicted.reshape(test_predicted.shape[0])
test_predicted
# Out:
# array([[246.37239],
#        [249.88422],
#        [253.25572],
#        [257.01883],
#        [261.83655],
#        [268.21252],
#        [276.26736],
#        [284.7645 ],
#        [292.13956],
#        [298.19995],
#        [302.71295]], dtype=float32)

# %%
# Re-populate Y_test
#X_test, Y_test = create_dmatrix(test_set, time_step)
#Y_test = Y_test.reshape(test_predicted.shape[0],1)
#Y_test = scaler.inverse_transform(Y_test)
#Y_test = Y_test.reshape(-1)
Y_test
# Out:
# array([0.69679428, 0.72444967, 0.75904152, 0.80074996, 0.84023198,
#        0.87596148, 0.91217893, 0.93992563, 0.97112559])

# %%
# Reshape Y_test to 2D
Y_test = Y_test.reshape(test_predicted.shape[0],1)
Y_test = scaler.inverse_transform(Y_test)

# Reshape back to 1D
Y_test = Y_test.reshape(test_predicted.shape[0])
Y_test
# Out:
# array([231.45046524, 231.83269223, 232.80002415, 235.63291781,
#        238.22681998, 241.91043322, 245.02071711, 248.77551829,
#        252.58926419, 256.19233444, 260.74244789, 266.31273152,
#        273.2801407 , 281.68095655, 289.63333011, 296.82988156,
#        304.12471465, 309.71339095, 315.99761266])

# %%
# Calculate RMSE
math.sqrt(mean_squared_error(Y_test,test_predicted))
# Out:
# 18.08482850108361

# %%
#test_predicted = test_predicted.reshape(-1, 1)
#test_predicted
test_predicted
# Out:
# array([[237.0811 ],
#        [240.32011],
#        [243.95862],
#        [248.07315],
#        [252.65337],
#        [257.63763],
#        [262.94397],
#        [268.51364],
#        [274.28806]], dtype=float32)

# %%
training_predicted = model.predict(X_train)
validation_predicted = model.predict(X_val)

# %%
training_predicted = scaler.inverse_transform(training_predicted)
#training_predicted.shape
validation_predicted = scaler.inverse_transform(validation_predicted)
#validation_predicted.shape
print(scaler.inverse_transform(validation_set))
# Out:
# [[177.79124755]
#  [179.30300157]
#  [180.23606116]
#  [181.27301702]
#  [181.906548  ]
#  [182.5129086 ]
#  [183.23624805]
#  [184.32702694]
#  [185.48524594]
#  [187.29957722]
#  [188.81726327]
#  [191.25350939]
#  [192.0606832 ]
#  [192.1530866 ]
#  [192.12507583]
#  [193.18992211]
#  [194.80182656]
#  [195.52227904]
#  [196.56334956]
#  [197.21897219]
#  [198.96773997]
#  [200.01970483]
#  [201.95115829]
#  [203.03163447]
#  [204.65713353]
#  [205.50370861]
#  [206.36003519]
#  [206.93065877]]

# %%
# Plotting everything together
# Setting the intervals 

# shift training predictions for plotting
training_predicted_plot = np.empty_like(df1)
training_predicted_plot[:, :] = np.nan
#training_predicted.shape
#training_predicted_plot[14:167, :] = training_predicted
training_predicted_plot[24:167, :] = training_predicted

#training_predicted_plot[24:143, :] = training_predicted
# shift validation predictions for plotting
val_predicted_plot = np.empty_like(df1)
val_predicted_plot[:, :] = np.nan
#validation_predicted.shape
#val_predicted_plot[181:214, :] = validation_predicted
#val_predicted_plot[192:203, :] = validation_predicted
#val_predicted_plot[168:191, :] = validation_predicted
val_predicted_plot[192:195, :] = validation_predicted
# shift test predictions for plotting
test_predicted_plot = np.empty_like(df1)
test_predicted_plot[:, :] = np.nan
#test_predicted.shape
#test_predicted_plot[230:239, :] = test_predicted
#test_predicted_plot[228:239, :] = test_predicted
#test_predicted_plot[216:239, :] = test_predicted
test_predicted_plot[220:239, :] = test_predicted

# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1), label = "Real Data")
plt.plot(test_predicted_plot, label = "Predicted Data for Test Set")
plt.plot(val_predicted_plot, label = "Predicted Data for Validation Set")
plt.plot(training_predicted_plot, label = "Predicted Data for Training Set")
plt.legend()
plt.show()

# %%
#math.sqrt(mean_squared_error(Y_test,test_predicted))
#print(scaler.inverse_transform(train_set))
#print(scaler.inverse_transform(training_predicted))
#train_set_invers = scaler.inverse_transform(Y_train)
#math.sqrt(mean_squared_error(_test,test_predicted))
#Y_train_sh = Y_train.reshape(training_predicted.shape[0],1)
#train_set_invers = scaler.inverse_transform(Y_train_sh)

#Y_train_d = Y_train.reshape(-1, 1)
#train_set_invers = scaler.inverse_transform(Y_train_d)
#math.sqrt(mean_squared_error(train_set_invers, training_predicted))
#print(scaler.inverse_transform(X_test))
#test_predicted
# Out:
# array([[237.0811 ],
#        [240.32011],
#        [243.95862],
#        [248.07315],
#        [252.65337],
#        [257.63763],
#        [262.94397],
#        [268.51364],
#        [274.28806]], dtype=float32)

# %%
# Create new array for future predictions

# Explanation. Since we have been predicting using timestep = 24, meaning we have used the past 24 prices to predict the 25th, now we will use the test_set data as that is the latest data to predict further INTO THE UNKNOWN!
# The size of the future_input array needs to be equal to timestep, so if you change the test_data size and timestep make sure to reflect those changes here as well.

pred_input=test_set[20:].reshape(1,-1)
pred_input
# Out:
# array([[0.52147711, 0.52940026, 0.54001855, 0.54781837, 0.55136519,
#         0.55326287, 0.55806549, 0.57213027, 0.58500849, 0.60329693,
#         0.61873889, 0.63738076, 0.65631528, 0.67420383, 0.69679428,
#         0.72444967, 0.75904152, 0.80074996, 0.84023198, 0.87596148,
#         0.91217893, 0.93992563, 0.97112559, 1.        ]])

# %%
# Add that to temp input
temp_input=list(pred_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.5214771099328371,
#  0.5294002616466654,
#  0.5400185496809672,
#  0.547818365302882,
#  0.5513651887811998,
#  0.5532628726176704,
#  0.5580654904306673,
#  0.5721302651987928,
#  0.5850084929300411,
#  0.6032969274853995,
#  0.618738891631221,
#  0.637380760719506,
#  0.6563152790464756,
#  0.6742038330898864,
#  0.6967942753713957,
#  0.7244496672966544,
#  0.7590415200934172,
#  0.800749962664507,
#  0.8402319750835007,
#  0.8759614753754742,
#  0.9121789252262916,
#  0.9399256332415941,
#  0.9711255910452022,
#  0.9999999999999999]

# %%
# Predict in the future

from numpy import array

list_output=[]
n_steps=24
i=0
while(i<12):
    
    if(len(temp_input)>24):
        print('Entering main condition')
        #print(temp_input)
        pred_input=np.array(temp_input[1:]) # Shift one to the right
        print("{} month input {}".format(i,pred_input))
        pred_input=pred_input.reshape(1,-1)
        pred_input = pred_input.reshape(1, n_steps, 1)
        print('Pred_input shape is:', pred_input.shape)
        fut_pred = model.predict(pred_input, verbose=0)
        print("{} month output {}".format(i,fut_pred))
        temp_input.extend(fut_pred[0].tolist()) # Add that prediction to the temp input list as that will be used in the next prediction 
        temp_input=temp_input[1:] #Shift the temp_input to remove the first element which was already used in a sequence
        #print(temp_input)
        list_output.extend(fut_pred.tolist())
        i=i+1
    else:
        print('Entering else condition')
        pred_input = pred_input.reshape((1, n_steps,1))
        fut_pred = model.predict(pred_input, verbose=0)
        print('The predicted value is:',fut_pred[0])
        temp_input.extend(fut_pred[0].tolist())
        print(len(temp_input))
        list_output.extend(fut_pred.tolist())
        i=i+1
    

print(list_output)
# Out:
# Entering else condition
# The predicted value is: [0.8857332]
# 25
# Entering main condition
# 1 month input [0.52940026 0.54001855 0.54781837 0.55136519 0.55326287 0.55806549
#  0.57213027 0.58500849 0.60329693 0.61873889 0.63738076 0.65631528
#  0.67420383 0.69679428 0.72444967 0.75904152 0.80074996 0.84023198
#  0.87596148 0.91217893 0.93992563 0.97112559 1.         0.88573319]
# Pred_input shape is: (1, 24, 1)
# 1 month output [[0.86932856]]
# Entering main condition
# 2 month input [0.54001855 0.54781837 0.55136519 0.55326287 0.55806549 0.57213027
#  0.58500849 0.60329693 0.61873889 0.63738076 0.65631528 0.67420383
#  0.69679428 0.72444967 0.75904152 0.80074996 0.84023198 0.87596148
#  0.91217893 0.93992563 0.97112559 1.         0.88573319 0.86932856]
# Pred_input shape is: (1, 24, 1)
# 2 month output [[0.82108843]]
# Entering main condition
# 3 month input [0.54781837 0.55136519 0.55326287 0.55806549 0.57213027 0.58500849
#  0.60329693 0.61873889 0.63738076 0.65631528 0.67420383 0.69679428
#  0.72444967 0.75904152 0.80074996 0.84023198 0.87596148 0.91217893
#  0.93992563 0.97112559 1.         0.88573319 0.86932856 0.82108843]
# Pred_input shape is: (1, 24, 1)
# 3 month output [[0.75441676]]
# Entering main condition
# 4 month input [0.55136519 0.55326287 0.55806549 0.57213027 0.58500849 0.60329693
#  0.61873889 0.63738076 0.65631528 0.67420383 0.69679428 0.72444967
#  0.75904152 0.80074996 0.84023198 0.87596148 0.91217893 0.93992563
#  0.97112559 1.         0.88573319 0.86932856 0.82108843 0.75441676]
# Pred_input shape is: (1, 24, 1)
# 4 month output [[0.6796441]]
# Entering main condition
# 5 month input [0.55326287 0.55806549 0.57213027 0.58500849 0.60329693 0.61873889
#  0.63738076 0.65631528 0.67420383 0.69679428 0.72444967 0.75904152
#  0.80074996 0.84023198 0.87596148 0.91217893 0.93992563 0.97112559
#  1.         0.88573319 0.86932856 0.82108843 0.75441676 0.67964411]
# Pred_input shape is: (1, 24, 1)
# 5 month output [[0.60140985]]
# Entering main condition
# 6 month input [0.55806549 0.57213027 0.58500849 0.60329693 0.61873889 0.63738076
#  0.65631528 0.67420383 0.69679428 0.72444967 0.75904152 0.80074996
#  0.84023198 0.87596148 0.91217893 0.93992563 0.97112559 1.
#  0.88573319 0.86932856 0.82108843 0.75441676 0.67964411 0.60140985]
# Pred_input shape is: (1, 24, 1)
# 6 month output [[0.5209803]]
# Entering main condition
# 7 month input [0.57213027 0.58500849 0.60329693 0.61873889 0.63738076 0.65631528
#  0.67420383 0.69679428 0.72444967 0.75904152 0.80074996 0.84023198
#  0.87596148 0.91217893 0.93992563 0.97112559 1.         0.88573319
#  0.86932856 0.82108843 0.75441676 0.67964411 0.60140985 0.5209803 ]
# Pred_input shape is: (1, 24, 1)
# 7 month output [[0.43863404]]
# Entering main condition
# 8 month input [0.58500849 0.60329693 0.61873889 0.63738076 0.65631528 0.67420383
#  0.69679428 0.72444967 0.75904152 0.80074996 0.84023198 0.87596148
#  0.91217893 0.93992563 0.97112559 1.         0.88573319 0.86932856
#  0.82108843 0.75441676 0.67964411 0.60140985 0.5209803  0.43863404]
# Pred_input shape is: (1, 24, 1)
# 8 month output [[0.35470387]]
# Entering main condition
# 9 month input [0.60329693 0.61873889 0.63738076 0.65631528 0.67420383 0.69679428
#  0.72444967 0.75904152 0.80074996 0.84023198 0.87596148 0.91217893
#  0.93992563 0.97112559 1.         0.88573319 0.86932856 0.82108843
#  0.75441676 0.67964411 0.60140985 0.5209803  0.43863404 0.35470387]
# Pred_input shape is: (1, 24, 1)
# 9 month output [[0.2696744]]
# Entering main condition
# 10 month input [0.61873889 0.63738076 0.65631528 0.67420383 0.69679428 0.72444967
#  0.75904152 0.80074996 0.84023198 0.87596148 0.91217893 0.93992563
#  0.97112559 1.         0.88573319 0.86932856 0.82108843 0.75441676
#  0.67964411 0.60140985 0.5209803  0.43863404 0.35470387 0.26967439]
# Pred_input shape is: (1, 24, 1)
# 10 month output [[0.18395458]]
# Entering main condition
# 11 month input [0.63738076 0.65631528 0.67420383 0.69679428 0.72444967 0.75904152
#  0.80074996 0.84023198 0.87596148 0.91217893 0.93992563 0.97112559
#  1.         0.88573319 0.86932856 0.82108843 0.75441676 0.67964411
#  0.60140985 0.5209803  0.43863404 0.35470387 0.26967439 0.18395458]
# Pred_input shape is: (1, 24, 1)
# 11 month output [[0.09774858]]
# [[0.8857331871986389], [0.8693285584449768], [0.821088433265686], [0.7544167637825012], [0.6796441078186035], [0.6014098525047302], [0.5209802985191345], [0.4386340379714966], [0.3547038733959198], [0.2696743905544281], [0.18395458161830902], [0.09774857759475708]]

# %%
month_new = np.arange(1, 24)
month_pred = np.arange(24,36)

# %%
plt.plot(month_new,scaler.inverse_transform(df1[217:]))
plt.plot(month_pred,scaler.inverse_transform(list_output))

# %%
df3 = df1.tolist()
df3.extend(list_output)
plt.plot(df3[240:])

# %%
print(scaler.inverse_transform(list_output))
# Out:
# [[298.79807664]
#  [295.49389512]
#  [285.7774832 ]
#  [272.34863322]
#  [257.28810171]
#  [241.53034304]
#  [225.3304125 ]
#  [208.74442347]
#  [191.83940823]
#  [174.7129709 ]
#  [157.44748973]
#  [140.08408029]]

# %%
df3=scaler.inverse_transform(df3).tolist()
plt.plot(df3)

# %%
# Make copy of original data
df_orig33 = pd.read_csv('/content/Model_Tampa_Prediction_6months.csv')
df_orig33
# Out:
#            DATE      TPXRSA
# 0    2002-01-01  120.395793
# 1    2002-02-01  120.700034
# 2    2002-03-01  122.958147
# 3    2002-04-01  123.707047
# 4    2002-05-01  124.950321
# ..          ...         ...
# 241  2022-02-01  295.493895
# 242  2022-03-01  285.777483
# 243  2022-04-01  272.348633
# 244  2022-05-01  257.288102
# 245  2022-06-01  241.530343
#
# [246 rows x 2 columns]

# %%
output1_df = pd.DataFrame(df3, columns=['Sale Price'])
output1_df
# Out:
#      Sale Price
# 0    120.395793
# 1    120.700034
# 2    122.958147
# 3    123.707047
# 4    124.950321
# ..          ...
# 241  295.493895
# 242  285.777483
# 243  272.348633
# 244  257.288102
# 245  241.530343
#
# [246 rows x 1 columns]

# %%
test_df = df_orig.copy()
test_df['TXP'] = output1_df

# %%
result = [output1_df, df_orig]
new_df = pd.concat(result, axis =1)

# %%
new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
new_df
# Out:
#      Sale Price        DATE
# 0    120.395793  2002-01-01
# 1    120.700034  2002-02-01
# 2    122.958147  2002-03-01
# 3    123.707047  2002-04-01
# 4    124.950321  2002-05-01
# ..          ...         ...
# 241  295.493895         NaN
# 242  285.777483         NaN
# 243  272.348633         NaN
# 244  257.288102         NaN
# 245  241.530343         NaN
#
# [246 rows x 2 columns]

# %%
#new_df['DATE'] = pd.to_datetime(new_df['DATE'])
#new_df = new_df.set_index('DATE')
#new_df.index = new_df.index.to_period("1M")

# %%
#new_df = new_df.drop(['TPXRSA'], axis =1 )

# %%
#new_date_range = pd.date_range(start="2002-01", end='2023-01', freq="M")
#new_date_range = pd.Series(pd.date_range("1/1/2002", freq="M", periods=len(df3)))
#new_df = new_df.reindex(new_date_range, fill_value=0)

# %%
#new_df['Sale Price'] = output1_df['Sale Price']

#new_df = new_df.append(output1_df, ignore_index = True)

# %%
#df_orig1 = df_orig.copy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-a5f9668e6f2b> in <module>()
#       1 df_orig1 = df_orig.copy()
# ----> 2 df_orig1 = pd.concat(output1_df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     328         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
#     329             raise TypeError(
# --> 330                 "first argument must be an iterable of pandas "
#     331                 f'objects, you passed an object of type "{type(objs).__name__}"'
#     332             )
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
result1 = [new_df, output_df]
new_df = pd.concat(result1, axis =1)

# %%
# Out:
#            DATE      TPXRSA  Sale Price
# 0    2002-01-01  120.395793         NaN
# 1    2002-02-01  120.700034         NaN
# 2    2002-03-01  122.958147         NaN
# 3    2002-04-01  123.707047         NaN
# 4    2002-05-01  124.950321         NaN
# ..          ...         ...         ...
# 481         NaN         NaN  295.493895
# 482         NaN         NaN  285.777483
# 483         NaN         NaN  272.348633
# 484         NaN         NaN  257.288102
# 485         NaN         NaN  241.530343
#
# [486 rows x 3 columns]
